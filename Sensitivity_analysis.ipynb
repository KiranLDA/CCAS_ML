# %% [markdown]
# # SENSITIVITY ANALYSES
# ------------------------

# %% [markdown]
# ## Import Libraries

# %%
github_dir = "/home/kiran/Documents/github/CCAS_ML"

# add path to local functions
import os
os.chdir(github_dir)

# import all the params for this model
from example_params import *
is_forked = True # is going to need to go into the params file

# import own functions
import preprocess.preprocess_functions as pre
import postprocess.evaluation_metrics_functions_old as metrics
import postprocess.merge_predictions_functions as ppm
import model.specgen_batch_generator as bg
import model.network_class as rnn
# import postprocess.visualise_prediction_functions as pp
from model.callback_functions import LossHistory
import model.audiopool as audiopool

# import normal packages used in pre-processing
import numpy as np
import librosa
import warnings
import ntpath
import os
from itertools import compress  
from random import random, shuffle
from math import floor
import statistics
import glob

# plotting
import matplotlib.pyplot as plt

# ML section packages
import datetime
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras import optimizers
from keras.layers import Input, Flatten
from keras.models import Model
from keras.layers import Conv2D, MaxPooling2D, Activation, SeparableConv2D, concatenate
from keras.layers import Reshape, Permute
from keras.layers import TimeDistributed, Dense, Dropout, BatchNormalization
from keras.models import load_model
from keras.layers import GRU, Bidirectional, GlobalAveragePooling2D
from keras.callbacks import TensorBoard
from keras.utils import plot_model

# postprocessfrom decimal import Decimal
from decimal import Decimal
import pandas as pd
import pickle

# evaluate and plot 
import seaborn as sn
# import pandas as pd
# import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import csv
# Out:
# /home/kiran/anaconda3/envs/ML1_env/lib/python3.7/site-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# /home/kiran/anaconda3/envs/ML1_env/lib/python3.7/site-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import of 'jit' requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# WARNING:tensorflow:From /home/kiran/Documents/github/CCAS_ML/postprocess/evaluation_metrics_functions_old.py:10: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/kiran/Documents/github/CCAS_ML/postprocess/evaluation_metrics_functions_old.py:12: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# Using TensorFlow backend.

# %% [markdown]
# ----------------------------------------------------------------------
# # PREPROCESSING / DATA WRANGLING
#
# Currently, all the meerkat files are found on the server. The labels in particular are divided by year (currently 2017 and 2019) and all file labels are in a single document. This bit of code just takes these and puts them together

# %%
# Compile all the synched label files together
labels_all = pd.DataFrame()
for directory in label_dirs:
    for group in group_IDs:
        temp = pd.read_csv(os.path.join(directory, group +"_ALL_CALLS_SYNCHED.csv"), sep=sep,
                       header=0, engine = engine, encoding = encoding) 
        temp["group"] = group
        labels_all = pd.concat([labels_all, temp]) 
        del temp

labels_all = labels_all[-labels_all.wavFileName.str.contains('SOUNDFOC')]
labels_all = labels_all.reset_index(drop = True)

# %% [markdown]
# Data also contain focal follows (someone walking around behind the meerkats) and the resultion of this data is different and therefore not anlysed with the collar data (but could be done separately or put to the same resolution).

# %%
# subset all the audio files that we should use in the analysis (i.e. not focal follow data)
audio_files = list(set(labels_all["wavFileName"]))
audio_filenames = list(compress(audio_files, ["SOUNDFOC" not in filei for filei in audio_files]))

# subset all the audio files that we should use in the analysis (i.e. not focal follow data)
label_files = list(set(labels_all["csvFileName"]))
label_filenames = list(compress(label_files, ["SOUNDFOC" not in filei for filei in label_files]))

# get the file IDS without all the extentions (used later for naming)
all_filenames = [audio_filenames[i].split(".")[0] for i in range(0,len(audio_filenames))]

# %% [markdown]
# Then we locate all the paths to the files

# %%
# find all the labels
EXT = "*.csv"
label_filepaths = []
for PATH in acoustic_data_path :
      label_filepaths.extend( [file for path, subdir, files in os.walk(PATH) for file in glob.glob(os.path.join(path, EXT))])
EXT = "*.CSV"
for PATH in acoustic_data_path :
      label_filepaths.extend( [file for path, subdir, files in os.walk(PATH) for file in glob.glob(os.path.join(path, EXT))])

# find all audio paths (will be longer than label path as not everything is labelled)
audio_filepaths = []
EXT = "*.wav"
for PATH in audio_dirs:
      audio_filepaths.extend( [file for path, subdir, files in os.walk(PATH) for file in glob.glob(os.path.join(path, EXT))])

# %% [markdown]
# ### Create a label table
#
# Currently, the labels are stored in a file generated by audition for the meerkats. We want to these manual labels and put them into a more meaningful categories for for the machine learning. To set categories, I use a pre-defined dictionary called call_types that is defined in the parameters file and which specifies what the different classes are for the call types. Anything strange gets put into a category "oth" for other.

# %%
# Create the label table
label_table = pre.create_meerkat_table(labels_all, call_types, sep,
                                       start_column, duration_column, columns_to_keep,
                                       label_column, convert_to_seconds, 
                                       label_for_other, label_for_noise, engine,
                                       multiclass_forbidden)
# Out:
# This label 'c' on line 5909 will be classed as 'oth'
# This label 'c' on line 7266 will be classed as 'oth'
# This label 'cn' on line 7921 will be classed as 'oth'
# This label 'chew' on line 8385 will be classed as 'oth'
# This label 'sb' on line 8504 will be classed as 'oth'
# This label 'chew' on line 8782 will be classed as 'oth'
# This label 'chew' on line 8862 will be classed as 'oth'
# This label 'chew' on line 8886 will be classed as 'oth'
# This label 'chew' on line 8887 will be classed as 'oth'
# This label 'chew' on line 8890 will be classed as 'oth'
# This label 'chew' on line 8914 will be classed as 'oth'
# This label 'chew' on line 8933 will be classed as 'oth'
# This label 'chew' on line 8962 will be classed as 'oth'
# This label 'chew' on line 9008 will be classed as 'oth'
# This label 'chew' on line 9011 will be classed as 'oth'
# This label 'chew' on line 9045 will be classed as 'oth'
# This label 'chew' on line 9046 will be classed as 'oth'
# This label 'chew' on line 9243 will be classed as 'oth'
# This label 'chew' on line 9249 will be classed as 'oth'
# This label 'chew' on line 9268 will be classed as 'oth'
# This label 'chew' on line 9697 will be classed as 'oth'
# This label 'chew' on line 9842 will be classed as 'oth'
# This label 'chew' on line 9861 will be classed as 'oth'
# This label 'chew' on line 10115 will be classed as 'oth'
# This label 'chew' on line 10139 will be classed as 'oth'
# This label 'chew' on line 10141 will be classed as 'oth'
# This label '01:48:00' on line 11666 will be classed as 'oth'
# This label 'c' on line 13384 will be classed as 'oth'
# This label 'nan' on line 13961 will be classed as 'oth'
# This label 'sx' on line 18196 will be classed as 'oth'
# This label 'pause' on line 18848 will be classed as 'oth'
# This label 'sc f' on line 19787 will be classed as 'oth'
# This label 'eating' on line 20297 will be classed as 'oth'
# This label 'eating' on line 20298 will be classed as 'oth'
# This label 'eating' on line 20312 will be classed as 'oth'
# This label 'eating' on line 20330 will be classed as 'oth'
# This label 'x' on line 20426 will be classed as 'oth'
# This label 'x' on line 20509 will be classed as 'oth'
# This label 'x' on line 21496 will be classed as 'oth'
# This label 'eating' on line 21500 will be classed as 'oth'
# This label 'eating' on line 21507 will be classed as 'oth'
# This label 'x' on line 21510 will be classed as 'oth'
# This label 'x' on line 21541 will be classed as 'oth'
# This label 'c nf' on line 22004 will be classed as 'oth'
# This label 'x' on line 22292 will be classed as 'oth'
# This label 'x' on line 22294 will be classed as 'oth'
# This label 'x' on line 22297 will be classed as 'oth'
# This label 'x' on line 22311 will be classed as 'oth'
# This label 'x nf' on line 22318 will be classed as 'oth'
# This label 'x' on line 22323 will be classed as 'oth'
# This label 'x' on line 22331 will be classed as 'oth'
# This label 'x nf' on line 22340 will be classed as 'oth'
# This label 'x nf' on line 22356 will be classed as 'oth'
# This label 'x' on line 22362 will be classed as 'oth'
# This label 'x' on line 22381 will be classed as 'oth'
# This label 'x nf' on line 22385 will be classed as 'oth'
# This label 'x nf' on line 22405 will be classed as 'oth'
# This label 'x nf' on line 22436 will be classed as 'oth'
# This label 'x' on line 22438 will be classed as 'oth'
# This label 'x nf' on line 22445 will be classed as 'oth'
# This label 'x nf' on line 22448 will be classed as 'oth'
# This label '01:25:30' on line 22510 will be classed as 'oth'
# This label 'na' on line 23324 will be classed as 'oth'
# This label 'na' on line 23331 will be classed as 'oth'
# This label 'na' on line 23344 will be classed as 'oth'
# This label 'na' on line 23353 will be classed as 'oth'
# This label 'na' on line 23551 will be classed as 'oth'
# This label 'na' on line 23553 will be classed as 'oth'
# This label 'na' on line 23561 will be classed as 'oth'
# This label 'na' on line 23626 will be classed as 'oth'
# This label 'na' on line 23632 will be classed as 'oth'
# This label 'na' on line 23674 will be classed as 'oth'
# This label 'na' on line 23755 will be classed as 'oth'
# This label 'na' on line 23821 will be classed as 'oth'
# This label 'na' on line 23856 will be classed as 'oth'
# This label 'na' on line 23877 will be classed as 'oth'
# This label 'x' on line 24344 will be classed as 'oth'
# This label 'x' on line 24386 will be classed as 'oth'
# This label 'x' on line 24664 will be classed as 'oth'
# This label 'x' on line 24693 will be classed as 'oth'
# This label 'x' on line 24709 will be classed as 'oth'
# This label 'x' on line 24710 will be classed as 'oth'
# This label 'x' on line 24712 will be classed as 'oth'
# This label 'x' on line 24754 will be classed as 'oth'
# This label 'x' on line 24770 will be classed as 'oth'
# This label 'x' on line 24771 will be classed as 'oth'
# This label 'x' on line 24813 will be classed as 'oth'
# This label 'x' on line 24840 will be classed as 'oth'
# This label 'x' on line 24841 will be classed as 'oth'
# This label 'x' on line 24842 will be classed as 'oth'
# This label 'x' on line 24907 will be classed as 'oth'
# This label 'x' on line 24908 will be classed as 'oth'
# This label 'x' on line 27182 will be classed as 'oth'
# This label 'x' on line 27396 will be classed as 'oth'
# This label 'x' on line 27457 will be classed as 'oth'
# This label 'x' on line 27568 will be classed as 'oth'
# This label 'x' on line 27580 will be classed as 'oth'
# This label 'x' on line 29274 will be classed as 'oth'
# This label 'x' on line 29531 will be classed as 'oth'
# This label 'x' on line 29688 will be classed as 'oth'
# This label 'x' on line 29690 will be classed as 'oth'
# This label 'c nf' on line 29839 will be classed as 'oth'
# This label 'x' on line 30166 will be classed as 'oth'
# This label 's%' on line 32036 will be classed as 'oth'
# This label 'chuck' on line 32167 will be classed as 'oth'
# This label 'x' on line 32340 will be classed as 'oth'
# This label 'x' on line 32407 will be classed as 'oth'
# This label 'synh 01:30:00' on line 32910 will be classed as 'oth'
# This label 'sych 01:51:00' on line 33314 will be classed as 'oth'
# This label 'x' on line 34057 will be classed as 'oth'
# This label 'digging' on line 34282 will be classed as 'oth'
# This label 'digging' on line 34285 will be classed as 'oth'
# This label 'chew' on line 34373 will be classed as 'oth'
# This label 'chew' on line 34374 will be classed as 'oth'
# This label 'chew' on line 34375 will be classed as 'oth'
# This label 'x' on line 34592 will be classed as 'oth'
# This label 'x' on line 34622 will be classed as 'oth'
# This label 'x' on line 34665 will be classed as 'oth'
# This label 'x' on line 34753 will be classed as 'oth'
# This label 'x' on line 34836 will be classed as 'oth'
# This label 'x' on line 34951 will be classed as 'oth'
# This label '//' on line 35075 will be classed as 'oth'
# This label 'x' on line 36573 will be classed as 'oth'
# This label 'x' on line 37322 will be classed as 'oth'
# This label 'x' on line 38818 will be classed as 'oth'
# This label 'sycnh 01:54:00' on line 40080 will be classed as 'oth'
# This label 'aynxh 01:28:30' on line 40931 will be classed as 'oth'
# This label 'x' on line 41786 will be classed as 'oth'
# This label 'x' on line 44978 will be classed as 'oth'
# This label 'x' on line 45052 will be classed as 'oth'
# This label 'x' on line 45095 will be classed as 'oth'
# This label 'x' on line 45109 will be classed as 'oth'
# This label 'x' on line 45135 will be classed as 'oth'
# This label 'x' on line 45474 will be classed as 'oth'
# This label 'x' on line 45758 will be classed as 'oth'
# This label 'x' on line 46865 will be classed as 'oth'
# This label 'x' on line 47160 will be classed as 'oth'
# This label 'x' on line 47324 will be classed as 'oth'
# This label 'x' on line 48199 will be classed as 'oth'
# This label 'ññ' on line 48424 will be classed as 'oth'
# This label 'ññ x' on line 48490 will be classed as 'oth'
# This label '××' on line 48615 will be classed as 'oth'
# This label 'x' on line 49340 will be classed as 'oth'
# This label 'x' on line 49664 will be classed as 'oth'
# This label 'x' on line 49745 will be classed as 'oth'
# This label 'x' on line 49887 will be classed as 'oth'
# This label 'x' on line 49888 will be classed as 'oth'
# This label 'x' on line 49889 will be classed as 'oth'
# This label 'x' on line 49890 will be classed as 'oth'
# This label 'x' on line 49891 will be classed as 'oth'
# This label 'x' on line 50849 will be classed as 'oth'
# This label 'x' on line 52248 will be classed as 'oth'
# This label 'x' on line 52382 will be classed as 'oth'
# This label 'x' on line 52419 will be classed as 'oth'
# This label 'eating' on line 52620 will be classed as 'oth'
# This label 'x' on line 52896 will be classed as 'oth'
# This label 'x' on line 52984 will be classed as 'oth'
# This label 'x' on line 53082 will be classed as 'oth'
# This label 'x' on line 55858 will be classed as 'oth'
# This label 'x' on line 56061 will be classed as 'oth'
# This label 'x' on line 56162 will be classed as 'oth'
# This label 'eating' on line 56190 will be classed as 'oth'
# This label 'x' on line 56385 will be classed as 'oth'
# This label 'x' on line 57233 will be classed as 'oth'
# This label 'x' on line 57814 will be classed as 'oth'
# This label 'x' on line 57886 will be classed as 'oth'
# This label 'x' on line 58020 will be classed as 'oth'
# This label 'm nf' on line 58263 will be classed as 'oth'
# This label 'x' on line 58372 will be classed as 'oth'
# This label 'sc x nf' on line 58510 will be classed as 'oth'
# This label 'x' on line 58736 will be classed as 'oth'
# This label 'x' on line 58812 will be classed as 'oth'
# This label 'x' on line 59226 will be classed as 'oth'
# This label 'x' on line 59634 will be classed as 'oth'
# This label 'x' on line 59762 will be classed as 'oth'
# This label 'x' on line 59879 will be classed as 'oth'
# This label 'x' on line 60509 will be classed as 'oth'
# This label 'x' on line 60626 will be classed as 'oth'
# This label 'x' on line 62005 will be classed as 'oth'
# This label 'x' on line 62584 will be classed as 'oth'
# This label 'x' on line 62686 will be classed as 'oth'
# This label 'x' on line 64059 will be classed as 'oth'
# This label 'x' on line 64060 will be classed as 'oth'
# This label 'x' on line 64510 will be classed as 'oth'
# This label 'x' on line 66199 will be classed as 'oth'
# This label 'x' on line 67409 will be classed as 'oth'
# This label 'eating' on line 67465 will be classed as 'oth'
# This label 'eating' on line 67469 will be classed as 'oth'
# This label 'eating' on line 67571 will be classed as 'oth'
# This label 'x' on line 67768 will be classed as 'oth'
# This label 'eating' on line 67786 will be classed as 'oth'
# This label 'x' on line 69049 will be classed as 'oth'
# This label 'x' on line 70355 will be classed as 'oth'
# This label 'x' on line 70434 will be classed as 'oth'
# This label 'x' on line 70466 will be classed as 'oth'
# This label 'x' on line 71220 will be classed as 'oth'
# This label 'ññ' on line 71762 will be classed as 'oth'
# This label 'x' on line 72157 will be classed as 'oth'
# This label 'x' on line 72158 will be classed as 'oth'
# This label 'sycnh 01:36:00' on line 72213 will be classed as 'oth'
# This label 'ññ nf' on line 72365 will be classed as 'oth'
# This label 'ññ nf' on line 72366 will be classed as 'oth'
# This label 'x' on line 73069 will be classed as 'oth'
# This label 'beg nf' on line 73110 will be classed as 'oth'
# This label 'beg nf' on line 73111 will be classed as 'oth'
# This label 'beg nf' on line 73112 will be classed as 'oth'
# This label 'beg nf' on line 73113 will be classed as 'oth'
# This label 'beg nf' on line 73114 will be classed as 'oth'
# This label 'beg nf' on line 73115 will be classed as 'oth'
# This label 'beg nf' on line 73116 will be classed as 'oth'
# This label 'x' on line 73330 will be classed as 'oth'
# This label 'x' on line 73360 will be classed as 'oth'
# This label 'x' on line 73421 will be classed as 'oth'
# This label 'x' on line 73494 will be classed as 'oth'
# This label 'x' on line 73551 will be classed as 'oth'
# This label 'x' on line 73610 will be classed as 'oth'
# This label 'x' on line 73660 will be classed as 'oth'
# This label 'x' on line 73667 will be classed as 'oth'
# This label 'x' on line 73676 will be classed as 'oth'
# This label 'x' on line 73677 will be classed as 'oth'
# This label 'x' on line 73761 will be classed as 'oth'
# This label 'x' on line 73762 will be classed as 'oth'
# This label 'x' on line 73896 will be classed as 'oth'
# This label 'x' on line 73965 will be classed as 'oth'
# This label 'zz' on line 73985 will be classed as 'oth'
# This label 'x' on line 74071 will be classed as 'oth'
# This label 'x' on line 74084 will be classed as 'oth'
# This label 'x' on line 74145 will be classed as 'oth'
# This label 'x' on line 74151 will be classed as 'oth'
# This label 'x' on line 74304 will be classed as 'oth'
# This label 'x' on line 74840 will be classed as 'oth'
# This label 'x' on line 74979 will be classed as 'oth'
# This label 'cñ *' on line 75342 will be classed as 'oth'
# This label 'cñ nf' on line 75344 will be classed as 'oth'
# This label 'ññ nf' on line 75363 will be classed as 'oth'
# This label 'ññ nf' on line 75364 will be classed as 'oth'
# This label 'ññ nf' on line 75365 will be classed as 'oth'
# This label 'x' on line 75679 will be classed as 'oth'
# This label 'x' on line 75703 will be classed as 'oth'
# This label 'x' on line 75730 will be classed as 'oth'
# This label 'x' on line 75754 will be classed as 'oth'
# This label 'x' on line 75764 will be classed as 'oth'
# This label 'x' on line 75776 will be classed as 'oth'
# This label 'x' on line 75806 will be classed as 'oth'
# This label 'x' on line 75877 will be classed as 'oth'
# This label 'x' on line 75882 will be classed as 'oth'
# This label 'x' on line 75895 will be classed as 'oth'
# This label 'x' on line 75909 will be classed as 'oth'
# This label 'x' on line 75923 will be classed as 'oth'
# This label 'x' on line 75946 will be classed as 'oth'
# This label 'synhch 01:37:30' on line 76620 will be classed as 'oth'
# This label 'x' on line 76757 will be classed as 'oth'
# This label 'x' on line 76760 will be classed as 'oth'
# This label 'x' on line 76767 will be classed as 'oth'
# This label 'x' on line 76768 will be classed as 'oth'
# This label 'x' on line 76769 will be classed as 'oth'
# This label 'x' on line 76772 will be classed as 'oth'
# This label 'x' on line 76773 will be classed as 'oth'
# This label 'x' on line 76774 will be classed as 'oth'
# This label 'x' on line 76775 will be classed as 'oth'
# This label 'x' on line 76857 will be classed as 'oth'
# This label 'x' on line 76893 will be classed as 'oth'
# This label 'x' on line 76894 will be classed as 'oth'
# This label 'x' on line 76902 will be classed as 'oth'
# This label 'x' on line 76907 will be classed as 'oth'
# This label 'x' on line 76922 will be classed as 'oth'
# This label 'x' on line 76940 will be classed as 'oth'
# This label 'x' on line 76941 will be classed as 'oth'
# This label 'x' on line 76943 will be classed as 'oth'
# This label 'x' on line 76945 will be classed as 'oth'
# This label 'x' on line 76946 will be classed as 'oth'
# This label 'x' on line 76994 will be classed as 'oth'
# This label 'x' on line 77061 will be classed as 'oth'
# This label '*' on line 77173 will be classed as 'oth'
# This label 'a %' on line 77243 will be classed as 'oth'
# This label 'x' on line 77358 will be classed as 'oth'
# This label 'sic nf %' on line 77601 will be classed as 'oth'
# This label 'x' on line 78211 will be classed as 'oth'
# This label 'x' on line 78624 will be classed as 'oth'
# This label 'x' on line 78643 will be classed as 'oth'
# This label 'x' on line 78649 will be classed as 'oth'
# This label 'x' on line 78683 will be classed as 'oth'
# This label 'x' on line 78698 will be classed as 'oth'
# This label 'x' on line 78702 will be classed as 'oth'
# This label 'sic nf' on line 78773 will be classed as 'oth'
# This label 'x' on line 78985 will be classed as 'oth'
# This label 'x' on line 79217 will be classed as 'oth'
# This label 'x' on line 79229 will be classed as 'oth'
# This label 'x' on line 79252 will be classed as 'oth'
# This label 'x' on line 79294 will be classed as 'oth'
# This label 'x' on line 79335 will be classed as 'oth'
# This label 'x' on line 79378 will be classed as 'oth'
# This label 'bark' on line 79389 will be classed as 'oth'
# This label 'x' on line 80076 will be classed as 'oth'
# This label 'x' on line 80100 will be classed as 'oth'
# This label 'syn 01:30:30 x' on line 80172 will be classed as 'oth'
# This label 'x' on line 80391 will be classed as 'oth'
# This label 'x' on line 80452 will be classed as 'oth'
# This label 'x' on line 80566 will be classed as 'oth'
# This label 'x' on line 80569 will be classed as 'oth'
# This label 'x' on line 80693 will be classed as 'oth'
# This label 'ñ' on line 81184 will be classed as 'oth'
# This label 'x' on line 81218 will be classed as 'oth'
# This label 'x' on line 81661 will be classed as 'oth'
# This label 'x' on line 82556 will be classed as 'oth'
# This label 'x' on line 82683 will be classed as 'oth'
# This label 'x' on line 82712 will be classed as 'oth'
# This label 'x' on line 82716 will be classed as 'oth'
# This label 'x' on line 82719 will be classed as 'oth'
# This label 'x' on line 82929 will be classed as 'oth'
# This label 'x' on line 82985 will be classed as 'oth'
# This label 'x' on line 83044 will be classed as 'oth'
# This label 'x' on line 83666 will be classed as 'oth'
# This label 'x' on line 83737 will be classed as 'oth'
# This label 'x' on line 83968 will be classed as 'oth'
# This label 'x' on line 84004 will be classed as 'oth'
# This label 'x' on line 84032 will be classed as 'oth'
# This label 'x' on line 84033 will be classed as 'oth'
# This label 'x' on line 84037 will be classed as 'oth'
# This label 'x' on line 84043 will be classed as 'oth'
# This label 'x' on line 84044 will be classed as 'oth'
# This label 'x' on line 84062 will be classed as 'oth'
# This label 'x' on line 84104 will be classed as 'oth'
# This label 'x' on line 84113 will be classed as 'oth'
# This label 'x' on line 84121 will be classed as 'oth'
# This label 'x' on line 84122 will be classed as 'oth'
# This label 'x' on line 84134 will be classed as 'oth'
# This label 'x' on line 84138 will be classed as 'oth'
# This label 'x' on line 84148 will be classed as 'oth'
# This label '01:57:00' on line 84384 will be classed as 'oth'
# This label 'x' on line 85457 will be classed as 'oth'
# This label 'x' on line 86042 will be classed as 'oth'
# This label 'x' on line 86048 will be classed as 'oth'
# This label 'x' on line 86073 will be classed as 'oth'
# This label 'x' on line 86358 will be classed as 'oth'
# This label 'x' on line 86617 will be classed as 'oth'
# This label 'ññ *' on line 86706 will be classed as 'oth'
# This label 'ññ *' on line 86708 will be classed as 'oth'
# This label 'x' on line 86953 will be classed as 'oth'
# This label 'x' on line 89845 will be classed as 'oth'
# This label 'x' on line 89846 will be classed as 'oth'
# This label 'x' on line 89847 will be classed as 'oth'
# This label 'x' on line 90616 will be classed as 'oth'
# This label 'x' on line 90617 will be classed as 'oth'
# This label 'x' on line 90728 will be classed as 'oth'
# This label 'x' on line 90729 will be classed as 'oth'
# This label 'x' on line 91004 will be classed as 'oth'
# This label 'x' on line 91119 will be classed as 'oth'
# This label 'x' on line 91120 will be classed as 'oth'
# This label 'x' on line 91136 will be classed as 'oth'
# This label 'x' on line 91141 will be classed as 'oth'
# This label 'x' on line 91151 will be classed as 'oth'
# This label 'x' on line 91155 will be classed as 'oth'
# This label 'x' on line 91162 will be classed as 'oth'
# This label 'x' on line 91171 will be classed as 'oth'
# This label 'x' on line 91172 will be classed as 'oth'
# This label 'x' on line 91916 will be classed as 'oth'
# This label 'x' on line 92331 will be classed as 'oth'
# This label 'x' on line 92597 will be classed as 'oth'
# This label 'x' on line 92598 will be classed as 'oth'
# This label 'x' on line 92730 will be classed as 'oth'
# This label 'x' on line 92731 will be classed as 'oth'
# This label 'x' on line 92816 will be classed as 'oth'
# This label 'x' on line 92894 will be classed as 'oth'
# This label 'x' on line 92971 will be classed as 'oth'
# This label 'x' on line 92984 will be classed as 'oth'
# This label 'x' on line 92988 will be classed as 'oth'
# This label 'x' on line 93007 will be classed as 'oth'
# This label 'x' on line 93008 will be classed as 'oth'
# This label 'x' on line 93009 will be classed as 'oth'
# This label 'x' on line 95676 will be classed as 'oth'
# This label 'x' on line 95677 will be classed as 'oth'
# This label 'x' on line 95816 will be classed as 'oth'
# This label 'ak nf' on line 96312 will be classed as 'oth'
# This label 'x' on line 97261 will be classed as 'oth'
# This label 'x' on line 97817 will be classed as 'oth'
# This label 'x' on line 98169 will be classed as 'oth'
# This label 'x' on line 98299 will be classed as 'oth'
# This label 'x' on line 98402 will be classed as 'oth'
# This label 'x' on line 98406 will be classed as 'oth'
# This label 'x' on line 98477 will be classed as 'oth'
# This label 'x' on line 98550 will be classed as 'oth'
# This label 'x' on line 98947 will be classed as 'oth'
# This label 'x' on line 98948 will be classed as 'oth'
# This label 'x' on line 98950 will be classed as 'oth'
# This label 'x' on line 98995 will be classed as 'oth'
# This label 'x' on line 98996 will be classed as 'oth'
# This label 'chuck nf' on line 99988 will be classed as 'oth'
# This label 'chuck nf' on line 99997 will be classed as 'oth'
# This label 'chuck *' on line 100006 will be classed as 'oth'
# This label 'c nf' on line 100137 will be classed as 'oth'
# This label 'x' on line 101217 will be classed as 'oth'
# This label 'v' on line 101338 will be classed as 'oth'
# This label 'x' on line 101433 will be classed as 'oth'
# This label 'x' on line 102304 will be classed as 'oth'
# This label 'x' on line 103150 will be classed as 'oth'
# This label 'x' on line 103160 will be classed as 'oth'
# This label 's% nf' on line 104301 will be classed as 'oth'
# This label 's%' on line 104721 will be classed as 'oth'
# This label 's%' on line 104725 will be classed as 'oth'
# This label 'c nf' on line 104799 will be classed as 'oth'
# This label 's%' on line 104906 will be classed as 'oth'
# This label 'a nf' on line 105189 will be classed as 'oth'
# This label 'x' on line 105668 will be classed as 'oth'
# This label 'a' on line 106014 will be classed as 'oth'
# This label 's%' on line 106157 will be classed as 'oth'
# This label 'x' on line 108465 will be classed as 'oth'
# This label 'x' on line 108522 will be classed as 'oth'
# This label 'x' on line 108547 will be classed as 'oth'
# This label 'sych 01:24:00' on line 108633 will be classed as 'oth'
# This label 'x' on line 108710 will be classed as 'oth'
# This label 'x' on line 108815 will be classed as 'oth'
# This label 'x nf' on line 108820 will be classed as 'oth'
# This label 'sycnh 01:58:30' on line 108975 will be classed as 'oth'
# This label 'x' on line 108978 will be classed as 'oth'
# This label 'x' on line 108979 will be classed as 'oth'
# This label 'x' on line 108980 will be classed as 'oth'
# This label 'x' on line 108981 will be classed as 'oth'
# This label 'x' on line 108982 will be classed as 'oth'
# This label 'x' on line 108983 will be classed as 'oth'
# This label 'x' on line 108984 will be classed as 'oth'
# This label 'x' on line 108985 will be classed as 'oth'
# This label 'x' on line 108986 will be classed as 'oth'
# This label 'x' on line 108987 will be classed as 'oth'
# This label 'x' on line 108988 will be classed as 'oth'
# This label 'x' on line 108990 will be classed as 'oth'
# This label 'x' on line 108992 will be classed as 'oth'
# This label 'x' on line 109165 will be classed as 'oth'
# This label 'x' on line 109240 will be classed as 'oth'
# This label 'x' on line 110168 will be classed as 'oth'
# This label 'x' on line 110169 will be classed as 'oth'
# This label 'x' on line 110189 will be classed as 'oth'
# This label 'x' on line 110213 will be classed as 'oth'
# This label 'x' on line 110243 will be classed as 'oth'
# This label 'x' on line 110244 will be classed as 'oth'
# This label 'x' on line 110245 will be classed as 'oth'
# This label 'chuck' on line 110251 will be classed as 'oth'
# This label 'chuck' on line 110252 will be classed as 'oth'
# This label 'x' on line 110276 will be classed as 'oth'
# This label 'x' on line 110386 will be classed as 'oth'
# This label 'x' on line 110467 will be classed as 'oth'
# This label 'x' on line 110550 will be classed as 'oth'
# This label 'sycnh 01:57:00' on line 110831 will be classed as 'oth'
# This label 'x' on line 110928 will be classed as 'oth'
# This label 'x' on line 110931 will be classed as 'oth'
# This label 'x' on line 110948 will be classed as 'oth'
# This label 'x' on line 110992 will be classed as 'oth'
# This label 'x' on line 111258 will be classed as 'oth'
# This label 'x' on line 111268 will be classed as 'oth'
# This label 'x' on line 111374 will be classed as 'oth'
# This label 'synhc 01:37:30' on line 111422 will be classed as 'oth'
# This label 'x' on line 111628 will be classed as 'oth'
# This label 'x' on line 111629 will be classed as 'oth'
# This label 'x' on line 111630 will be classed as 'oth'
# This label 'x' on line 111631 will be classed as 'oth'
# This label 'x' on line 112105 will be classed as 'oth'
# This label 'x' on line 112156 will be classed as 'oth'
# This label 'x' on line 112173 will be classed as 'oth'
# This label 'x' on line 112174 will be classed as 'oth'
# This label 'x' on line 112180 will be classed as 'oth'
# This label 'x' on line 112216 will be classed as 'oth'
# This label 'x' on line 112217 will be classed as 'oth'
# This label 'x' on line 112278 will be classed as 'oth'
# This label 'x' on line 112290 will be classed as 'oth'
# This label 'x' on line 112300 will be classed as 'oth'
# This label 'x' on line 112500 will be classed as 'oth'
# This label 'x' on line 112507 will be classed as 'oth'
# This label 'x' on line 112508 will be classed as 'oth'
# This label 'x' on line 112509 will be classed as 'oth'
# This label 'x' on line 112510 will be classed as 'oth'
# This label 'x' on line 112511 will be classed as 'oth'
# This label 'x' on line 112512 will be classed as 'oth'
# This label 'x' on line 112513 will be classed as 'oth'
# This label 'x' on line 112514 will be classed as 'oth'
# This label 'x' on line 112515 will be classed as 'oth'
# This label 'x' on line 112516 will be classed as 'oth'
# This label 'x' on line 112517 will be classed as 'oth'
# This label 'x' on line 112518 will be classed as 'oth'
# This label 'x' on line 112519 will be classed as 'oth'
# This label 'x' on line 112520 will be classed as 'oth'
# This label 'x' on line 112558 will be classed as 'oth'
# This label 'x' on line 112559 will be classed as 'oth'
# This label 'x' on line 112560 will be classed as 'oth'
# This label 'x' on line 112569 will be classed as 'oth'
# This label 'x' on line 112578 will be classed as 'oth'

# %%
# estimate the average beep length because many of them are not annotated in the data
avg_beep = round(statistics.mean(label_table.loc[label_table["beep"],"Duration"].loc[label_table.loc[label_table["beep"],"Duration"]>0]),3)
label_table.loc[(label_table["beep"].bool and label_table["Duration"] == 0.) ==True, "Duration"] = avg_beep
label_table.loc[(label_table["beep"].bool and label_table["Duration"] == avg_beep) ==True, "End"] += avg_beep
print(avg_beep)
# Out:
# 0.068

# %%
# add wav and audio paths
label_table["wav_path"] = label_table['wavFileName'].apply(lambda x: [pathi for pathi in audio_filepaths if x in pathi][0])
label_table["label_path"] = label_table['csvFileName'].apply(lambda x: [pathi for pathi in label_filepaths if x in pathi][0])

# %%
# make sure these paths are added to the noise table too
columns_to_keep.append("wav_path")
columns_to_keep.append("label_path")

# create the matching noise table
noise_table = pre.create_noise_table(label_table, call_types, label_for_noise, label_for_startstop, columns_to_keep)#, '\$'])

# remove rows where the annotated noise is smaller than the window size otherwise the spectrogram we generate will inclue a call
noise_table = noise_table.drop(noise_table[noise_table["Duration"] < spec_window_size].index)

# %% [markdown]
# # YEAR and GROUP SENSITIVITY ANALYSIS

# %% [markdown]
# audio_filenames Here we split the training and test set based on files (rather than spectrograms).

# %%
train_pattern = [["HM2017"], ["L2019","HM2019"],["HM2017","HM2019"], ["L2019"]]
# Out:
# 'L2019_HM2019'

# %%
for sensitivity_i in train_pattern:  
    
    
    ### SETUP file structure for sensitivity runs
    #------------------------------------------------------------
    run_name = "NoiseAugmented_"+ str(min_scaling_factor)+"_" +str(max_scaling_factor)+"_NotWeighted_MaskedOther_Forked_trained_with_" + '_'.join(sensitivity_i)

    # basically the root directory for train, test and model
    save_data_path = os.path.join(results_dir, run_name)
    if not os.path.isdir(save_data_path):
        os.makedirs(save_data_path)

    # Test folders
    test_path = os.path.join(save_data_path, 'test_data')
    if not os.path.isdir(test_path):
        os.makedirs(test_path)


    save_pred_test_path = os.path.join(test_path , "predictions")
    if not os.path.isdir(save_pred_test_path):
        os.makedirs(save_pred_test_path)

    save_pred_stack_test_path = os.path.join(save_pred_test_path,"stacks")
    if not os.path.isdir(save_pred_stack_test_path):
        os.makedirs(save_pred_stack_test_path)        

    save_pred_table_test_path = os.path.join(save_pred_test_path,"pred_table")
    if not os.path.isdir(save_pred_table_test_path):
        os.makedirs(save_pred_table_test_path)

    save_label_table_test_path = os.path.join(test_path, 'label_table')
    if not os.path.isdir(save_label_table_test_path):
        os.makedirs(save_label_table_test_path)

    save_metrics_path = os.path.join(test_path , "metrics")
    if not os.path.isdir(save_metrics_path):
        os.makedirs(save_metrics_path)

    save_metrics_path_eval = os.path.join(save_metrics_path, eval_analysis)
    if not os.path.isdir(save_metrics_path_eval):
        os.makedirs(save_metrics_path_eval)


    # Model folder
    save_model_path = os.path.join(save_data_path, 'trained_model')
    if not os.path.isdir(save_model_path):
        os.makedirs(save_model_path)
        
   

    training_files = label_table['wavFileName'][label_table['group'].isin(sensitivity_i)].unique()
    testing_filenames = label_table['wavFileName'][label_table['group'].isin(sensitivity_i) == False].unique()
    
    # Split the training and test set based on the separation
    split_index = floor(len(training_files) * train_val_split )
    training_filenames = training_files[:split_index]
    validation_filenames = training_files[split_index:]


    # save a copy of the training and testing diles
    with open(os.path.join(save_model_path, "training_files_used.txt"), "w") as f:
        for s in training_filenames:
            f.write(str(s) +"\n")
    with open(os.path.join(save_model_path, "testing_files_used.txt"), "w") as f:
        for s in testing_filenames:
            f.write(str(s) +"\n")
    with open(os.path.join(save_model_path, "validation_files_used.txt"), "w") as f:
        for s in validation_filenames:
            f.write(str(s) +"\n")


    '''Then we create a dictionary that will be used in the datagenerator. 
    Each key is a calltype and contains the start/stop/duration/filename where that call occurs. 
    This allows the data generator to shuffle them during the training.
    '''

    # separate out the training and test sets for analysis
    training_label_table = label_table[label_table['wavFileName'].isin(training_filenames)]
    testing_label_table = label_table[label_table['wavFileName'].isin(testing_filenames)]
    validation_label_table = label_table[label_table['wavFileName'].isin(validation_filenames)]

    # do the same for the noise
    training_noise_table = noise_table[noise_table['wavFileName'].isin(training_filenames)]
    testing_noise_table = noise_table[noise_table['wavFileName'].isin(testing_filenames)]
    validation_noise_table = noise_table[noise_table['wavFileName'].isin(validation_filenames)]

    # Compile training data into a format that the data generator can use
    training_label_dict = dict()
    for label in call_types: 
        training_label_dict[label] = training_label_table.loc[training_label_table[label] == True, ["Label", "Start", "Duration","End","wav_path","label_path"]]
    training_label_dict[label_for_noise] = training_noise_table[["Label", "Start", "Duration","End","wav_path","label_path"]]

    # Compile test data into a format that the data generator can use
    testing_label_dict = dict()
    for label in call_types: 
        testing_label_dict[label] = testing_label_table.loc[testing_label_table[label] == True, ["Label", "Start", "Duration","End","wav_path","label_path"]]
    testing_label_dict[label_for_noise] = testing_noise_table[["Label", "Start", "Duration","End","wav_path","label_path"]]

    # Compile validation data into a format that the data generator can use
    validation_label_dict = dict()
    for label in call_types: 
        validation_label_dict[label] = validation_label_table.loc[validation_label_table[label] == True, ["Label", "Start", "Duration","End","wav_path","label_path"]]
    validation_label_dict[label_for_noise] = validation_label_table[["Label", "Start", "Duration","End","wav_path","label_path"]]

    #---------------------------------------------------------------------------------------------
    #---------------------------------------------------------------------------------------------
    # TRAINING
    #---------------------------------------------------------------------------------------------
    #---------------------------------------------------------------------------------------------
    

    ## Build the training and validation data generators (for real this time)
    #---------------------------------------------------------------------------------------------
    


    if is_forked == True:
        # initiate the data generator
        train_generator = bg.ForkedDataGenerator(training_label_dict,
                                                 training_label_table, 
                                                 spec_window_size,
                                                 n_mels, 
                                                 window, 
                                                 fft_win , 
                                                 fft_hop , 
                                                 normalise,
                                                 label_for_noise,
                                                 label_for_other,
                                                 min_scaling_factor,
                                                 max_scaling_factor,
                                                 n_per_call,
                                                 other_ignored_in_training,
                                                 mask_value,
                                                 mask_vector)
        
        # get a batch to estimate rnn parameters
        x_train, y_train = train_generator.__next__()#__getitem__(0)

        # initial parameters
        num_calltypes = y_train[0].shape[2]
        gru_units = y_train[0].shape[1] 


        # initialise the training data generator and validation data generator
        train_generator = bg.ForkedDataGenerator(training_label_dict,
                                                 training_label_table, 
                                                 spec_window_size,
                                                 n_mels, 
                                                 window, 
                                                 fft_win , 
                                                 fft_hop , 
                                                 normalise,
                                                 label_for_noise,
                                                 label_for_other,
                                                 min_scaling_factor,
                                                 max_scaling_factor,
                                                 n_per_call,
                                                 other_ignored_in_training,
                                                 mask_value,
                                                 mask_vector)

        val_generator = bg.ForkedDataGenerator(validation_label_dict,
                                               validation_label_table, 
                                               spec_window_size,
                                               n_mels, 
                                               window, 
                                               fft_win , 
                                               fft_hop , 
                                               normalise,
                                               label_for_noise,
                                               label_for_other,
                                               min_scaling_factor,
                                               max_scaling_factor,
                                               n_per_call,
                                               other_ignored_in_training,
                                               mask_value,
                                               mask_vector)

    else:
        train_generator = bg.DataGenerator(training_label_dict,
                                                 training_label_table, 
                                                 spec_window_size,
                                                 n_mels, 
                                                 window, 
                                                 fft_win , 
                                                 fft_hop , 
                                                 normalise,
                                                 label_for_noise,
                                                 label_for_other,
                                                 min_scaling_factor,
                                                 max_scaling_factor,
                                                 n_per_call,
                                                 other_ignored_in_training,
                                                 mask_value,
                                                 mask_vector)
        x_train, y_train = train_generator.__next__()#__getitem__(0)

        # initial parameters
        num_calltypes = y_train[0].shape[2]
        gru_units = y_train[0].shape[1] 

        train_generator = bg.DataGenerator(training_label_dict,
                                                 training_label_table, 
                                                 spec_window_size,
                                                 n_mels, 
                                                 window, 
                                                 fft_win , 
                                                 fft_hop , 
                                                 normalise,
                                                 label_for_noise,
                                                 label_for_other,
                                                 min_scaling_factor,
                                                 max_scaling_factor,
                                                 n_per_call,
                                                 other_ignored_in_training,
                                                 mask_value,
                                                 mask_vector)

        val_generator = bg.DataGenerator(validation_label_dict,
                                               validation_label_table, 
                                               spec_window_size,
                                               n_mels, 
                                               window, 
                                               fft_win , 
                                               fft_hop , 
                                               normalise,
                                               label_for_noise,
                                               label_for_other,
                                               min_scaling_factor,
                                               max_scaling_factor,
                                               n_per_call,
                                               other_ignored_in_training,
                                               mask_value,
                                               mask_vector)    



    #---------------------------------------------------------------------------------------------
    ## CONSTRUCT THE RNN
    #---------------------------------------------------------------------------------------------

    # initialise the model class
    model = rnn.BuildNetwork(x_train, num_calltypes, filters, gru_units, dense_neurons, dropout, mask_value)

    # build the model
    if is_forked == True:
        RNN_model = model.build_forked_masked_rnn()

        # Multiple target losses
        losses = {
            'output_calltype' : 'categorical_crossentropy',  # classification
            'output_callpresence' : 'mse'  # regression 0-1
        }

        loss_weights = {
            'output_calltype' : 1.0,
            'output_callpresence' : 0.05  # Making this too large is not a good idea as we really want the network paying attention to class
        }
        accuracy_metrics = {
            'output_calltype' : 'categorical_accuracy',
            'output_callpresence' : 'binary_accuracy'
            
        }

    else:
        RNN_model = model.build_masked_rnn()
        # only one target loss
        losses = 'categorical_crossentropy'
        loss_weights = None
        accuracy_metrics = 'categorical_accuracy'

    # Adam optimiser
    adam = optimizers.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

    # Compile the model
    #RNN_model.compile(optimizer=adam, loss=losses, loss_weights=loss_weights, metrics=['binary_accuracy'])
    RNN_model.compile(optimizer=adam, loss=losses, loss_weights=loss_weights, metrics = accuracy_metrics)

    # Setup callbycks: learning rate / loss /tensorboard
    early_stopping = EarlyStopping(monitor='val_loss', patience=40, restore_best_weights=True, verbose=1)
    reduce_lr_plat = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=25, verbose=1,
                                       mode='auto', min_delta=0.0001, cooldown=0, min_lr=0.000001)
    loss = LossHistory()

    # setup a path with a timestamp
    date_time = datetime.datetime.now()
    date_now = str(date_time.date())
    time_now = str(date_time.time())
    save_tensorboard_path = os.path.join(save_model_path, "tensorboard_logs_" + date_now + "_" + time_now)
    if not os.path.isdir(save_tensorboard_path):
        os.makedirs(save_tensorboard_path)   

    # tensorboard
    tensorboard = TensorBoard(log_dir = save_tensorboard_path,
                              histogram_freq=0,
                              write_graph=True,  # Show the network
                              write_grads=True   # Show gradients
                              )  
    # fit model
    RNN_model.fit_generator(train_generator, 
                            steps_per_epoch = train_generator.__len__(),
                            epochs = epochs,
                            callbacks = [early_stopping, reduce_lr_plat, loss, tensorboard],
                            validation_data = val_generator,
                            validation_steps = val_generator.__len__())


    # Look at the model
    # plot_model(RNN_model, run_name + ".png", show_shapes=True)


    #---------------------------------------------------------------------------------------------
    ## SAVE THE MODEL
    #---------------------------------------------------------------------------------------------

    # save the model
    date_time = datetime.datetime.now()
    date_now = str(date_time.date())
    time_now = str(date_time.time())
    sf = os.path.join(save_model_path, run_name+ "_" + date_now + "_" + time_now)
    if not os.path.isdir(sf):
        os.makedirs(sf)

    RNN_model.save(sf + '/savedmodel' + '.h5')

    print(sf)

    test = load_model(sf + '/savedmodel' + '.h5')
    test.summary()
    #test.predict([spec])




    #---------------------------------------------------------------------------------------------
    #---------------------------------------------------------------------------------------------
    ## TESTING
    #---------------------------------------------------------------------------------------------
    #---------------------------------------------------------------------------------------------

    ## Predict over the test files
    #---------------------------------------------------------------------------------------------
    skipped_files = []

    # we only do one file in this example to avoid it running too long
    for file_ID in testing_filenames:
        # file_ID = testing_filenames[0] # for testing purposes only

        # subset the label table to only use that one file
        label_table = testing_label_table[testing_label_table['wavFileName'].isin([file_ID])]
        label_table = label_table.sort_values(by=['Start']).reset_index()
        # Find the file ID name i.e. remove the extention
        file_ID = file_ID.split(".")[0] 
        # find the matching audio for the label data
        audio_path = label_table["wav_path"][0]   

        print("*****************************************************************")   
        print("*****************************************************************") 
        print ("File being processed : " + audio_path)    

        # find the start and stop  of the labelling periods (also using skipon/skipoff)
        loop_table = label_table.loc[label_table["Label"].str.contains('|'.join(label_for_startstop), regex=True, case = False), ["Label","Start"]]
        loop_times = list(loop_table["Start"])

        # Make sure that the file contains the right number of start and stops, otherwise go to the next file
        if len(loop_times)%2 != 0:
            print("!!!!!!!!!!!!!!!!")
            warnings.warn("There is a missing start or stop in this file and it has been skipped: " + audio_path)
            skipped_files.append(file_ID)
            continue 

        if len(loop_times) == 0:
            print("!!!!!!!!!!!!!!!!")
            warnings.warn("There is a missing start or stop in this file and it has been skipped: " + audio_path)
            skipped_files.append(file_ID)
            continue 

        # save the label_table
        save_label_table_filename = file_ID + "_LABEL_TABLE.txt"
        label_table.to_csv(os.path.join(save_label_table_test_path, save_label_table_filename), 
                            header=True, index=None, sep=';')

        # load the audio data
        y, sr = librosa.load(audio_path, sr=None, mono=False)

        # # Reshaping the Audio file (mono) to deal with all wav files similarly
        # if y.ndim == 1:
        #     y = y.reshape(1, -1)

        # # Implement this for acc data
        # for ch in range(y.shape[0]):
        # ch=0
        # y_sub = y[:,ch]
        y_sub = y

        # loop through every labelling start based on skipon/off within this loop_table
        for loopi in range(0, int(len(loop_times)), 2):
            # loopi = 0
            fromi =  loop_times[loopi]
            #toi = fromi + 5
            toi = loop_times[int(loopi + 1)] # define the end of the labelling periods

            calltype_pred_list = []
            callpresence_pred_list = []
            # if the file exists, load it
            if os.path.exists(os.path.join(save_pred_stack_test_path, file_ID + '_CALLTYPE_PRED_STACK_' + str(fromi) + '-' + str(toi) + '.npy')): 
                calltype_pred_list = np.load( os.path.join(save_pred_stack_test_path, file_ID + '_CALLTYPE_PRED_STACK_' + str(fromi) + '-' + str(toi) + '.npy')) 
                callpresence_pred_list = np.load( os.path.join(save_pred_stack_test_path, file_ID + '_CALLPRESENCE_PRED_STACK_' + str(fromi) + '-' + str(toi) + '.npy'))


            # if the file is incomplete or non existant redo it
            if (len(np.arange(fromi, toi, slide)) - sum(np.arange(fromi, toi, slide)+spec_window_size > toi)) != (len(calltype_pred_list)):

                for spectro_slide in np.arange(fromi, toi, slide):                
                    # spectro_slide = fromi
                    start = round(spectro_slide,3)
                    stop = round(spectro_slide + spec_window_size, 3)

                    # ignore cases where the window is larger than what is labelled (e.g. at the end)
                    if stop <= toi:

                        #generate the spectrogram
                        spectro = pre.generate_mel_spectrogram(y=y_sub, sr=sr, start=start, stop=stop, 
                                                                n_mels = n_mels, window='hann', 
                                                                fft_win= fft_win, fft_hop = fft_hop, 
                                                                normalise = True)

                        # transpose it and put it in a format that works with the NN
                        spec = spectro.T
                        spec = spec[np.newaxis, ..., np.newaxis]  

                        # generate a mask (as a placeholder) but don't mask anything as we are predicting and want to include other
                        mask = np.asarray([True for i in range(spectro.shape[1])])
                        mask = mask[np.newaxis,...]

                        # generate the prediction
                        pred = RNN_model.predict([spec,mask])

                        # add this prediction to the stack that will be used to generate the predictions table
                        if is_forked:
                            calltype_pred_list.append(np.squeeze(pred[0]))
                            callpresence_pred_list.append(np.squeeze(pred[1]))
                        else:
                            calltype_pred_list.append(np.squeeze(pred))

                # save the prediction stacks
                np.save( os.path.join(save_pred_stack_test_path, file_ID + '_CALLTYPE_PRED_STACK_' + str(fromi) + '-' + str(toi) + '.npy'), calltype_pred_list)
                with open(os.path.join(save_pred_stack_test_path, file_ID + '_CALLTYPE_PRED_STACK_' + str(fromi) + '-' + str(toi) + '.txt'), "w") as f:
                    for row in calltype_pred_list:
                        f.write(str(row) +"\n")
                if is_forked:      
                    np.save( os.path.join(save_pred_stack_test_path, file_ID + '_CALLPRESENCE_PRED_STACK_' + str(fromi) + '-' + str(toi) + '.npy'), callpresence_pred_list)
                    with open(os.path.join(save_pred_stack_test_path, file_ID + '_CALLPRESENCE_PRED_STACK_' + str(fromi) + '-' + str(toi) + '.txt'), "w") as f:
                        for row in callpresence_pred_list:
                            f.write(str(row) +"\n")

            # Loop through different sets of thresholds
            for low_thr in [0.05,0.1,0.2]:
                for high_thr in [0.5,0.6,0.7,0.8,0.9,0.95]: 

                    # make sure it doesnt generate a 0.00098982374957839486 type number
                    low_thr = round(low_thr,2)                               
                    high_thr = round(high_thr,2)

                    # stop the loop if the low threshold is bigger than the high threshold
                    if low_thr >= high_thr:
                        continue

                    save_pred_table_filename = file_ID + "_CALLTYPE_PRED_TABLE_thr_" + str(low_thr) + "-" + str(high_thr) + ".txt"

                    # if the file exists, pass to the next iteration of the loop
                    #if os.path.exists(os.path.join(save_pred_table_test_path, save_pred_table_filename)):
                    #    continue

                    print("*****************************************************************") 
                    print ("Low Threshold: " + str(low_thr))    
                    print ("High Threshold: " + str(high_thr))  

                    #----------------------------------------------------------------------------
                    # Compile the predictions for each on/off labelling chunk
                    detections = ppm.merge_p(probabilities = calltype_pred_list, 
                                              labels=list(call_types.keys()),
                                              starttime = 0, 
                                              frameadv_s = fft_hop, 
                                              specadv_s = slide,
                                              low_thr=low_thr, 
                                              high_thr=high_thr, 
                                              debug=1)

                    #in case the dataset was just noise, still create an empty placeholder to merge
                    if len(detections) == 0:  
                        detections = pd.DataFrame(columns = ['category', 'start', 'end', 'scores'])

                    # create an empty dataset
                    pred_table = pd.DataFrame() 

                    #convert these detections to a predictions table                
                    table = pd.DataFrame(detections)
                    table["Label"] = table["category"]
                    table["Start"] = round(table["start"]*fft_hop + fromi, 3) #table["start"].apply(Decimal)*Decimal(fft_hop) + Decimal(fromi)
                    table["Duration"] = round( (table["end"]-table["start"])*fft_hop, 3) #(table["end"].apply(Decimal)-table["start"].apply(Decimal))*Decimal(fft_hop)
                    table["End"] = round(table["end"]*fft_hop + fromi, 3) #table["Start"].apply(Decimal) + table["Duration"].apply(Decimal)

                    # keep only the useful columns    
                    table = table[["Label","Start","Duration", "End", "scores"]]  

                    # Add a row which stores the start of the labelling period
                    row_start = pd.DataFrame()
                    row_start.loc[0,'Label'] = list(loop_table["Label"])[loopi]
                    row_start.loc[0,'Start'] = fromi
                    row_start.loc[0,'Duration'] = 0
                    row_start.loc[0,'End'] = fromi 
                    row_start.loc[0,'scores'] = [0] 

                    # Add a row which stores the end of the labelling period
                    row_stop = pd.DataFrame()
                    row_stop.loc[0,'Label'] = list(loop_table["Label"])[int(loopi + 1)]
                    row_stop.loc[0,'Start'] = toi
                    row_stop.loc[0,'Duration'] = 0
                    row_stop.loc[0,'End'] = toi 
                    row_stop.loc[0,'scores'] = [0]       

                    # add the true false columns based on the call types dictionary
                    for true_label in call_types:
                        table[true_label] = False
                        row_start[true_label] = False
                        row_stop[true_label] = False
                        for old_label in call_types[true_label]:
                            table.loc[table["Label"].str.contains(old_label, regex=True, case = False), true_label] = True

                    # make sure start and stop are not classified as calls
                    row_start[label_for_noise] = True
                    row_stop[label_for_noise] = True

                    # put these rows to the label table
                    table = pd.concat([row_start, table, row_stop]) 

                    # add this table to the overall predictions table for that collar
                    pred_table = pd.concat([pred_table, table ])

                    # for each on/off labelling chunk, we can save the prediction and append it to the previous chunk
                    if loopi == 0:                    
                        # for the first chunck keep the header, but not when appending later. Also, overwrite old runs
                        pred_table.to_csv(os.path.join(save_pred_table_test_path, save_pred_table_filename), 
                                          header=True, index=None, sep=';', mode = 'w')
                    else:
                        pred_table.to_csv(os.path.join(save_pred_table_test_path, save_pred_table_filename), 
                                          header=None, index=None, sep=';', mode = 'a')

    '''
    # # load the saved file
    # with open(os.path.join(save_pred_stack_test_path, file_ID + '_PRED_STACK.txt')) as f:
    #     content = f.readlines()
    # # remove whitespace characters like `\n` at the end of each line
    # pred_list = [x.strip() for x in content] 


    # #or
    # pred_list = np.load( os.path.join(save_pred_stack_test_path, file_ID + '_PRED_STACK.npy'))
    # '''

    # save the files that were skipped
    print(skipped_files)

    # save a copy of the training and testing diles
    with open(os.path.join(save_model_path, "skipped_testing_files.txt"), "w") as f:
        for s in skipped_files:
            f.write(str(s) +"\n")


    #---------------------------------------------------------------------------------------------
    #---------------------------------------------------------------------------------------------
    ## TESTING
    #---------------------------------------------------------------------------------------------
    #---------------------------------------------------------------------------------------------

    # because of new file format, need to only keep certain columns so that the evaluation metrics work with the label tables
    column_names = ["Label","Start","Duration","End"]
    column_names.extend(list(testing_label_dict.keys()))
    for file in label_list :
        df = pd.read_csv(file, delimiter=';') 
        # df = df.drop_duplicates(keep=False)
        df = df[column_names]
        df.to_csv(file, header=True, index=None, sep=';', mode = 'w')


    eval_analysis = "call_type_by_call_type"
    save_metrics_path_eval = os.path.join(save_metrics_path, eval_analysis)

    file_ID_list = [file_ID.split(".")[0] for file_ID in testing_filenames if file_ID not in skipped_files]
    label_list =  [os.path.join(save_label_table_test_path,file_ID.split(".")[0]  + "_LABEL_TABLE.txt" ) for file_ID in file_ID_list]


    for low_thr in [0.05,0.1,0.2]:
        for high_thr in [0.5,0.6,0.7,0.8,0.9,0.95]: 

            low_thr = round(low_thr,2)                               
            high_thr = round(high_thr,2) 
            print("**********************************************************")
            print("Evaluating thresholds: " + str(low_thr) + "-" + str(high_thr))
            print("**********************************************************")

            if low_thr >= high_thr:
                continue

            pred_list = [os.path.join(save_pred_table_test_path,file_ID.split(".")[0]  + "_CALLTYPE_PRED_TABLE_thr_" + str(low_thr) + "-" + str(high_thr) + ".txt" ) for file_ID in file_ID_list ]
            evaluation = metrics.Evaluate(label_list = label_list, 
                                          prediction_list = pred_list, 
                                          noise_label = "noise", 
                                          IoU_threshold = 0.2, 
                                          call_analysis = eval_analysis, 
                                          GT_proportion_cut = 0.01, 
                                          no_call = no_call,
                                          headers = set(['Label', 'Duration', 'Start', 'End']),
                                          nonfoc_tags =["NONFOC", "nf", "*"]
                                         ) # 0.99 is 0.5
            output, skipped_calls = evaluation.main()        
            print(str(skipped_calls) + " calls were skipped in total")

            to_pickle = ["Time_Difference", "Matching_Table", "Prediction_Indices", "Label_Indices" , "_Match"]
            for metric in output.keys():
                if any(ext in metric for ext in to_pickle):
                    filename = "PRED_TABLE_thr_" + str(low_thr) + "-" + str(high_thr) + "_" +str(metric) +".p"
                    with open(os.path.join(save_metrics_path_eval, filename), 'wb') as fp:
                        pickle.dump(output[metric], fp) 
                else:
                    filename = "PRED_TABLE_thr_" + str(low_thr) + "-" + str(high_thr) + "_" +str(metric) +".csv"
                    output[metric].to_csv(os.path.join(save_metrics_path_eval, filename))    


    #--------------------------------------------------------------------------------------------
    # PLOT A PREDICTION
    #--------------------------------------------------------------------------------------------


    pool = audiopool.AudioPool() 

    # Find a call
    call = testing_label_dict["sn"].iloc[15]
    label_subset = testing_label_table[testing_label_table['wav_path'].isin([call["wav_path"]])]

    # set the labels
    label_list = list(call_types.keys())
    if other_ignored_in_training:
        label_list.remove(label_for_other)


    # randomise the start a little so the new spectrogram will be a little different from the old
    # if the call is very long have a large range to draw the window
    if call["Duration"]>= spec_window_size:
        call_start = round(float(np.random.uniform(call["Start"]-spec_window_size/2, 
                                                   call["End"]-spec_window_size/2, 1)), 3)
    # if the call is short call, draw it from somewhere
    else:
        call_start = round(float(np.random.uniform((call["Start"]+call["End"])/2-spec_window_size, 
                                                   (call["Start"]+call["End"])/2)), 3)

    # load in a subsection of the spectrogram
    # y, sr = librosa.load(call["wav_path"], sr=None, mono=False,
    #                      offset = call_start, duration =self.spec_window_size)
    y = pool.get_seconds(call["wav_path"], call_start, spec_window_size)
    sr = pool.get_Fs(call["wav_path"])

    call_stop = round(call_start + spec_window_size,3 )

    # have it as an array
    data_subset = np.asfortranarray(y)

    #get the spectrogram
    spectrogram = pre.generate_mel_spectrogram(data_subset, sr, 0, spec_window_size, 
                                               n_mels, window, fft_win , fft_hop , normalise)

    # generate label
    label = pre.create_label_matrix(label_subset, 
                                    spectrogram, 
                                    testing_label_dict, 
                                    call_start, 
                                    call_stop, 
                                    label_for_noise, 
                                    label_for_other, 
                                    other_ignored_in_training)
    # plot spectrogram
    plt.figure(figsize=(10,4))
    #plt.subplot(411)
    yaxis = range(0, np.flipud(spectrogram).shape[0]+1)
    xaxis = range(0, np.flipud(spectrogram).shape[1]+1)
    plt.xticks(np.arange(0, np.flipud(label).shape[1]+1,50),
               list(label.columns[np.arange(0, np.flipud(label).shape[1]+1,50)]))
    librosa.display.specshow(spectrogram,  y_axis='mel', x_coords = label.columns)#, x_axis= "time",sr=sr, x_coords = label.columns)
    plt.ylabel('Frequency (Hz)')
    plt.clim(-35, 35)
    plt.colorbar(format='%+2.0f dB')
    plt.show()

    # plot LABEL
    #plt.subplot(412)
    #print(label.shape)
    plt.figure(figsize=(10, 4))
    xaxis = range(0, np.flipud(label).shape[1]+1)
    yaxis = range(0, np.flipud(label).shape[0]+1)
    plt.yticks(np.arange(0.5, len(label_list)+0.5 ,1 ),reversed(label_list))
    plt.xticks(np.arange(0, np.flipud(label).shape[1]+1,50),
               list(label.columns[np.arange(0, np.flipud(label).shape[1]+1,50)]))
    plt.pcolormesh(xaxis, yaxis, np.flipud(label))
    plt.clim(0, 1)
    plt.xlabel('Time (s)')
    plt.ylabel('Calltype')
    plt.colorbar(label="Label")
    plt.show()

    if is_forked:
        # generate matrix of call/not call
        callmat = pre.create_call_matrix(label_subset, spectrogram, call_start, call_stop, 
                                          label_for_noise, label_for_other, other_ignored_in_training)

    # prediction
    # transpose it and put it in a format that works with the NN
    spec = spectrogram.T
    spec = spec[np.newaxis, ..., np.newaxis]  

    # generate a mask (as a placeholder) but don't mask anything as we are predicting and want to include other
    mask = np.asarray([True for i in range(spectrogram.shape[1])])
    mask = mask[np.newaxis,...]

    # generate the prediction
    pred = RNN_model.predict([spec,mask])

    # add this prediction to the stack that will be used to generate the predictions table
    if is_forked:
        calltype_pred= pred[0]
        callpresence_pred = pred[1]   
    else:
        calltype_pred = pred

    pred = calltype_pred[0].T

    #print(pred.shape)
    #plot calltype prediction
    plt.figure(figsize=(10, 4))
    xaxis = range(0, np.flipud(label).shape[1]+1)
    yaxis = range(0, np.flipud(label).shape[0]+1)
    plt.yticks(np.arange(0.5, len(label_list)+0.5 ,1 ),reversed(label_list))
    plt.xticks(np.arange(0, np.flipud(label).shape[1]+1,50),
               list(label.columns[np.arange(0, np.flipud(label).shape[1]+1,50)]))
    plt.pcolormesh(xaxis, yaxis, np.flipud(pred))
    plt.clim(0, 1)
    plt.xlabel('Time (s)')
    plt.ylabel('Calltype Prediction')
    plt.colorbar(label="Label")
    plt.show()


    if is_forked:  
        # plot call matrix
        #plt.subplot(413)
        plt.figure(figsize=(10, 1))
        xaxis = range(0, np.flipud(label).shape[1]+1)
        yaxis = range(0, np.flipud(callmat).shape[0]+1)
        plt.yticks(np.arange(0.5, callmat.shape[0]+0.5 ,1 ), reversed(callmat.index.values))
        plt.xticks(np.arange(0, np.flipud(label).shape[1]+1,50),
                   list(label.columns[np.arange(0, np.flipud(label).shape[1]+1,50)]))
        plt.pcolormesh(xaxis, yaxis, np.flipud(callmat))
        plt.clim(0, 1)
        plt.xlabel('Time (s)')
        plt.ylabel('Call / No Call')
        plt.colorbar(label="Label")
        plt.show()

        pred = callpresence_pred[0].T
        #plot prediction
        plt.figure(figsize=(10, 1))
        xaxis = range(0, np.flipud(label).shape[1]+1)
        yaxis = range(0, np.flipud(callmat).shape[0]+1)
        plt.yticks(np.arange(0.5, callmat.shape[0]+0.5 ,1 ), reversed(callmat.index.values))
        plt.xticks(np.arange(0, np.flipud(label).shape[1]+1,50),
                   list(label.columns[np.arange(0, np.flipud(label).shape[1]+1,50)]))
        plt.pcolormesh(xaxis, yaxis, np.flipud(pred))
        plt.clim(0, 1)
        plt.xlabel('Time (s)')
        plt.ylabel('Call / No Call prediction')
        plt.colorbar(label="Label")
        plt.show()

    #--------------------------------------------------------------------------------------------
    # CONFUSION MATRIX
    #--------------------------------------------------------------------------------------------

    # loop over the threaholdsf
    for low_thr in [0.1]:#[0.05,0.1,0.2]:
        for high_thr in [0.6]:#[0.5,0.6,0.7,0.8,0.9,0.95]:         
            #########################################
            # FORMAT 

            low_thr = round(low_thr,2)                               
            high_thr = round(high_thr,2) 

            if low_thr >= high_thr:
                continue
            if low_thr == 0.1 and high_thr == 0.2:
                continue

            if eval_analysis == "normal":
                confusion_filename = os.path.join(save_metrics_path_eval, "PRED_TABLE_thr_" + str(low_thr) + "-" + str(high_thr) + '_foc_Confusion_Matrix.csv')
            else:
                confusion_filename = os.path.join(save_metrics_path_eval, "PRED_TABLE_thr_" + str(low_thr) + "-" + str(high_thr) + '__Confusion_Matrix.csv')
            with open(confusion_filename, newline='') as csvfile:
                array = list(csv.reader(csvfile))

            df_cm = pd.DataFrame(array) #, range(6), range(6))    

            # get rid of the weird indentations and make rows and columns as names
            new_col = df_cm.iloc[0] # grab the first row for the header
            df_cm = df_cm[1:] # take the data less the header row
            df_cm.columns = new_col # set the header row as the df header    
            new_row = df_cm['']
            df_cm = df_cm.drop('', 1)
            df_cm.index = new_row
            df_cm.index.name= None
            df_cm.columns.name= None

            # # replace FP and FN with noise
            df_cm['noise'] = df_cm['FN'] 
            #df_cm.loc['noise']=df_cm.loc['FP']

            # remove FP and FN
            df_cm = df_cm.drop("FN", axis=1)
            #df_cm = df_cm.drop("FP", axis=0)

            df_cm = df_cm.apply(pd.to_numeric)

            # Raw confusion matrix
            df_cm = df_cm[list(testing_label_dict.keys())]
            df_cm = df_cm.reindex(list(testing_label_dict.keys()))       

            #########################################
            # CALCULATE

            # Recall confusion matrix
            df_recall = df_cm.div(df_cm.sum(axis=1), axis=0).round(2)#pd.DataFrame(df_cm.values / df_cm.sum(axis=1).values).round(2)

            # Proportion of calls for confusion matrix
            call_len = list()
            for i in testing_label_dict.keys():
                call_len.append(testing_label_dict[i].shape[0])
            # add noise at the end
            call_len[-1] = df_cm.sum(axis=1)[-1]

            #proportion of calls
            df_prop = df_cm.div(call_len, axis=0).round(2)#pd.DataFrame(df_cm.values / df_cm.sum(axis=1).values).round(2)

            #########################################
            # PLOT

            #multi figure parameters
            fig,((ax1,ax2,ax3)) = plt.subplots(1,3, figsize=(20,5))
            fig.suptitle(str(low_thr) + " - " + str(high_thr))

            # plot raw
            sn.set(font_scale=1.1) # for label size
            sn.heatmap((df_cm+1), annot=df_cm, fmt='g',norm = LogNorm(), annot_kws={"size": 10}, ax= ax1) # font size
            ax1.set_title("Raw")              

            # plot recall
            sn.set(font_scale=1.1) # for label size
            sn.heatmap((df_recall), annot=True, fmt='g', annot_kws={"size": 10}, ax= ax2) # font size
            ax2.set_title("Recall" )

            # plot proportion of calls
            sn.set(font_scale=1.1) # for label size
            sn.heatmap((df_prop), annot=True, fmt='g', annot_kws={"size": 10}, ax= ax3) # font size
            ax3.set_title("Call Prop")

            # Save 3 panels
            plt.savefig(os.path.join(save_metrics_path, eval_analysis, "Confusion_mat_thr_" + str(low_thr) + "-" + str(high_thr) + '.png'))
            plt.show()
            plt.clf()
# Out:
# WARNING:tensorflow:From /home/kiran/anaconda3/envs/ML1_env/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/kiran/anaconda3/envs/ML1_env/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/kiran/anaconda3/envs/ML1_env/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/kiran/anaconda3/envs/ML1_env/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /home/kiran/anaconda3/envs/ML1_env/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /home/kiran/anaconda3/envs/ML1_env/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/kiran/anaconda3/envs/ML1_env/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:2974: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/kiran/anaconda3/envs/ML1_env/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /home/kiran/anaconda3/envs/ML1_env/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /home/kiran/anaconda3/envs/ML1_env/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /home/kiran/anaconda3/envs/ML1_env/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /home/kiran/anaconda3/envs/ML1_env/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /home/kiran/anaconda3/envs/ML1_env/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /home/kiran/anaconda3/envs/ML1_env/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /home/kiran/anaconda3/envs/ML1_env/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /home/kiran/anaconda3/envs/ML1_env/lib/python3.7/site-packages/keras/callbacks.py:850: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /home/kiran/anaconda3/envs/ML1_env/lib/python3.7/site-packages/keras/callbacks.py:853: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/200
# 40/40 [==============================] - 87s 2s/step - loss: 1.6802 - output_calltype_loss: 1.6693 - output_callpresence_loss: 0.2183 - output_calltype_binary_accuracy: 0.8416 - output_callpresence_binary_accuracy: 0.7167 - val_loss: 1.4402 - val_output_calltype_loss: 1.4303 - val_output_callpresence_loss: 0.1988 - val_output_calltype_binary_accuracy: 0.9452 - val_output_callpresence_binary_accuracy: 0.7338
# WARNING:tensorflow:From /home/kiran/anaconda3/envs/ML1_env/lib/python3.7/site-packages/keras/callbacks.py:995: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# Epoch 2/200
# 40/40 [==============================] - 67s 2s/step - loss: 1.2173 - output_calltype_loss: 1.2068 - output_callpresence_loss: 0.2084 - output_calltype_binary_accuracy: 0.9443 - output_callpresence_binary_accuracy: 0.7208 - val_loss: 1.1759 - val_output_calltype_loss: 1.1658 - val_output_callpresence_loss: 0.2024 - val_output_calltype_binary_accuracy: 0.9426 - val_output_callpresence_binary_accuracy: 0.7205
# Epoch 3/200
# 40/40 [==============================] - 69s 2s/step - loss: 1.1974 - output_calltype_loss: 1.1871 - output_callpresence_loss: 0.2064 - output_calltype_binary_accuracy: 0.9440 - output_callpresence_binary_accuracy: 0.7228 - val_loss: 1.1619 - val_output_calltype_loss: 1.1518 - val_output_callpresence_loss: 0.2022 - val_output_calltype_binary_accuracy: 0.9419 - val_output_callpresence_binary_accuracy: 0.7156
# Epoch 4/200
# 40/40 [==============================] - 64s 2s/step - loss: 1.1632 - output_calltype_loss: 1.1532 - output_callpresence_loss: 0.1992 - output_calltype_binary_accuracy: 0.9466 - output_callpresence_binary_accuracy: 0.7364 - val_loss: 1.1556 - val_output_calltype_loss: 1.1457 - val_output_callpresence_loss: 0.1979 - val_output_calltype_binary_accuracy: 0.9431 - val_output_callpresence_binary_accuracy: 0.7222
# Epoch 5/200
# 40/40 [==============================] - 59s 1s/step - loss: 1.1700 - output_calltype_loss: 1.1600 - output_callpresence_loss: 0.2014 - output_calltype_binary_accuracy: 0.9453 - output_callpresence_binary_accuracy: 0.7293 - val_loss: 1.1725 - val_output_calltype_loss: 1.1625 - val_output_callpresence_loss: 0.2010 - val_output_calltype_binary_accuracy: 0.9420 - val_output_callpresence_binary_accuracy: 0.7197
# Epoch 6/200
# 40/40 [==============================] - 59s 1s/step - loss: 1.1692 - output_calltype_loss: 1.1591 - output_callpresence_loss: 0.2019 - output_calltype_binary_accuracy: 0.9443 - output_callpresence_binary_accuracy: 0.7253 - val_loss: 1.0851 - val_output_calltype_loss: 1.0756 - val_output_callpresence_loss: 0.1908 - val_output_calltype_binary_accuracy: 0.9434 - val_output_callpresence_binary_accuracy: 0.7223
# Epoch 7/200
# 40/40 [==============================] - 59s 1s/step - loss: 1.1296 - output_calltype_loss: 1.1199 - output_callpresence_loss: 0.1932 - output_calltype_binary_accuracy: 0.9467 - output_callpresence_binary_accuracy: 0.7366 - val_loss: 1.0091 - val_output_calltype_loss: 1.0007 - val_output_callpresence_loss: 0.1670 - val_output_calltype_binary_accuracy: 0.9428 - val_output_callpresence_binary_accuracy: 0.7222
# Epoch 8/200
# 40/40 [==============================] - 58s 1s/step - loss: 1.1074 - output_calltype_loss: 1.0980 - output_callpresence_loss: 0.1873 - output_calltype_binary_accuracy: 0.9450 - output_callpresence_binary_accuracy: 0.7286 - val_loss: 1.0661 - val_output_calltype_loss: 1.0585 - val_output_callpresence_loss: 0.1523 - val_output_calltype_binary_accuracy: 0.9443 - val_output_callpresence_binary_accuracy: 0.7653
# Epoch 9/200
# 40/40 [==============================] - 58s 1s/step - loss: 1.0459 - output_calltype_loss: 1.0376 - output_callpresence_loss: 0.1664 - output_calltype_binary_accuracy: 0.9466 - output_callpresence_binary_accuracy: 0.7557 - val_loss: 1.0654 - val_output_calltype_loss: 1.0577 - val_output_callpresence_loss: 0.1533 - val_output_calltype_binary_accuracy: 0.9443 - val_output_callpresence_binary_accuracy: 0.8105
# Epoch 10/200
# 40/40 [==============================] - 59s 1s/step - loss: 1.0163 - output_calltype_loss: 1.0087 - output_callpresence_loss: 0.1510 - output_calltype_binary_accuracy: 0.9464 - output_callpresence_binary_accuracy: 0.8052 - val_loss: 1.0237 - val_output_calltype_loss: 1.0163 - val_output_callpresence_loss: 0.1488 - val_output_calltype_binary_accuracy: 0.9300 - val_output_callpresence_binary_accuracy: 0.8128
# Epoch 11/200
# 40/40 [==============================] - 58s 1s/step - loss: 1.0095 - output_calltype_loss: 1.0023 - output_callpresence_loss: 0.1430 - output_calltype_binary_accuracy: 0.9444 - output_callpresence_binary_accuracy: 0.8209 - val_loss: 1.0458 - val_output_calltype_loss: 1.0377 - val_output_callpresence_loss: 0.1633 - val_output_calltype_binary_accuracy: 0.8945 - val_output_callpresence_binary_accuracy: 0.7907
# Epoch 12/200
# 40/40 [==============================] - 58s 1s/step - loss: 0.9711 - output_calltype_loss: 0.9643 - output_callpresence_loss: 0.1355 - output_calltype_binary_accuracy: 0.9431 - output_callpresence_binary_accuracy: 0.8292 - val_loss: 1.0267 - val_output_calltype_loss: 1.0189 - val_output_callpresence_loss: 0.1560 - val_output_calltype_binary_accuracy: 0.8752 - val_output_callpresence_binary_accuracy: 0.8019
# Epoch 13/200
# 40/40 [==============================] - 56s 1s/step - loss: 0.9795 - output_calltype_loss: 0.9728 - output_callpresence_loss: 0.1336 - output_calltype_binary_accuracy: 0.9308 - output_callpresence_binary_accuracy: 0.8306 - val_loss: 1.0686 - val_output_calltype_loss: 1.0604 - val_output_callpresence_loss: 0.1639 - val_output_calltype_binary_accuracy: 0.8748 - val_output_callpresence_binary_accuracy: 0.7886
# Epoch 14/200
# 40/40 [==============================] - 58s 1s/step - loss: 0.9545 - output_calltype_loss: 0.9478 - output_callpresence_loss: 0.1334 - output_calltype_binary_accuracy: 0.9288 - output_callpresence_binary_accuracy: 0.8279 - val_loss: 1.0161 - val_output_calltype_loss: 1.0084 - val_output_callpresence_loss: 0.1528 - val_output_calltype_binary_accuracy: 0.8898 - val_output_callpresence_binary_accuracy: 0.7997
# Epoch 15/200
# 40/40 [==============================] - 57s 1s/step - loss: 0.9211 - output_calltype_loss: 0.9146 - output_callpresence_loss: 0.1297 - output_calltype_binary_accuracy: 0.9319 - output_callpresence_binary_accuracy: 0.8340 - val_loss: 1.0158 - val_output_calltype_loss: 1.0084 - val_output_callpresence_loss: 0.1493 - val_output_calltype_binary_accuracy: 0.8986 - val_output_callpresence_binary_accuracy: 0.8021
# Epoch 16/200
# 40/40 [==============================] - 58s 1s/step - loss: 0.9368 - output_calltype_loss: 0.9306 - output_callpresence_loss: 0.1252 - output_calltype_binary_accuracy: 0.9292 - output_callpresence_binary_accuracy: 0.8383 - val_loss: 0.9694 - val_output_calltype_loss: 0.9621 - val_output_callpresence_loss: 0.1458 - val_output_calltype_binary_accuracy: 0.8994 - val_output_callpresence_binary_accuracy: 0.7990
# Epoch 17/200
# 40/40 [==============================] - 57s 1s/step - loss: 0.9085 - output_calltype_loss: 0.9021 - output_callpresence_loss: 0.1289 - output_calltype_binary_accuracy: 0.9321 - output_callpresence_binary_accuracy: 0.8309 - val_loss: 0.9690 - val_output_calltype_loss: 0.9617 - val_output_callpresence_loss: 0.1457 - val_output_calltype_binary_accuracy: 0.8938 - val_output_callpresence_binary_accuracy: 0.7973
# Epoch 18/200
# 40/40 [==============================] - 57s 1s/step - loss: 0.8759 - output_calltype_loss: 0.8697 - output_callpresence_loss: 0.1225 - output_calltype_binary_accuracy: 0.9324 - output_callpresence_binary_accuracy: 0.8381 - val_loss: 1.0576 - val_output_calltype_loss: 1.0494 - val_output_callpresence_loss: 0.1632 - val_output_calltype_binary_accuracy: 0.8821 - val_output_callpresence_binary_accuracy: 0.7747
# Epoch 19/200
# 40/40 [==============================] - 57s 1s/step - loss: 0.8475 - output_calltype_loss: 0.8416 - output_callpresence_loss: 0.1192 - output_calltype_binary_accuracy: 0.9345 - output_callpresence_binary_accuracy: 0.8394 - val_loss: 1.0019 - val_output_calltype_loss: 0.9946 - val_output_callpresence_loss: 0.1443 - val_output_calltype_binary_accuracy: 0.9002 - val_output_callpresence_binary_accuracy: 0.7944
# Epoch 20/200
# 40/40 [==============================] - 57s 1s/step - loss: 0.8672 - output_calltype_loss: 0.8610 - output_callpresence_loss: 0.1224 - output_calltype_binary_accuracy: 0.9328 - output_callpresence_binary_accuracy: 0.8365 - val_loss: 0.9860 - val_output_calltype_loss: 0.9786 - val_output_callpresence_loss: 0.1463 - val_output_calltype_binary_accuracy: 0.9007 - val_output_callpresence_binary_accuracy: 0.7947
# Epoch 21/200
# 40/40 [==============================] - 56s 1s/step - loss: 0.8236 - output_calltype_loss: 0.8176 - output_callpresence_loss: 0.1206 - output_calltype_binary_accuracy: 0.9366 - output_callpresence_binary_accuracy: 0.8374 - val_loss: 0.9988 - val_output_calltype_loss: 0.9914 - val_output_callpresence_loss: 0.1471 - val_output_calltype_binary_accuracy: 0.8958 - val_output_callpresence_binary_accuracy: 0.7983
# Epoch 22/200
# 40/40 [==============================] - 58s 1s/step - loss: 0.8033 - output_calltype_loss: 0.7974 - output_callpresence_loss: 0.1174 - output_calltype_binary_accuracy: 0.9348 - output_callpresence_binary_accuracy: 0.8406 - val_loss: 1.0367 - val_output_calltype_loss: 1.0283 - val_output_callpresence_loss: 0.1673 - val_output_calltype_binary_accuracy: 0.8910 - val_output_callpresence_binary_accuracy: 0.7626
# Epoch 23/200
# 40/40 [==============================] - 57s 1s/step - loss: 0.8278 - output_calltype_loss: 0.8218 - output_callpresence_loss: 0.1191 - output_calltype_binary_accuracy: 0.9329 - output_callpresence_binary_accuracy: 0.8380 - val_loss: 1.0369 - val_output_calltype_loss: 1.0288 - val_output_callpresence_loss: 0.1616 - val_output_calltype_binary_accuracy: 0.8926 - val_output_callpresence_binary_accuracy: 0.7723
# Epoch 24/200
# 40/40 [==============================] - 56s 1s/step - loss: 0.7981 - output_calltype_loss: 0.7922 - output_callpresence_loss: 0.1185 - output_calltype_binary_accuracy: 0.9346 - output_callpresence_binary_accuracy: 0.8367 - val_loss: 1.0349 - val_output_calltype_loss: 1.0267 - val_output_callpresence_loss: 0.1640 - val_output_calltype_binary_accuracy: 0.8899 - val_output_callpresence_binary_accuracy: 0.7724
# Epoch 25/200
# 40/40 [==============================] - 56s 1s/step - loss: 0.7759 - output_calltype_loss: 0.7703 - output_callpresence_loss: 0.1129 - output_calltype_binary_accuracy: 0.9371 - output_callpresence_binary_accuracy: 0.8482 - val_loss: 1.0586 - val_output_calltype_loss: 1.0506 - val_output_callpresence_loss: 0.1602 - val_output_calltype_binary_accuracy: 0.8924 - val_output_callpresence_binary_accuracy: 0.7707
# Epoch 26/200
# 40/40 [==============================] - 57s 1s/step - loss: 0.7844 - output_calltype_loss: 0.7787 - output_callpresence_loss: 0.1126 - output_calltype_binary_accuracy: 0.9367 - output_callpresence_binary_accuracy: 0.8459 - val_loss: 0.9763 - val_output_calltype_loss: 0.9688 - val_output_callpresence_loss: 0.1487 - val_output_calltype_binary_accuracy: 0.9016 - val_output_callpresence_binary_accuracy: 0.7879
# Epoch 27/200
# 40/40 [==============================] - 56s 1s/step - loss: 0.7928 - output_calltype_loss: 0.7870 - output_callpresence_loss: 0.1169 - output_calltype_binary_accuracy: 0.9375 - output_callpresence_binary_accuracy: 0.8417 - val_loss: 0.9756 - val_output_calltype_loss: 0.9679 - val_output_callpresence_loss: 0.1546 - val_output_calltype_binary_accuracy: 0.9012 - val_output_callpresence_binary_accuracy: 0.7750
# Epoch 28/200
# 40/40 [==============================] - 56s 1s/step - loss: 0.7607 - output_calltype_loss: 0.7552 - output_callpresence_loss: 0.1091 - output_calltype_binary_accuracy: 0.9390 - output_callpresence_binary_accuracy: 0.8536 - val_loss: 1.0308 - val_output_calltype_loss: 1.0227 - val_output_callpresence_loss: 0.1619 - val_output_calltype_binary_accuracy: 0.8953 - val_output_callpresence_binary_accuracy: 0.7680
# Epoch 29/200
# 40/40 [==============================] - 55s 1s/step - loss: 0.7548 - output_calltype_loss: 0.7493 - output_callpresence_loss: 0.1085 - output_calltype_binary_accuracy: 0.9409 - output_callpresence_binary_accuracy: 0.8526 - val_loss: 0.9942 - val_output_calltype_loss: 0.9865 - val_output_callpresence_loss: 0.1545 - val_output_calltype_binary_accuracy: 0.9016 - val_output_callpresence_binary_accuracy: 0.7795
# Epoch 30/200
# 40/40 [==============================] - 55s 1s/step - loss: 0.7420 - output_calltype_loss: 0.7366 - output_callpresence_loss: 0.1074 - output_calltype_binary_accuracy: 0.9409 - output_callpresence_binary_accuracy: 0.8537 - val_loss: 0.9120 - val_output_calltype_loss: 0.9048 - val_output_callpresence_loss: 0.1425 - val_output_calltype_binary_accuracy: 0.9092 - val_output_callpresence_binary_accuracy: 0.7958
# Epoch 31/200
# 40/40 [==============================] - 55s 1s/step - loss: 0.7143 - output_calltype_loss: 0.7091 - output_callpresence_loss: 0.1047 - output_calltype_binary_accuracy: 0.9428 - output_callpresence_binary_accuracy: 0.8543 - val_loss: 1.0205 - val_output_calltype_loss: 1.0129 - val_output_callpresence_loss: 0.1528 - val_output_calltype_binary_accuracy: 0.9035 - val_output_callpresence_binary_accuracy: 0.7812
# Epoch 32/200
# 40/40 [==============================] - 56s 1s/step - loss: 0.7335 - output_calltype_loss: 0.7283 - output_callpresence_loss: 0.1044 - output_calltype_binary_accuracy: 0.9444 - output_callpresence_binary_accuracy: 0.8583 - val_loss: 0.9776 - val_output_calltype_loss: 0.9704 - val_output_callpresence_loss: 0.1440 - val_output_calltype_binary_accuracy: 0.9127 - val_output_callpresence_binary_accuracy: 0.7971
# Epoch 33/200
# 40/40 [==============================] - 57s 1s/step - loss: 0.7324 - output_calltype_loss: 0.7269 - output_callpresence_loss: 0.1091 - output_calltype_binary_accuracy: 0.9428 - output_callpresence_binary_accuracy: 0.8475 - val_loss: 0.8590 - val_output_calltype_loss: 0.8525 - val_output_callpresence_loss: 0.1305 - val_output_calltype_binary_accuracy: 0.9190 - val_output_callpresence_binary_accuracy: 0.8144
# Epoch 34/200
# 40/40 [==============================] - 56s 1s/step - loss: 0.7123 - output_calltype_loss: 0.7072 - output_callpresence_loss: 0.1017 - output_calltype_binary_accuracy: 0.9446 - output_callpresence_binary_accuracy: 0.8598 - val_loss: 0.8149 - val_output_calltype_loss: 0.8086 - val_output_callpresence_loss: 0.1252 - val_output_calltype_binary_accuracy: 0.9250 - val_output_callpresence_binary_accuracy: 0.8150
# Epoch 35/200
# 40/40 [==============================] - 56s 1s/step - loss: 0.7077 - output_calltype_loss: 0.7026 - output_callpresence_loss: 0.1026 - output_calltype_binary_accuracy: 0.9465 - output_callpresence_binary_accuracy: 0.8601 - val_loss: 1.0253 - val_output_calltype_loss: 1.0171 - val_output_callpresence_loss: 0.1640 - val_output_calltype_binary_accuracy: 0.9089 - val_output_callpresence_binary_accuracy: 0.7716
# Epoch 36/200
# 40/40 [==============================] - 56s 1s/step - loss: 0.6990 - output_calltype_loss: 0.6939 - output_callpresence_loss: 0.1017 - output_calltype_binary_accuracy: 0.9488 - output_callpresence_binary_accuracy: 0.8598 - val_loss: 0.9777 - val_output_calltype_loss: 0.9702 - val_output_callpresence_loss: 0.1498 - val_output_calltype_binary_accuracy: 0.9179 - val_output_callpresence_binary_accuracy: 0.7987
# Epoch 37/200
# 40/40 [==============================] - 56s 1s/step - loss: 0.6929 - output_calltype_loss: 0.6877 - output_callpresence_loss: 0.1036 - output_calltype_binary_accuracy: 0.9500 - output_callpresence_binary_accuracy: 0.8574 - val_loss: 0.8993 - val_output_calltype_loss: 0.8924 - val_output_callpresence_loss: 0.1373 - val_output_calltype_binary_accuracy: 0.9254 - val_output_callpresence_binary_accuracy: 0.8097
# Epoch 38/200
# 40/40 [==============================] - 57s 1s/step - loss: 0.6948 - output_calltype_loss: 0.6896 - output_callpresence_loss: 0.1036 - output_calltype_binary_accuracy: 0.9504 - output_callpresence_binary_accuracy: 0.8596 - val_loss: 0.9259 - val_output_calltype_loss: 0.9184 - val_output_callpresence_loss: 0.1502 - val_output_calltype_binary_accuracy: 0.9246 - val_output_callpresence_binary_accuracy: 0.7912
# Epoch 39/200
# 40/40 [==============================] - 56s 1s/step - loss: 0.6726 - output_calltype_loss: 0.6674 - output_callpresence_loss: 0.1027 - output_calltype_binary_accuracy: 0.9548 - output_callpresence_binary_accuracy: 0.8575 - val_loss: 0.8119 - val_output_calltype_loss: 0.8056 - val_output_callpresence_loss: 0.1273 - val_output_calltype_binary_accuracy: 0.9360 - val_output_callpresence_binary_accuracy: 0.8207
# Epoch 40/200
# 40/40 [==============================] - 56s 1s/step - loss: 0.6540 - output_calltype_loss: 0.6489 - output_callpresence_loss: 0.1004 - output_calltype_binary_accuracy: 0.9546 - output_callpresence_binary_accuracy: 0.8620 - val_loss: 1.0323 - val_output_calltype_loss: 1.0245 - val_output_callpresence_loss: 0.1553 - val_output_calltype_binary_accuracy: 0.9248 - val_output_callpresence_binary_accuracy: 0.7838
# Epoch 41/200
# 40/40 [==============================] - 56s 1s/step - loss: 0.6588 - output_calltype_loss: 0.6537 - output_callpresence_loss: 0.1018 - output_calltype_binary_accuracy: 0.9576 - output_callpresence_binary_accuracy: 0.8607 - val_loss: 0.8467 - val_output_calltype_loss: 0.8400 - val_output_callpresence_loss: 0.1337 - val_output_calltype_binary_accuracy: 0.9389 - val_output_callpresence_binary_accuracy: 0.8207
# Epoch 42/200
# 40/40 [==============================] - 55s 1s/step - loss: 0.6495 - output_calltype_loss: 0.6444 - output_callpresence_loss: 0.1027 - output_calltype_binary_accuracy: 0.9583 - output_callpresence_binary_accuracy: 0.8580 - val_loss: 0.8716 - val_output_calltype_loss: 0.8646 - val_output_callpresence_loss: 0.1409 - val_output_calltype_binary_accuracy: 0.9394 - val_output_callpresence_binary_accuracy: 0.8046
# Epoch 43/200
# 40/40 [==============================] - 56s 1s/step - loss: 0.6125 - output_calltype_loss: 0.6077 - output_callpresence_loss: 0.0969 - output_calltype_binary_accuracy: 0.9616 - output_callpresence_binary_accuracy: 0.8679 - val_loss: 0.7614 - val_output_calltype_loss: 0.7553 - val_output_callpresence_loss: 0.1211 - val_output_calltype_binary_accuracy: 0.9481 - val_output_callpresence_binary_accuracy: 0.8362
# Epoch 44/200
# 40/40 [==============================] - 57s 1s/step - loss: 0.6122 - output_calltype_loss: 0.6072 - output_callpresence_loss: 0.0998 - output_calltype_binary_accuracy: 0.9604 - output_callpresence_binary_accuracy: 0.8634 - val_loss: 0.9764 - val_output_calltype_loss: 0.9688 - val_output_callpresence_loss: 0.1511 - val_output_calltype_binary_accuracy: 0.9315 - val_output_callpresence_binary_accuracy: 0.7986
# Epoch 45/200
# 40/40 [==============================] - 56s 1s/step - loss: 0.5991 - output_calltype_loss: 0.5941 - output_callpresence_loss: 0.0998 - output_calltype_binary_accuracy: 0.9589 - output_callpresence_binary_accuracy: 0.8568 - val_loss: 0.8656 - val_output_calltype_loss: 0.8588 - val_output_callpresence_loss: 0.1348 - val_output_calltype_binary_accuracy: 0.9393 - val_output_callpresence_binary_accuracy: 0.8165
# Epoch 46/200
# 40/40 [==============================] - 56s 1s/step - loss: 0.6158 - output_calltype_loss: 0.6107 - output_callpresence_loss: 0.1009 - output_calltype_binary_accuracy: 0.9601 - output_callpresence_binary_accuracy: 0.8619 - val_loss: 0.9441 - val_output_calltype_loss: 0.9370 - val_output_callpresence_loss: 0.1418 - val_output_calltype_binary_accuracy: 0.9374 - val_output_callpresence_binary_accuracy: 0.8144
# Epoch 47/200
# 40/40 [==============================] - 56s 1s/step - loss: 0.5892 - output_calltype_loss: 0.5843 - output_callpresence_loss: 0.0976 - output_calltype_binary_accuracy: 0.9619 - output_callpresence_binary_accuracy: 0.8637 - val_loss: 0.7838 - val_output_calltype_loss: 0.7772 - val_output_callpresence_loss: 0.1310 - val_output_calltype_binary_accuracy: 0.9416 - val_output_callpresence_binary_accuracy: 0.8220
# Epoch 48/200
# 40/40 [==============================] - 56s 1s/step - loss: 0.5700 - output_calltype_loss: 0.5654 - output_callpresence_loss: 0.0926 - output_calltype_binary_accuracy: 0.9628 - output_callpresence_binary_accuracy: 0.8743 - val_loss: 0.8426 - val_output_calltype_loss: 0.8356 - val_output_callpresence_loss: 0.1395 - val_output_calltype_binary_accuracy: 0.9369 - val_output_callpresence_binary_accuracy: 0.8027
# Epoch 49/200
# 40/40 [==============================] - 55s 1s/step - loss: 0.5788 - output_calltype_loss: 0.5741 - output_callpresence_loss: 0.0935 - output_calltype_binary_accuracy: 0.9623 - output_callpresence_binary_accuracy: 0.8723 - val_loss: 0.8080 - val_output_calltype_loss: 0.8015 - val_output_callpresence_loss: 0.1298 - val_output_calltype_binary_accuracy: 0.9437 - val_output_callpresence_binary_accuracy: 0.8207
# Epoch 50/200
# 40/40 [==============================] - 54s 1s/step - loss: 0.5797 - output_calltype_loss: 0.5750 - output_callpresence_loss: 0.0942 - output_calltype_binary_accuracy: 0.9630 - output_callpresence_binary_accuracy: 0.8699 - val_loss: 0.8527 - val_output_calltype_loss: 0.8457 - val_output_callpresence_loss: 0.1389 - val_output_calltype_binary_accuracy: 0.9377 - val_output_callpresence_binary_accuracy: 0.8115
# Epoch 51/200
# 40/40 [==============================] - 55s 1s/step - loss: 0.5938 - output_calltype_loss: 0.5889 - output_callpresence_loss: 0.0966 - output_calltype_binary_accuracy: 0.9615 - output_callpresence_binary_accuracy: 0.8634 - val_loss: 0.8557 - val_output_calltype_loss: 0.8491 - val_output_callpresence_loss: 0.1322 - val_output_calltype_binary_accuracy: 0.9395 - val_output_callpresence_binary_accuracy: 0.8208
# Epoch 52/200
# 40/40 [==============================] - 54s 1s/step - loss: 0.5403 - output_calltype_loss: 0.5358 - output_callpresence_loss: 0.0912 - output_calltype_binary_accuracy: 0.9640 - output_callpresence_binary_accuracy: 0.8723 - val_loss: 0.8535 - val_output_calltype_loss: 0.8465 - val_output_callpresence_loss: 0.1394 - val_output_calltype_binary_accuracy: 0.9423 - val_output_callpresence_binary_accuracy: 0.8107
# Epoch 53/200
# 40/40 [==============================] - 56s 1s/step - loss: 0.5825 - output_calltype_loss: 0.5777 - output_callpresence_loss: 0.0957 - output_calltype_binary_accuracy: 0.9625 - output_callpresence_binary_accuracy: 0.8659 - val_loss: 0.7890 - val_output_calltype_loss: 0.7824 - val_output_callpresence_loss: 0.1322 - val_output_calltype_binary_accuracy: 0.9432 - val_output_callpresence_binary_accuracy: 0.8154
# Epoch 54/200
# 40/40 [==============================] - 54s 1s/step - loss: 0.5420 - output_calltype_loss: 0.5375 - output_callpresence_loss: 0.0888 - output_calltype_binary_accuracy: 0.9644 - output_callpresence_binary_accuracy: 0.8760 - val_loss: 0.7617 - val_output_calltype_loss: 0.7553 - val_output_callpresence_loss: 0.1286 - val_output_calltype_binary_accuracy: 0.9449 - val_output_callpresence_binary_accuracy: 0.8191
# Epoch 55/200
# 40/40 [==============================] - 55s 1s/step - loss: 0.5377 - output_calltype_loss: 0.5332 - output_callpresence_loss: 0.0906 - output_calltype_binary_accuracy: 0.9645 - output_callpresence_binary_accuracy: 0.8748 - val_loss: 0.9006 - val_output_calltype_loss: 0.8934 - val_output_callpresence_loss: 0.1435 - val_output_calltype_binary_accuracy: 0.9373 - val_output_callpresence_binary_accuracy: 0.8037
# Epoch 56/200
# 40/40 [==============================] - 55s 1s/step - loss: 0.5637 - output_calltype_loss: 0.5591 - output_callpresence_loss: 0.0927 - output_calltype_binary_accuracy: 0.9637 - output_callpresence_binary_accuracy: 0.8713 - val_loss: 0.8185 - val_output_calltype_loss: 0.8117 - val_output_callpresence_loss: 0.1363 - val_output_calltype_binary_accuracy: 0.9442 - val_output_callpresence_binary_accuracy: 0.8115
# Epoch 57/200
# 40/40 [==============================] - 56s 1s/step - loss: 0.5412 - output_calltype_loss: 0.5368 - output_callpresence_loss: 0.0896 - output_calltype_binary_accuracy: 0.9659 - output_callpresence_binary_accuracy: 0.8785 - val_loss: 0.9234 - val_output_calltype_loss: 0.9161 - val_output_callpresence_loss: 0.1478 - val_output_calltype_binary_accuracy: 0.9395 - val_output_callpresence_binary_accuracy: 0.7980
# Epoch 58/200
# 40/40 [==============================] - 56s 1s/step - loss: 0.5215 - output_calltype_loss: 0.5172 - output_callpresence_loss: 0.0872 - output_calltype_binary_accuracy: 0.9665 - output_callpresence_binary_accuracy: 0.8809 - val_loss: 0.8440 - val_output_calltype_loss: 0.8375 - val_output_callpresence_loss: 0.1289 - val_output_calltype_binary_accuracy: 0.9446 - val_output_callpresence_binary_accuracy: 0.8315
# Epoch 59/200
# 40/40 [==============================] - 54s 1s/step - loss: 0.5268 - output_calltype_loss: 0.5223 - output_callpresence_loss: 0.0903 - output_calltype_binary_accuracy: 0.9649 - output_callpresence_binary_accuracy: 0.8768 - val_loss: 0.8831 - val_output_calltype_loss: 0.8764 - val_output_callpresence_loss: 0.1345 - val_output_calltype_binary_accuracy: 0.9412 - val_output_callpresence_binary_accuracy: 0.8225
# Epoch 60/200
# 40/40 [==============================] - 54s 1s/step - loss: 0.5242 - output_calltype_loss: 0.5198 - output_callpresence_loss: 0.0886 - output_calltype_binary_accuracy: 0.9657 - output_callpresence_binary_accuracy: 0.8783 - val_loss: 0.7711 - val_output_calltype_loss: 0.7647 - val_output_callpresence_loss: 0.1277 - val_output_calltype_binary_accuracy: 0.9485 - val_output_callpresence_binary_accuracy: 0.8262
# Epoch 61/200
# 40/40 [==============================] - 55s 1s/step - loss: 0.5244 - output_calltype_loss: 0.5199 - output_callpresence_loss: 0.0907 - output_calltype_binary_accuracy: 0.9648 - output_callpresence_binary_accuracy: 0.8733 - val_loss: 0.8862 - val_output_calltype_loss: 0.8793 - val_output_callpresence_loss: 0.1379 - val_output_calltype_binary_accuracy: 0.9391 - val_output_callpresence_binary_accuracy: 0.8192
# Epoch 62/200
# 40/40 [==============================] - 54s 1s/step - loss: 0.5213 - output_calltype_loss: 0.5169 - output_callpresence_loss: 0.0883 - output_calltype_binary_accuracy: 0.9658 - output_callpresence_binary_accuracy: 0.8783 - val_loss: 0.8946 - val_output_calltype_loss: 0.8874 - val_output_callpresence_loss: 0.1450 - val_output_calltype_binary_accuracy: 0.9388 - val_output_callpresence_binary_accuracy: 0.8002
# Epoch 63/200
# 40/40 [==============================] - 54s 1s/step - loss: 0.5162 - output_calltype_loss: 0.5118 - output_callpresence_loss: 0.0878 - output_calltype_binary_accuracy: 0.9657 - output_callpresence_binary_accuracy: 0.8791 - val_loss: 0.8595 - val_output_calltype_loss: 0.8525 - val_output_callpresence_loss: 0.1381 - val_output_calltype_binary_accuracy: 0.9405 - val_output_callpresence_binary_accuracy: 0.8136
# Epoch 64/200
# 40/40 [==============================] - 55s 1s/step - loss: 0.5142 - output_calltype_loss: 0.5098 - output_callpresence_loss: 0.0873 - output_calltype_binary_accuracy: 0.9662 - output_callpresence_binary_accuracy: 0.8797 - val_loss: 0.8747 - val_output_calltype_loss: 0.8677 - val_output_callpresence_loss: 0.1414 - val_output_calltype_binary_accuracy: 0.9420 - val_output_callpresence_binary_accuracy: 0.8156
# Epoch 65/200
# 40/40 [==============================] - 55s 1s/step - loss: 0.5165 - output_calltype_loss: 0.5119 - output_callpresence_loss: 0.0905 - output_calltype_binary_accuracy: 0.9655 - output_callpresence_binary_accuracy: 0.8756 - val_loss: 0.8190 - val_output_calltype_loss: 0.8120 - val_output_callpresence_loss: 0.1398 - val_output_calltype_binary_accuracy: 0.9400 - val_output_callpresence_binary_accuracy: 0.8051
# Epoch 66/200
# 40/40 [==============================] - 56s 1s/step - loss: 0.5089 - output_calltype_loss: 0.5046 - output_callpresence_loss: 0.0863 - output_calltype_binary_accuracy: 0.9669 - output_callpresence_binary_accuracy: 0.8837 - val_loss: 0.7749 - val_output_calltype_loss: 0.7682 - val_output_callpresence_loss: 0.1343 - val_output_calltype_binary_accuracy: 0.9448 - val_output_callpresence_binary_accuracy: 0.8158
# Epoch 67/200
# 40/40 [==============================] - 55s 1s/step - loss: 0.5067 - output_calltype_loss: 0.5022 - output_callpresence_loss: 0.0883 - output_calltype_binary_accuracy: 0.9654 - output_callpresence_binary_accuracy: 0.8775 - val_loss: 0.7702 - val_output_calltype_loss: 0.7635 - val_output_callpresence_loss: 0.1337 - val_output_calltype_binary_accuracy: 0.9456 - val_output_callpresence_binary_accuracy: 0.8142
# Epoch 68/200
# 40/40 [==============================] - 54s 1s/step - loss: 0.5000 - output_calltype_loss: 0.4956 - output_callpresence_loss: 0.0873 - output_calltype_binary_accuracy: 0.9666 - output_callpresence_binary_accuracy: 0.8780 - val_loss: 0.8476 - val_output_calltype_loss: 0.8410 - val_output_callpresence_loss: 0.1313 - val_output_calltype_binary_accuracy: 0.9449 - val_output_callpresence_binary_accuracy: 0.8251
#
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 69/200
# 40/40 [==============================] - 54s 1s/step - loss: 0.4767 - output_calltype_loss: 0.4724 - output_callpresence_loss: 0.0849 - output_calltype_binary_accuracy: 0.9678 - output_callpresence_binary_accuracy: 0.8838 - val_loss: 0.7704 - val_output_calltype_loss: 0.7639 - val_output_callpresence_loss: 0.1308 - val_output_calltype_binary_accuracy: 0.9462 - val_output_callpresence_binary_accuracy: 0.8224
# Epoch 70/200
# 40/40 [==============================] - 55s 1s/step - loss: 0.5084 - output_calltype_loss: 0.5038 - output_callpresence_loss: 0.0912 - output_calltype_binary_accuracy: 0.9655 - output_callpresence_binary_accuracy: 0.8729 - val_loss: 0.7907 - val_output_calltype_loss: 0.7844 - val_output_callpresence_loss: 0.1265 - val_output_calltype_binary_accuracy: 0.9460 - val_output_callpresence_binary_accuracy: 0.8273
# Epoch 71/200
# 40/40 [==============================] - 55s 1s/step - loss: 0.4823 - output_calltype_loss: 0.4780 - output_callpresence_loss: 0.0863 - output_calltype_binary_accuracy: 0.9675 - output_callpresence_binary_accuracy: 0.8803 - val_loss: 0.8140 - val_output_calltype_loss: 0.8073 - val_output_callpresence_loss: 0.1342 - val_output_calltype_binary_accuracy: 0.9425 - val_output_callpresence_binary_accuracy: 0.8120
# Epoch 72/200
# 40/40 [==============================] - 54s 1s/step - loss: 0.4857 - output_calltype_loss: 0.4814 - output_callpresence_loss: 0.0867 - output_calltype_binary_accuracy: 0.9672 - output_callpresence_binary_accuracy: 0.8795 - val_loss: 0.8128 - val_output_calltype_loss: 0.8064 - val_output_callpresence_loss: 0.1290 - val_output_calltype_binary_accuracy: 0.9461 - val_output_callpresence_binary_accuracy: 0.8328
# Epoch 73/200
# 40/40 [==============================] - 56s 1s/step - loss: 0.4808 - output_calltype_loss: 0.4766 - output_callpresence_loss: 0.0842 - output_calltype_binary_accuracy: 0.9674 - output_callpresence_binary_accuracy: 0.8837 - val_loss: 0.7852 - val_output_calltype_loss: 0.7786 - val_output_callpresence_loss: 0.1335 - val_output_calltype_binary_accuracy: 0.9453 - val_output_callpresence_binary_accuracy: 0.8181
# Epoch 74/200
# 40/40 [==============================] - 55s 1s/step - loss: 0.4704 - output_calltype_loss: 0.4661 - output_callpresence_loss: 0.0857 - output_calltype_binary_accuracy: 0.9672 - output_callpresence_binary_accuracy: 0.8793 - val_loss: 0.8004 - val_output_calltype_loss: 0.7935 - val_output_callpresence_loss: 0.1386 - val_output_calltype_binary_accuracy: 0.9436 - val_output_callpresence_binary_accuracy: 0.8092
# Epoch 75/200
# 40/40 [==============================] - 54s 1s/step - loss: 0.4791 - output_calltype_loss: 0.4749 - output_callpresence_loss: 0.0838 - output_calltype_binary_accuracy: 0.9677 - output_callpresence_binary_accuracy: 0.8845 - val_loss: 0.8354 - val_output_calltype_loss: 0.8285 - val_output_callpresence_loss: 0.1368 - val_output_calltype_binary_accuracy: 0.9447 - val_output_callpresence_binary_accuracy: 0.8201
# Epoch 76/200
# 40/40 [==============================] - 56s 1s/step - loss: 0.4729 - output_calltype_loss: 0.4687 - output_callpresence_loss: 0.0852 - output_calltype_binary_accuracy: 0.9669 - output_callpresence_binary_accuracy: 0.8808 - val_loss: 0.7534 - val_output_calltype_loss: 0.7471 - val_output_callpresence_loss: 0.1250 - val_output_calltype_binary_accuracy: 0.9488 - val_output_callpresence_binary_accuracy: 0.8332
# Epoch 77/200
# 40/40 [==============================] - 54s 1s/step - loss: 0.4826 - output_calltype_loss: 0.4784 - output_callpresence_loss: 0.0842 - output_calltype_binary_accuracy: 0.9669 - output_callpresence_binary_accuracy: 0.8837 - val_loss: 0.7760 - val_output_calltype_loss: 0.7698 - val_output_callpresence_loss: 0.1243 - val_output_calltype_binary_accuracy: 0.9481 - val_output_callpresence_binary_accuracy: 0.8326
# Epoch 78/200
# 40/40 [==============================] - 55s 1s/step - loss: 0.4825 - output_calltype_loss: 0.4783 - output_callpresence_loss: 0.0849 - output_calltype_binary_accuracy: 0.9673 - output_callpresence_binary_accuracy: 0.8832 - val_loss: 0.8071 - val_output_calltype_loss: 0.8007 - val_output_callpresence_loss: 0.1285 - val_output_calltype_binary_accuracy: 0.9478 - val_output_callpresence_binary_accuracy: 0.8311
# Epoch 79/200
# 40/40 [==============================] - 55s 1s/step - loss: 0.4596 - output_calltype_loss: 0.4555 - output_callpresence_loss: 0.0819 - output_calltype_binary_accuracy: 0.9689 - output_callpresence_binary_accuracy: 0.8878 - val_loss: 0.8074 - val_output_calltype_loss: 0.8009 - val_output_callpresence_loss: 0.1286 - val_output_calltype_binary_accuracy: 0.9467 - val_output_callpresence_binary_accuracy: 0.8257
# Epoch 80/200
# 40/40 [==============================] - 56s 1s/step - loss: 0.4827 - output_calltype_loss: 0.4784 - output_callpresence_loss: 0.0865 - output_calltype_binary_accuracy: 0.9671 - output_callpresence_binary_accuracy: 0.8760 - val_loss: 0.7798 - val_output_calltype_loss: 0.7733 - val_output_callpresence_loss: 0.1285 - val_output_calltype_binary_accuracy: 0.9478 - val_output_callpresence_binary_accuracy: 0.8253
# Epoch 81/200
# 40/40 [==============================] - 55s 1s/step - loss: 0.4571 - output_calltype_loss: 0.4530 - output_callpresence_loss: 0.0813 - output_calltype_binary_accuracy: 0.9691 - output_callpresence_binary_accuracy: 0.8869 - val_loss: 0.7282 - val_output_calltype_loss: 0.7221 - val_output_callpresence_loss: 0.1213 - val_output_calltype_binary_accuracy: 0.9502 - val_output_callpresence_binary_accuracy: 0.8351
# Epoch 82/200
# 40/40 [==============================] - 54s 1s/step - loss: 0.4726 - output_calltype_loss: 0.4684 - output_callpresence_loss: 0.0843 - output_calltype_binary_accuracy: 0.9678 - output_callpresence_binary_accuracy: 0.8832 - val_loss: 0.7530 - val_output_calltype_loss: 0.7464 - val_output_callpresence_loss: 0.1311 - val_output_calltype_binary_accuracy: 0.9485 - val_output_callpresence_binary_accuracy: 0.8213
# Epoch 83/200
# 40/40 [==============================] - 56s 1s/step - loss: 0.4750 - output_calltype_loss: 0.4707 - output_callpresence_loss: 0.0847 - output_calltype_binary_accuracy: 0.9674 - output_callpresence_binary_accuracy: 0.8819 - val_loss: 0.8127 - val_output_calltype_loss: 0.8060 - val_output_callpresence_loss: 0.1351 - val_output_calltype_binary_accuracy: 0.9462 - val_output_callpresence_binary_accuracy: 0.8234
# Epoch 84/200
# 40/40 [==============================] - 55s 1s/step - loss: 0.4631 - output_calltype_loss: 0.4590 - output_callpresence_loss: 0.0805 - output_calltype_binary_accuracy: 0.9685 - output_callpresence_binary_accuracy: 0.8902 - val_loss: 0.7110 - val_output_calltype_loss: 0.7051 - val_output_callpresence_loss: 0.1185 - val_output_calltype_binary_accuracy: 0.9513 - val_output_callpresence_binary_accuracy: 0.8437
# Epoch 85/200
# 40/40 [==============================] - 56s 1s/step - loss: 0.4409 - output_calltype_loss: 0.4370 - output_callpresence_loss: 0.0775 - output_calltype_binary_accuracy: 0.9698 - output_callpresence_binary_accuracy: 0.8927 - val_loss: 0.7209 - val_output_calltype_loss: 0.7147 - val_output_callpresence_loss: 0.1237 - val_output_calltype_binary_accuracy: 0.9508 - val_output_callpresence_binary_accuracy: 0.8391
# Epoch 86/200
# 40/40 [==============================] - 55s 1s/step - loss: 0.4616 - output_calltype_loss: 0.4575 - output_callpresence_loss: 0.0825 - output_calltype_binary_accuracy: 0.9692 - output_callpresence_binary_accuracy: 0.8883 - val_loss: 0.7310 - val_output_calltype_loss: 0.7248 - val_output_callpresence_loss: 0.1238 - val_output_calltype_binary_accuracy: 0.9495 - val_output_callpresence_binary_accuracy: 0.8325
# Epoch 87/200
# 40/40 [==============================] - 54s 1s/step - loss: 0.4505 - output_calltype_loss: 0.4464 - output_callpresence_loss: 0.0815 - output_calltype_binary_accuracy: 0.9689 - output_callpresence_binary_accuracy: 0.8861 - val_loss: 0.7986 - val_output_calltype_loss: 0.7922 - val_output_callpresence_loss: 0.1293 - val_output_calltype_binary_accuracy: 0.9476 - val_output_callpresence_binary_accuracy: 0.8246
# Epoch 88/200
# 40/40 [==============================] - 54s 1s/step - loss: 0.4540 - output_calltype_loss: 0.4499 - output_callpresence_loss: 0.0811 - output_calltype_binary_accuracy: 0.9691 - output_callpresence_binary_accuracy: 0.8867 - val_loss: 0.7473 - val_output_calltype_loss: 0.7412 - val_output_callpresence_loss: 0.1216 - val_output_calltype_binary_accuracy: 0.9500 - val_output_callpresence_binary_accuracy: 0.8329
# Epoch 89/200
# 40/40 [==============================] - 55s 1s/step - loss: 0.4643 - output_calltype_loss: 0.4602 - output_callpresence_loss: 0.0827 - output_calltype_binary_accuracy: 0.9687 - output_callpresence_binary_accuracy: 0.8869 - val_loss: 0.7675 - val_output_calltype_loss: 0.7610 - val_output_callpresence_loss: 0.1310 - val_output_calltype_binary_accuracy: 0.9486 - val_output_callpresence_binary_accuracy: 0.8203
# Epoch 90/200
# 40/40 [==============================] - 55s 1s/step - loss: 0.4412 - output_calltype_loss: 0.4372 - output_callpresence_loss: 0.0800 - output_calltype_binary_accuracy: 0.9693 - output_callpresence_binary_accuracy: 0.8890 - val_loss: 0.7636 - val_output_calltype_loss: 0.7569 - val_output_callpresence_loss: 0.1337 - val_output_calltype_binary_accuracy: 0.9488 - val_output_callpresence_binary_accuracy: 0.8124
# Epoch 91/200
# 40/40 [==============================] - 55s 1s/step - loss: 0.4687 - output_calltype_loss: 0.4645 - output_callpresence_loss: 0.0845 - output_calltype_binary_accuracy: 0.9689 - output_callpresence_binary_accuracy: 0.8841 - val_loss: 0.7635 - val_output_calltype_loss: 0.7573 - val_output_callpresence_loss: 0.1249 - val_output_calltype_binary_accuracy: 0.9476 - val_output_callpresence_binary_accuracy: 0.8291
# Epoch 92/200
# 40/40 [==============================] - 56s 1s/step - loss: 0.4583 - output_calltype_loss: 0.4543 - output_callpresence_loss: 0.0813 - output_calltype_binary_accuracy: 0.9686 - output_callpresence_binary_accuracy: 0.8867 - val_loss: 0.7597 - val_output_calltype_loss: 0.7533 - val_output_callpresence_loss: 0.1277 - val_output_calltype_binary_accuracy: 0.9489 - val_output_callpresence_binary_accuracy: 0.8302
# Epoch 93/200
# 40/40 [==============================] - 55s 1s/step - loss: 0.4485 - output_calltype_loss: 0.4444 - output_callpresence_loss: 0.0813 - output_calltype_binary_accuracy: 0.9695 - output_callpresence_binary_accuracy: 0.8893 - val_loss: 0.7464 - val_output_calltype_loss: 0.7404 - val_output_callpresence_loss: 0.1205 - val_output_calltype_binary_accuracy: 0.9513 - val_output_callpresence_binary_accuracy: 0.8393
# Epoch 94/200
# 40/40 [==============================] - 56s 1s/step - loss: 0.4346 - output_calltype_loss: 0.4307 - output_callpresence_loss: 0.0783 - output_calltype_binary_accuracy: 0.9700 - output_callpresence_binary_accuracy: 0.8929 - val_loss: 0.7249 - val_output_calltype_loss: 0.7190 - val_output_callpresence_loss: 0.1185 - val_output_calltype_binary_accuracy: 0.9508 - val_output_callpresence_binary_accuracy: 0.8346
# Epoch 95/200
# 40/40 [==============================] - 54s 1s/step - loss: 0.4360 - output_calltype_loss: 0.4321 - output_callpresence_loss: 0.0775 - output_calltype_binary_accuracy: 0.9705 - output_callpresence_binary_accuracy: 0.8953 - val_loss: 0.8002 - val_output_calltype_loss: 0.7932 - val_output_callpresence_loss: 0.1389 - val_output_calltype_binary_accuracy: 0.9447 - val_output_callpresence_binary_accuracy: 0.8112
# Epoch 96/200
# 40/40 [==============================] - 56s 1s/step - loss: 0.4776 - output_calltype_loss: 0.4735 - output_callpresence_loss: 0.0827 - output_calltype_binary_accuracy: 0.9688 - output_callpresence_binary_accuracy: 0.8868 - val_loss: 0.6983 - val_output_calltype_loss: 0.6924 - val_output_callpresence_loss: 0.1191 - val_output_calltype_binary_accuracy: 0.9525 - val_output_callpresence_binary_accuracy: 0.8405
# Epoch 97/200
# 40/40 [==============================] - 54s 1s/step - loss: 0.4499 - output_calltype_loss: 0.4459 - output_callpresence_loss: 0.0814 - output_calltype_binary_accuracy: 0.9689 - output_callpresence_binary_accuracy: 0.8877 - val_loss: 0.7698 - val_output_calltype_loss: 0.7633 - val_output_callpresence_loss: 0.1308 - val_output_calltype_binary_accuracy: 0.9471 - val_output_callpresence_binary_accuracy: 0.8170
# Epoch 98/200
# 40/40 [==============================] - 56s 1s/step - loss: 0.4313 - output_calltype_loss: 0.4274 - output_callpresence_loss: 0.0778 - output_calltype_binary_accuracy: 0.9703 - output_callpresence_binary_accuracy: 0.8918 - val_loss: 0.7961 - val_output_calltype_loss: 0.7895 - val_output_callpresence_loss: 0.1322 - val_output_calltype_binary_accuracy: 0.9471 - val_output_callpresence_binary_accuracy: 0.8225
# Epoch 99/200
# 40/40 [==============================] - 54s 1s/step - loss: 0.4554 - output_calltype_loss: 0.4512 - output_callpresence_loss: 0.0824 - output_calltype_binary_accuracy: 0.9690 - output_callpresence_binary_accuracy: 0.8851 - val_loss: 0.6786 - val_output_calltype_loss: 0.6728 - val_output_callpresence_loss: 0.1178 - val_output_calltype_binary_accuracy: 0.9533 - val_output_callpresence_binary_accuracy: 0.8401
# Epoch 100/200
# 40/40 [==============================] - 55s 1s/step - loss: 0.4481 - output_calltype_loss: 0.4440 - output_callpresence_loss: 0.0828 - output_calltype_binary_accuracy: 0.9692 - output_callpresence_binary_accuracy: 0.8859 - val_loss: 0.8065 - val_output_calltype_loss: 0.7999 - val_output_callpresence_loss: 0.1331 - val_output_calltype_binary_accuracy: 0.9479 - val_output_callpresence_binary_accuracy: 0.8244
# Epoch 101/200
# 40/40 [==============================] - 55s 1s/step - loss: 0.4370 - output_calltype_loss: 0.4331 - output_callpresence_loss: 0.0786 - output_calltype_binary_accuracy: 0.9703 - output_callpresence_binary_accuracy: 0.8927 - val_loss: 0.7737 - val_output_calltype_loss: 0.7673 - val_output_callpresence_loss: 0.1280 - val_output_calltype_binary_accuracy: 0.9507 - val_output_callpresence_binary_accuracy: 0.8274
# Epoch 102/200
# 40/40 [==============================] - 54s 1s/step - loss: 0.4533 - output_calltype_loss: 0.4491 - output_callpresence_loss: 0.0850 - output_calltype_binary_accuracy: 0.9689 - output_callpresence_binary_accuracy: 0.8837 - val_loss: 0.7576 - val_output_calltype_loss: 0.7513 - val_output_callpresence_loss: 0.1257 - val_output_calltype_binary_accuracy: 0.9497 - val_output_callpresence_binary_accuracy: 0.8322
# Epoch 103/200
# 40/40 [==============================] - 55s 1s/step - loss: 0.4452 - output_calltype_loss: 0.4412 - output_callpresence_loss: 0.0808 - output_calltype_binary_accuracy: 0.9694 - output_callpresence_binary_accuracy: 0.8892 - val_loss: 0.6564 - val_output_calltype_loss: 0.6508 - val_output_callpresence_loss: 0.1134 - val_output_calltype_binary_accuracy: 0.9542 - val_output_callpresence_binary_accuracy: 0.8470
# Epoch 104/200
# ...
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 1365
# Detecting calls in probability streams:  1000 / 1365
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 1365
# Detecting calls in probability streams:  1000 / 1365
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 4300
# Detecting calls in probability streams:  1000 / 4300
# Detecting calls in probability streams:  2000 / 4300
# Detecting calls in probability streams:  3000 / 4300
# Detecting calls in probability streams:  4000 / 4300
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 4300
# Detecting calls in probability streams:  1000 / 4300
# Detecting calls in probability streams:  2000 / 4300
# Detecting calls in probability streams:  3000 / 4300
# Detecting calls in probability streams:  4000 / 4300
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 4300
# Detecting calls in probability streams:  1000 / 4300
# Detecting calls in probability streams:  2000 / 4300
# Detecting calls in probability streams:  3000 / 4300
# Detecting calls in probability streams:  4000 / 4300
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 4300
# Detecting calls in probability streams:  1000 / 4300
# Detecting calls in probability streams:  2000 / 4300
# Detecting calls in probability streams:  3000 / 4300
# Detecting calls in probability streams:  4000 / 4300
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 4300
# Detecting calls in probability streams:  1000 / 4300
# Detecting calls in probability streams:  2000 / 4300
# Detecting calls in probability streams:  3000 / 4300
# Detecting calls in probability streams:  4000 / 4300
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 4300
# Detecting calls in probability streams:  1000 / 4300
# Detecting calls in probability streams:  2000 / 4300
# Detecting calls in probability streams:  3000 / 4300
# Detecting calls in probability streams:  4000 / 4300
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 4300
# Detecting calls in probability streams:  1000 / 4300
# Detecting calls in probability streams:  2000 / 4300
# Detecting calls in probability streams:  3000 / 4300
# Detecting calls in probability streams:  4000 / 4300
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 4300
# Detecting calls in probability streams:  1000 / 4300
# Detecting calls in probability streams:  2000 / 4300
# Detecting calls in probability streams:  3000 / 4300
# Detecting calls in probability streams:  4000 / 4300
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 4300
# Detecting calls in probability streams:  1000 / 4300
# Detecting calls in probability streams:  2000 / 4300
# Detecting calls in probability streams:  3000 / 4300
# Detecting calls in probability streams:  4000 / 4300
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 4300
# Detecting calls in probability streams:  1000 / 4300
# Detecting calls in probability streams:  2000 / 4300
# Detecting calls in probability streams:  3000 / 4300
# Detecting calls in probability streams:  4000 / 4300
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 4300
# Detecting calls in probability streams:  1000 / 4300
# Detecting calls in probability streams:  2000 / 4300
# Detecting calls in probability streams:  3000 / 4300
# Detecting calls in probability streams:  4000 / 4300
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 4300
# Detecting calls in probability streams:  1000 / 4300
# Detecting calls in probability streams:  2000 / 4300
# Detecting calls in probability streams:  3000 / 4300
# Detecting calls in probability streams:  4000 / 4300
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 4300
# Detecting calls in probability streams:  1000 / 4300
# Detecting calls in probability streams:  2000 / 4300
# Detecting calls in probability streams:  3000 / 4300
# Detecting calls in probability streams:  4000 / 4300
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 4300
# Detecting calls in probability streams:  1000 / 4300
# Detecting calls in probability streams:  2000 / 4300
# Detecting calls in probability streams:  3000 / 4300
# Detecting calls in probability streams:  4000 / 4300
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 4300
# Detecting calls in probability streams:  1000 / 4300
# Detecting calls in probability streams:  2000 / 4300
# Detecting calls in probability streams:  3000 / 4300
# Detecting calls in probability streams:  4000 / 4300
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 4300
# Detecting calls in probability streams:  1000 / 4300
# Detecting calls in probability streams:  2000 / 4300
# Detecting calls in probability streams:  3000 / 4300
# Detecting calls in probability streams:  4000 / 4300
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 4300
# Detecting calls in probability streams:  1000 / 4300
# Detecting calls in probability streams:  2000 / 4300
# Detecting calls in probability streams:  3000 / 4300
# Detecting calls in probability streams:  4000 / 4300
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 4300
# Detecting calls in probability streams:  1000 / 4300
# Detecting calls in probability streams:  2000 / 4300
# Detecting calls in probability streams:  3000 / 4300
# Detecting calls in probability streams:  4000 / 4300
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 5740
# Detecting calls in probability streams:  1000 / 5740
# Detecting calls in probability streams:  2000 / 5740
# Detecting calls in probability streams:  3000 / 5740
# Detecting calls in probability streams:  4000 / 5740
# Detecting calls in probability streams:  5000 / 5740
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 5740
# Detecting calls in probability streams:  1000 / 5740
# Detecting calls in probability streams:  2000 / 5740
# Detecting calls in probability streams:  3000 / 5740
# Detecting calls in probability streams:  4000 / 5740
# Detecting calls in probability streams:  5000 / 5740
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 5740
# Detecting calls in probability streams:  1000 / 5740
# Detecting calls in probability streams:  2000 / 5740
# Detecting calls in probability streams:  3000 / 5740
# Detecting calls in probability streams:  4000 / 5740
# Detecting calls in probability streams:  5000 / 5740
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 5740
# Detecting calls in probability streams:  1000 / 5740
# Detecting calls in probability streams:  2000 / 5740
# Detecting calls in probability streams:  3000 / 5740
# Detecting calls in probability streams:  4000 / 5740
# Detecting calls in probability streams:  5000 / 5740
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 5740
# Detecting calls in probability streams:  1000 / 5740
# Detecting calls in probability streams:  2000 / 5740
# Detecting calls in probability streams:  3000 / 5740
# Detecting calls in probability streams:  4000 / 5740
# Detecting calls in probability streams:  5000 / 5740
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 5740
# Detecting calls in probability streams:  1000 / 5740
# Detecting calls in probability streams:  2000 / 5740
# Detecting calls in probability streams:  3000 / 5740
# Detecting calls in probability streams:  4000 / 5740
# Detecting calls in probability streams:  5000 / 5740
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 5740
# Detecting calls in probability streams:  1000 / 5740
# Detecting calls in probability streams:  2000 / 5740
# Detecting calls in probability streams:  3000 / 5740
# Detecting calls in probability streams:  4000 / 5740
# Detecting calls in probability streams:  5000 / 5740
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 5740
# Detecting calls in probability streams:  1000 / 5740
# Detecting calls in probability streams:  2000 / 5740
# Detecting calls in probability streams:  3000 / 5740
# Detecting calls in probability streams:  4000 / 5740
# Detecting calls in probability streams:  5000 / 5740
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 5740
# Detecting calls in probability streams:  1000 / 5740
# Detecting calls in probability streams:  2000 / 5740
# Detecting calls in probability streams:  3000 / 5740
# Detecting calls in probability streams:  4000 / 5740
# Detecting calls in probability streams:  5000 / 5740
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 5740
# Detecting calls in probability streams:  1000 / 5740
# Detecting calls in probability streams:  2000 / 5740
# Detecting calls in probability streams:  3000 / 5740
# Detecting calls in probability streams:  4000 / 5740
# Detecting calls in probability streams:  5000 / 5740
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 5740
# Detecting calls in probability streams:  1000 / 5740
# Detecting calls in probability streams:  2000 / 5740
# Detecting calls in probability streams:  3000 / 5740
# Detecting calls in probability streams:  4000 / 5740
# Detecting calls in probability streams:  5000 / 5740
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 5740
# Detecting calls in probability streams:  1000 / 5740
# Detecting calls in probability streams:  2000 / 5740
# Detecting calls in probability streams:  3000 / 5740
# Detecting calls in probability streams:  4000 / 5740
# Detecting calls in probability streams:  5000 / 5740
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 5740
# Detecting calls in probability streams:  1000 / 5740
# Detecting calls in probability streams:  2000 / 5740
# Detecting calls in probability streams:  3000 / 5740
# Detecting calls in probability streams:  4000 / 5740
# Detecting calls in probability streams:  5000 / 5740
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 5740
# Detecting calls in probability streams:  1000 / 5740
# Detecting calls in probability streams:  2000 / 5740
# Detecting calls in probability streams:  3000 / 5740
# Detecting calls in probability streams:  4000 / 5740
# Detecting calls in probability streams:  5000 / 5740
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 5740
# Detecting calls in probability streams:  1000 / 5740
# Detecting calls in probability streams:  2000 / 5740
# Detecting calls in probability streams:  3000 / 5740
# Detecting calls in probability streams:  4000 / 5740
# Detecting calls in probability streams:  5000 / 5740
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 5740
# Detecting calls in probability streams:  1000 / 5740
# Detecting calls in probability streams:  2000 / 5740
# Detecting calls in probability streams:  3000 / 5740
# Detecting calls in probability streams:  4000 / 5740
# Detecting calls in probability streams:  5000 / 5740
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 5740
# Detecting calls in probability streams:  1000 / 5740
# Detecting calls in probability streams:  2000 / 5740
# Detecting calls in probability streams:  3000 / 5740
# Detecting calls in probability streams:  4000 / 5740
# Detecting calls in probability streams:  5000 / 5740
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 5740
# Detecting calls in probability streams:  1000 / 5740
# Detecting calls in probability streams:  2000 / 5740
# Detecting calls in probability streams:  3000 / 5740
# Detecting calls in probability streams:  4000 / 5740
# Detecting calls in probability streams:  5000 / 5740
# *****************************************************************
# *****************************************************************
# File being processed : /home/kiran/Documents/MPI-Server/EAS_shared/meerkat/archive/rawdata/MEERKAT_RAW_DATA/2019/HM_2019_2/COLLAR/AUDIO/HM_VHMM017_RSTB_R23_20190708-20190720/HM_VHMM017_RSTB_R23_20190708-20190720_file_6_(2019_07_12-11_44_59)_125944.wav
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.5
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-158936521a6b> in <module>
#     478                                               low_thr=low_thr,
#     479                                               high_thr=high_thr,
# --> 480                                               debug=1)
#     481
#     482                     #in case the dataset was just noise, still create an empty placeholder to merge
#
# ~/Documents/github/CCAS_ML/postprocess/merge_predictions_functions.py in merge_p(probabilities, labels, starttime, frameadv_s, specadv_s, low_thr, high_thr, debug)
#      44     # Get number of score matrices, number of categories and frames per score matrix (assume uniform)
#      45     N = len(probabilities)
# ---> 46     (framesN, catsN)= probabilities[0].shape
#      47
#      48     specadv_n = int(specadv_s / frameadv_s)
#
# IndexError: list index out of range

# %%
# Redo the testing because of problem with start column not being in order

#---------------------------------------------------------------------------------------------
#---------------------------------------------------------------------------------------------
## THRESHOLDING
#---------------------------------------------------------------------------------------------
#---------------------------------------------------------------------------------------------

## Predict over the test files
#---------------------------------------------------------------------------------------------
skipped_files = []

# we only do one file in this example to avoid it running too long
for file_ID in testing_filenames:
    # file_ID = testing_filenames[0] # for testing purposes only

    # subset the label table to only use that one file
    label_table = testing_label_table[testing_label_table['wavFileName'].isin([file_ID])]
    label_table = label_table.sort_values(by=['Start']).reset_index()
    # Find the file ID name i.e. remove the extention
    file_ID = file_ID.split(".")[0] 
    # find the matching audio for the label data
    audio_path = label_table["wav_path"][0]   

    print("*****************************************************************")   
    print("*****************************************************************") 
    print ("File being processed : " + audio_path)    

    # find the start and stop  of the labelling periods (also using skipon/skipoff)
    loop_table = label_table.loc[label_table["Label"].str.contains('|'.join(label_for_startstop), regex=True, case = False), ["Label","Start"]]
    loop_times = list(loop_table["Start"])

    # Make sure that the file contains the right number of start and stops, otherwise go to the next file
    if len(loop_times)%2 != 0:
        print("!!!!!!!!!!!!!!!!")
        warnings.warn("There is a missing start or stop in this file and it has been skipped: " + audio_path)
        skipped_files.append(file_ID)
        continue 

    if len(loop_times) == 0:
        print("!!!!!!!!!!!!!!!!")
        warnings.warn("There is a missing start or stop in this file and it has been skipped: " + audio_path)
        skipped_files.append(file_ID)
        continue 

    # save the label_table
    save_label_table_filename = file_ID + "_LABEL_TABLE.txt"
    label_table.to_csv(os.path.join(save_label_table_test_path, save_label_table_filename), 
                        header=True, index=None, sep=';')

    # load the audio data
    y, sr = librosa.load(audio_path, sr=None, mono=False)

    # # Reshaping the Audio file (mono) to deal with all wav files similarly
    # if y.ndim == 1:
    #     y = y.reshape(1, -1)

    # # Implement this for acc data
    # for ch in range(y.shape[0]):
    # ch=0
    # y_sub = y[:,ch]
    y_sub = y

    # loop through every labelling start based on skipon/off within this loop_table
    for loopi in range(0, int(len(loop_times)), 2):
        # loopi = 0
        fromi =  loop_times[loopi]
        #toi = fromi + 5
        toi = loop_times[int(loopi + 1)] # define the end of the labelling periods

        calltype_pred_list = []
        callpresence_pred_list = []
        # if the file exists, load it
        if os.path.exists(os.path.join(save_pred_stack_test_path, file_ID + '_CALLTYPE_PRED_STACK_' + str(fromi) + '-' + str(toi) + '.npy')): 
            calltype_pred_list = np.load( os.path.join(save_pred_stack_test_path, file_ID + '_CALLTYPE_PRED_STACK_' + str(fromi) + '-' + str(toi) + '.npy')) 
            callpresence_pred_list = np.load( os.path.join(save_pred_stack_test_path, file_ID + '_CALLPRESENCE_PRED_STACK_' + str(fromi) + '-' + str(toi) + '.npy'))


        # if the file is incomplete or non existant redo it
        if (len(np.arange(fromi, toi, slide)) - sum(np.arange(fromi, toi, slide)+spec_window_size > toi)) != (len(calltype_pred_list)):

            for spectro_slide in np.arange(fromi, toi, slide):                
                # spectro_slide = fromi
                start = round(spectro_slide,3)
                stop = round(spectro_slide + spec_window_size, 3)

                # ignore cases where the window is larger than what is labelled (e.g. at the end)
                if stop <= toi:

                    #generate the spectrogram
                    spectro = pre.generate_mel_spectrogram(y=y_sub, sr=sr, start=start, stop=stop, 
                                                            n_mels = n_mels, window='hann', 
                                                            fft_win= fft_win, fft_hop = fft_hop, 
                                                            normalise = True)

                    # transpose it and put it in a format that works with the NN
                    spec = spectro.T
                    spec = spec[np.newaxis, ..., np.newaxis]  

                    # generate a mask (as a placeholder) but don't mask anything as we are predicting and want to include other
                    mask = np.asarray([True for i in range(spectro.shape[1])])
                    mask = mask[np.newaxis,...]

                    # generate the prediction
                    pred = RNN_model.predict([spec,mask])

                    # add this prediction to the stack that will be used to generate the predictions table
                    if is_forked:
                        calltype_pred_list.append(np.squeeze(pred[0]))
                        callpresence_pred_list.append(np.squeeze(pred[1]))
                    else:
                        calltype_pred_list.append(np.squeeze(pred))

            # save the prediction stacks
            np.save( os.path.join(save_pred_stack_test_path, file_ID + '_CALLTYPE_PRED_STACK_' + str(fromi) + '-' + str(toi) + '.npy'), calltype_pred_list)
            with open(os.path.join(save_pred_stack_test_path, file_ID + '_CALLTYPE_PRED_STACK_' + str(fromi) + '-' + str(toi) + '.txt'), "w") as f:
                for row in calltype_pred_list:
                    f.write(str(row) +"\n")
            if is_forked:      
                np.save( os.path.join(save_pred_stack_test_path, file_ID + '_CALLPRESENCE_PRED_STACK_' + str(fromi) + '-' + str(toi) + '.npy'), callpresence_pred_list)
                with open(os.path.join(save_pred_stack_test_path, file_ID + '_CALLPRESENCE_PRED_STACK_' + str(fromi) + '-' + str(toi) + '.txt'), "w") as f:
                    for row in callpresence_pred_list:
                        f.write(str(row) +"\n")

        # Loop through different sets of thresholds
        for low_thr in [0.05,0.1,0.2]:
            for high_thr in [0.5,0.6,0.7,0.8,0.9,0.95]: 

                # make sure it doesnt generate a 0.00098982374957839486 type number
                low_thr = round(low_thr,2)                               
                high_thr = round(high_thr,2)

                # stop the loop if the low threshold is bigger than the high threshold
                if low_thr >= high_thr:
                    continue

                save_pred_table_filename = file_ID + "_CALLTYPE_PRED_TABLE_thr_" + str(low_thr) + "-" + str(high_thr) + ".txt"

                # if the file exists, pass to the next iteration of the loop
                #if os.path.exists(os.path.join(save_pred_table_test_path, save_pred_table_filename)):
                #    continue

                print("*****************************************************************") 
                print ("Low Threshold: " + str(low_thr))    
                print ("High Threshold: " + str(high_thr))  

                #----------------------------------------------------------------------------
                # Compile the predictions for each on/off labelling chunk
                detections = ppm.merge_p(probabilities = calltype_pred_list, 
                                          labels=list(call_types.keys()),
                                          starttime = 0, 
                                          frameadv_s = fft_hop, 
                                          specadv_s = slide,
                                          low_thr=low_thr, 
                                          high_thr=high_thr, 
                                          debug=1)

                #in case the dataset was just noise, still create an empty placeholder to merge
                if len(detections) == 0:  
                    detections = pd.DataFrame(columns = ['category', 'start', 'end', 'scores'])

                # create an empty dataset
                pred_table = pd.DataFrame() 

                #convert these detections to a predictions table                
                table = pd.DataFrame(detections)
                table["Label"] = table["category"]
                table["Start"] = round(table["start"]*fft_hop + fromi, 3) #table["start"].apply(Decimal)*Decimal(fft_hop) + Decimal(fromi)
                table["Duration"] = round( (table["end"]-table["start"])*fft_hop, 3) #(table["end"].apply(Decimal)-table["start"].apply(Decimal))*Decimal(fft_hop)
                table["End"] = round(table["end"]*fft_hop + fromi, 3) #table["Start"].apply(Decimal) + table["Duration"].apply(Decimal)

                # keep only the useful columns    
                table = table[["Label","Start","Duration", "End", "scores"]]  

                # Add a row which stores the start of the labelling period
                row_start = pd.DataFrame()
                row_start.loc[0,'Label'] = list(loop_table["Label"])[loopi]
                row_start.loc[0,'Start'] = fromi
                row_start.loc[0,'Duration'] = 0
                row_start.loc[0,'End'] = fromi 
                row_start.loc[0,'scores'] = [0] 

                # Add a row which stores the end of the labelling period
                row_stop = pd.DataFrame()
                row_stop.loc[0,'Label'] = list(loop_table["Label"])[int(loopi + 1)]
                row_stop.loc[0,'Start'] = toi
                row_stop.loc[0,'Duration'] = 0
                row_stop.loc[0,'End'] = toi 
                row_stop.loc[0,'scores'] = [0]       

                # add the true false columns based on the call types dictionary
                for true_label in call_types:
                    table[true_label] = False
                    row_start[true_label] = False
                    row_stop[true_label] = False
                    for old_label in call_types[true_label]:
                        table.loc[table["Label"].str.contains(old_label, regex=True, case = False), true_label] = True

                # make sure start and stop are not classified as calls
                row_start[label_for_noise] = True
                row_stop[label_for_noise] = True

                # put these rows to the label table
                table = pd.concat([row_start, table, row_stop]) 

                # add this table to the overall predictions table for that collar
                pred_table = pd.concat([pred_table, table ])

                # for each on/off labelling chunk, we can save the prediction and append it to the previous chunk
                if loopi == 0:                    
                    # for the first chunck keep the header, but not when appending later. Also, overwrite old runs
                    pred_table.to_csv(os.path.join(save_pred_table_test_path, save_pred_table_filename), 
                                      header=True, index=None, sep=';', mode = 'w')
                else:
                    pred_table.to_csv(os.path.join(save_pred_table_test_path, save_pred_table_filename), 
                                      header=None, index=None, sep=';', mode = 'a')

'''
# # load the saved file
# with open(os.path.join(save_pred_stack_test_path, file_ID + '_PRED_STACK.txt')) as f:
#     content = f.readlines()
# # remove whitespace characters like `\n` at the end of each line
# pred_list = [x.strip() for x in content] 


# #or
# pred_list = np.load( os.path.join(save_pred_stack_test_path, file_ID + '_PRED_STACK.npy'))
# '''

# save the files that were skipped
print(skipped_files)

# save a copy of the training and testing diles
with open(os.path.join(save_model_path, "skipped_testing_files.txt"), "w") as f:
    for s in skipped_files:
        f.write(str(s) +"\n")


#---------------------------------------------------------------------------------------------
#---------------------------------------------------------------------------------------------
## EVALUATE
#---------------------------------------------------------------------------------------------
#---------------------------------------------------------------------------------------------

# because of new file format, need to only keep certain columns so that the evaluation metrics work with the label tables
column_names = ["Label","Start","Duration","End"]
column_names.extend(list(testing_label_dict.keys()))
for file in label_list :
    df = pd.read_csv(file, delimiter=';') 
    # df = df.drop_duplicates(keep=False)
    df = df[column_names]
    df.to_csv(file, header=True, index=None, sep=';', mode = 'w')


eval_analysis = "call_type_by_call_type"
save_metrics_path_eval = os.path.join(save_metrics_path, eval_analysis)

file_ID_list = [file_ID.split(".")[0] for file_ID in testing_filenames if file_ID not in skipped_files]
label_list =  [os.path.join(save_label_table_test_path,file_ID.split(".")[0]  + "_LABEL_TABLE.txt" ) for file_ID in file_ID_list]


for low_thr in [0.05,0.1,0.2]:
    for high_thr in [0.5,0.6,0.7,0.8,0.9,0.95]: 

        low_thr = round(low_thr,2)                               
        high_thr = round(high_thr,2) 
        print("**********************************************************")
        print("Evaluating thresholds: " + str(low_thr) + "-" + str(high_thr))
        print("**********************************************************")

        if low_thr >= high_thr:
            continue

        pred_list = [os.path.join(save_pred_table_test_path,file_ID.split(".")[0]  + "_CALLTYPE_PRED_TABLE_thr_" + str(low_thr) + "-" + str(high_thr) + ".txt" ) for file_ID in file_ID_list ]
        evaluation = metrics.Evaluate(label_list = label_list, 
                                      prediction_list = pred_list, 
                                      noise_label = "noise", 
                                      IoU_threshold = 0.2, 
                                      call_analysis = eval_analysis, 
                                      GT_proportion_cut = 0.01, 
                                      no_call = no_call,
                                      headers = set(['Label', 'Duration', 'Start', 'End']),
                                      nonfoc_tags =["NONFOC", "nf", "*"]
                                     ) # 0.99 is 0.5
        output, skipped_calls = evaluation.main()        
        print(str(skipped_calls) + " calls were skipped in total")

        to_pickle = ["Time_Difference", "Matching_Table", "Prediction_Indices", "Label_Indices" , "_Match"]
        for metric in output.keys():
            if any(ext in metric for ext in to_pickle):
                filename = "PRED_TABLE_thr_" + str(low_thr) + "-" + str(high_thr) + "_" +str(metric) +".p"
                with open(os.path.join(save_metrics_path_eval, filename), 'wb') as fp:
                    pickle.dump(output[metric], fp) 
            else:
                filename = "PRED_TABLE_thr_" + str(low_thr) + "-" + str(high_thr) + "_" +str(metric) +".csv"
                output[metric].to_csv(os.path.join(save_metrics_path_eval, filename))    


#--------------------------------------------------------------------------------------------
# PLOT A PREDICTION
#--------------------------------------------------------------------------------------------


pool = audiopool.AudioPool() 

# Find a call
call = testing_label_dict["sn"].iloc[15]
label_subset = testing_label_table[testing_label_table['wav_path'].isin([call["wav_path"]])]

# set the labels
label_list = list(call_types.keys())
if other_ignored_in_training:
    label_list.remove(label_for_other)


# randomise the start a little so the new spectrogram will be a little different from the old
# if the call is very long have a large range to draw the window
if call["Duration"]>= spec_window_size:
    call_start = round(float(np.random.uniform(call["Start"]-spec_window_size/2, 
                                               call["End"]-spec_window_size/2, 1)), 3)
# if the call is short call, draw it from somewhere
else:
    call_start = round(float(np.random.uniform((call["Start"]+call["End"])/2-spec_window_size, 
                                               (call["Start"]+call["End"])/2)), 3)

# load in a subsection of the spectrogram
# y, sr = librosa.load(call["wav_path"], sr=None, mono=False,
#                      offset = call_start, duration =self.spec_window_size)
y = pool.get_seconds(call["wav_path"], call_start, spec_window_size)
sr = pool.get_Fs(call["wav_path"])

call_stop = round(call_start + spec_window_size,3 )

# have it as an array
data_subset = np.asfortranarray(y)

#get the spectrogram
spectrogram = pre.generate_mel_spectrogram(data_subset, sr, 0, spec_window_size, 
                                           n_mels, window, fft_win , fft_hop , normalise)

# generate label
label = pre.create_label_matrix(label_subset, 
                                spectrogram, 
                                testing_label_dict, 
                                call_start, 
                                call_stop, 
                                label_for_noise, 
                                label_for_other, 
                                other_ignored_in_training)
# plot spectrogram
plt.figure(figsize=(10,4))
#plt.subplot(411)
yaxis = range(0, np.flipud(spectrogram).shape[0]+1)
xaxis = range(0, np.flipud(spectrogram).shape[1]+1)
plt.xticks(np.arange(0, np.flipud(label).shape[1]+1,50),
           list(label.columns[np.arange(0, np.flipud(label).shape[1]+1,50)]))
librosa.display.specshow(spectrogram,  y_axis='mel', x_coords = label.columns)#, x_axis= "time",sr=sr, x_coords = label.columns)
plt.ylabel('Frequency (Hz)')
plt.clim(-35, 35)
plt.colorbar(format='%+2.0f dB')
plt.show()

# plot LABEL
#plt.subplot(412)
#print(label.shape)
plt.figure(figsize=(10, 4))
xaxis = range(0, np.flipud(label).shape[1]+1)
yaxis = range(0, np.flipud(label).shape[0]+1)
plt.yticks(np.arange(0.5, len(label_list)+0.5 ,1 ),reversed(label_list))
plt.xticks(np.arange(0, np.flipud(label).shape[1]+1,50),
           list(label.columns[np.arange(0, np.flipud(label).shape[1]+1,50)]))
plt.pcolormesh(xaxis, yaxis, np.flipud(label))
plt.clim(0, 1)
plt.xlabel('Time (s)')
plt.ylabel('Calltype')
plt.colorbar(label="Label")
plt.show()

if is_forked:
    # generate matrix of call/not call
    callmat = pre.create_call_matrix(label_subset, spectrogram, call_start, call_stop, 
                                      label_for_noise, label_for_other, other_ignored_in_training)

# prediction
# transpose it and put it in a format that works with the NN
spec = spectrogram.T
spec = spec[np.newaxis, ..., np.newaxis]  

# generate a mask (as a placeholder) but don't mask anything as we are predicting and want to include other
mask = np.asarray([True for i in range(spectrogram.shape[1])])
mask = mask[np.newaxis,...]

# generate the prediction
pred = RNN_model.predict([spec,mask])

# add this prediction to the stack that will be used to generate the predictions table
if is_forked:
    calltype_pred= pred[0]
    callpresence_pred = pred[1]   
else:
    calltype_pred = pred

pred = calltype_pred[0].T

#print(pred.shape)
#plot calltype prediction
plt.figure(figsize=(10, 4))
xaxis = range(0, np.flipud(label).shape[1]+1)
yaxis = range(0, np.flipud(label).shape[0]+1)
plt.yticks(np.arange(0.5, len(label_list)+0.5 ,1 ),reversed(label_list))
plt.xticks(np.arange(0, np.flipud(label).shape[1]+1,50),
           list(label.columns[np.arange(0, np.flipud(label).shape[1]+1,50)]))
plt.pcolormesh(xaxis, yaxis, np.flipud(pred))
plt.clim(0, 1)
plt.xlabel('Time (s)')
plt.ylabel('Calltype Prediction')
plt.colorbar(label="Label")
plt.show()


if is_forked:  
    # plot call matrix
    #plt.subplot(413)
    plt.figure(figsize=(10, 1))
    xaxis = range(0, np.flipud(label).shape[1]+1)
    yaxis = range(0, np.flipud(callmat).shape[0]+1)
    plt.yticks(np.arange(0.5, callmat.shape[0]+0.5 ,1 ), reversed(callmat.index.values))
    plt.xticks(np.arange(0, np.flipud(label).shape[1]+1,50),
               list(label.columns[np.arange(0, np.flipud(label).shape[1]+1,50)]))
    plt.pcolormesh(xaxis, yaxis, np.flipud(callmat))
    plt.clim(0, 1)
    plt.xlabel('Time (s)')
    plt.ylabel('Call / No Call')
    plt.colorbar(label="Label")
    plt.show()

    pred = callpresence_pred[0].T
    #plot prediction
    plt.figure(figsize=(10, 1))
    xaxis = range(0, np.flipud(label).shape[1]+1)
    yaxis = range(0, np.flipud(callmat).shape[0]+1)
    plt.yticks(np.arange(0.5, callmat.shape[0]+0.5 ,1 ), reversed(callmat.index.values))
    plt.xticks(np.arange(0, np.flipud(label).shape[1]+1,50),
               list(label.columns[np.arange(0, np.flipud(label).shape[1]+1,50)]))
    plt.pcolormesh(xaxis, yaxis, np.flipud(pred))
    plt.clim(0, 1)
    plt.xlabel('Time (s)')
    plt.ylabel('Call / No Call prediction')
    plt.colorbar(label="Label")
    plt.show()

#--------------------------------------------------------------------------------------------
# CONFUSION MATRIX
#--------------------------------------------------------------------------------------------

# loop over the threaholdsf
for low_thr in [0.1]:#[0.05,0.1,0.2]:
    for high_thr in [0.6]:#[0.5,0.6,0.7,0.8,0.9,0.95]:         
        #########################################
        # FORMAT 

        low_thr = round(low_thr,2)                               
        high_thr = round(high_thr,2) 

        if low_thr >= high_thr:
            continue
        if low_thr == 0.1 and high_thr == 0.2:
            continue

        if eval_analysis == "normal":
            confusion_filename = os.path.join(save_metrics_path_eval, "PRED_TABLE_thr_" + str(low_thr) + "-" + str(high_thr) + '_foc_Confusion_Matrix.csv')
        else:
            confusion_filename = os.path.join(save_metrics_path_eval, "PRED_TABLE_thr_" + str(low_thr) + "-" + str(high_thr) + '__Confusion_Matrix.csv')
        with open(confusion_filename, newline='') as csvfile:
            array = list(csv.reader(csvfile))

        df_cm = pd.DataFrame(array) #, range(6), range(6))    

        # get rid of the weird indentations and make rows and columns as names
        new_col = df_cm.iloc[0] # grab the first row for the header
        df_cm = df_cm[1:] # take the data less the header row
        df_cm.columns = new_col # set the header row as the df header    
        new_row = df_cm['']
        df_cm = df_cm.drop('', 1)
        df_cm.index = new_row
        df_cm.index.name= None
        df_cm.columns.name= None

        # # replace FP and FN with noise
        df_cm['noise'] = df_cm['FN'] 
        #df_cm.loc['noise']=df_cm.loc['FP']

        # remove FP and FN
        df_cm = df_cm.drop("FN", axis=1)
        #df_cm = df_cm.drop("FP", axis=0)

        df_cm = df_cm.apply(pd.to_numeric)

        # Raw confusion matrix
        df_cm = df_cm[list(testing_label_dict.keys())]
        df_cm = df_cm.reindex(list(testing_label_dict.keys()))       

        #########################################
        # CALCULATE

        # Recall confusion matrix
        df_recall = df_cm.div(df_cm.sum(axis=1), axis=0).round(2)#pd.DataFrame(df_cm.values / df_cm.sum(axis=1).values).round(2)

        # Proportion of calls for confusion matrix
        call_len = list()
        for i in testing_label_dict.keys():
            call_len.append(testing_label_dict[i].shape[0])
        # add noise at the end
        call_len[-1] = df_cm.sum(axis=1)[-1]

        #proportion of calls
        df_prop = df_cm.div(call_len, axis=0).round(2)#pd.DataFrame(df_cm.values / df_cm.sum(axis=1).values).round(2)

        #########################################
        # PLOT

        #multi figure parameters
        fig,((ax1,ax2,ax3)) = plt.subplots(1,3, figsize=(20,5))
        fig.suptitle(str(low_thr) + " - " + str(high_thr))

        # plot raw
        sn.set(font_scale=1.1) # for label size
        sn.heatmap((df_cm+1), annot=df_cm, fmt='g',norm = LogNorm(), annot_kws={"size": 10}, ax= ax1) # font size
        ax1.set_title("Raw")              

        # plot recall
        sn.set(font_scale=1.1) # for label size
        sn.heatmap((df_recall), annot=True, fmt='g', annot_kws={"size": 10}, ax= ax2) # font size
        ax2.set_title("Recall" )

        # plot proportion of calls
        sn.set(font_scale=1.1) # for label size
        sn.heatmap((df_prop), annot=True, fmt='g', annot_kws={"size": 10}, ax= ax3) # font size
        ax3.set_title("Call Prop")

        # Save 3 panels
        plt.savefig(os.path.join(save_metrics_path, eval_analysis, "Confusion_mat_thr_" + str(low_thr) + "-" + str(high_thr) + '.png'))
        plt.show()
        plt.clf()
# Out:
# *****************************************************************
# *****************************************************************
# File being processed : /home/kiran/Documents/MPI-Server/EAS_shared/meerkat/archive/rawdata/MEERKAT_RAW_DATA/2019/HM_2019_2/COLLAR/AUDIO/HM_VHMF001_HTB_R20_20190707-20190719/HM_VHMF001_HTB_R20_20190707-20190719_file_6_(2019_07_12-11_44_59)_125944.wav
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 529
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 529
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 529
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 529
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 529
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 529
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 529
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 529
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 529
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 529
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 529
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 529
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 529
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 529
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 529
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 529
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 529
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 529
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 3644
# Detecting calls in probability streams:  1000 / 3644
# Detecting calls in probability streams:  2000 / 3644
# Detecting calls in probability streams:  3000 / 3644
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 3644
# Detecting calls in probability streams:  1000 / 3644
# Detecting calls in probability streams:  2000 / 3644
# Detecting calls in probability streams:  3000 / 3644
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 3644
# Detecting calls in probability streams:  1000 / 3644
# Detecting calls in probability streams:  2000 / 3644
# Detecting calls in probability streams:  3000 / 3644
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 3644
# Detecting calls in probability streams:  1000 / 3644
# Detecting calls in probability streams:  2000 / 3644
# Detecting calls in probability streams:  3000 / 3644
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 3644
# Detecting calls in probability streams:  1000 / 3644
# Detecting calls in probability streams:  2000 / 3644
# Detecting calls in probability streams:  3000 / 3644
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 3644
# Detecting calls in probability streams:  1000 / 3644
# Detecting calls in probability streams:  2000 / 3644
# Detecting calls in probability streams:  3000 / 3644
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 3644
# Detecting calls in probability streams:  1000 / 3644
# Detecting calls in probability streams:  2000 / 3644
# Detecting calls in probability streams:  3000 / 3644
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 3644
# Detecting calls in probability streams:  1000 / 3644
# Detecting calls in probability streams:  2000 / 3644
# Detecting calls in probability streams:  3000 / 3644
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 3644
# Detecting calls in probability streams:  1000 / 3644
# Detecting calls in probability streams:  2000 / 3644
# Detecting calls in probability streams:  3000 / 3644
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 3644
# Detecting calls in probability streams:  1000 / 3644
# Detecting calls in probability streams:  2000 / 3644
# Detecting calls in probability streams:  3000 / 3644
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 3644
# Detecting calls in probability streams:  1000 / 3644
# Detecting calls in probability streams:  2000 / 3644
# Detecting calls in probability streams:  3000 / 3644
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 3644
# Detecting calls in probability streams:  1000 / 3644
# Detecting calls in probability streams:  2000 / 3644
# Detecting calls in probability streams:  3000 / 3644
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 3644
# Detecting calls in probability streams:  1000 / 3644
# Detecting calls in probability streams:  2000 / 3644
# Detecting calls in probability streams:  3000 / 3644
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 3644
# Detecting calls in probability streams:  1000 / 3644
# Detecting calls in probability streams:  2000 / 3644
# Detecting calls in probability streams:  3000 / 3644
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 3644
# Detecting calls in probability streams:  1000 / 3644
# Detecting calls in probability streams:  2000 / 3644
# Detecting calls in probability streams:  3000 / 3644
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 3644
# Detecting calls in probability streams:  1000 / 3644
# Detecting calls in probability streams:  2000 / 3644
# Detecting calls in probability streams:  3000 / 3644
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 3644
# Detecting calls in probability streams:  1000 / 3644
# Detecting calls in probability streams:  2000 / 3644
# Detecting calls in probability streams:  3000 / 3644
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 3644
# Detecting calls in probability streams:  1000 / 3644
# Detecting calls in probability streams:  2000 / 3644
# Detecting calls in probability streams:  3000 / 3644
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 15
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 15
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 15
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 15
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 15
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 15
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 15
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 15
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 15
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 15
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 15
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 15
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 15
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 15
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 15
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 15
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 15
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 15
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 2822
# Detecting calls in probability streams:  1000 / 2822
# Detecting calls in probability streams:  2000 / 2822
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 2822
# Detecting calls in probability streams:  1000 / 2822
# Detecting calls in probability streams:  2000 / 2822
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 2822
# Detecting calls in probability streams:  1000 / 2822
# Detecting calls in probability streams:  2000 / 2822
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 2822
# Detecting calls in probability streams:  1000 / 2822
# Detecting calls in probability streams:  2000 / 2822
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 2822
# Detecting calls in probability streams:  1000 / 2822
# Detecting calls in probability streams:  2000 / 2822
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 2822
# Detecting calls in probability streams:  1000 / 2822
# Detecting calls in probability streams:  2000 / 2822
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 2822
# Detecting calls in probability streams:  1000 / 2822
# Detecting calls in probability streams:  2000 / 2822
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 2822
# Detecting calls in probability streams:  1000 / 2822
# Detecting calls in probability streams:  2000 / 2822
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 2822
# Detecting calls in probability streams:  1000 / 2822
# Detecting calls in probability streams:  2000 / 2822
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 2822
# Detecting calls in probability streams:  1000 / 2822
# Detecting calls in probability streams:  2000 / 2822
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 2822
# Detecting calls in probability streams:  1000 / 2822
# Detecting calls in probability streams:  2000 / 2822
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 2822
# Detecting calls in probability streams:  1000 / 2822
# Detecting calls in probability streams:  2000 / 2822
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 2822
# Detecting calls in probability streams:  1000 / 2822
# Detecting calls in probability streams:  2000 / 2822
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 2822
# Detecting calls in probability streams:  1000 / 2822
# Detecting calls in probability streams:  2000 / 2822
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 2822
# Detecting calls in probability streams:  1000 / 2822
# Detecting calls in probability streams:  2000 / 2822
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 2822
# Detecting calls in probability streams:  1000 / 2822
# Detecting calls in probability streams:  2000 / 2822
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 2822
# Detecting calls in probability streams:  1000 / 2822
# Detecting calls in probability streams:  2000 / 2822
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 2822
# Detecting calls in probability streams:  1000 / 2822
# Detecting calls in probability streams:  2000 / 2822
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 45
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 45
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 45
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 45
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 45
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 45
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 45
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 45
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 45
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 45
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 45
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 45
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 45
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 45
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 45
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 45
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 45
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 45
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 14565
# Detecting calls in probability streams:  1000 / 14565
# Detecting calls in probability streams:  2000 / 14565
# Detecting calls in probability streams:  3000 / 14565
# Detecting calls in probability streams:  4000 / 14565
# Detecting calls in probability streams:  5000 / 14565
# Detecting calls in probability streams:  6000 / 14565
# Detecting calls in probability streams:  7000 / 14565
# Detecting calls in probability streams:  8000 / 14565
# Detecting calls in probability streams:  9000 / 14565
# Detecting calls in probability streams:  10000 / 14565
# Detecting calls in probability streams:  11000 / 14565
# Detecting calls in probability streams:  12000 / 14565
# Detecting calls in probability streams:  13000 / 14565
# Detecting calls in probability streams:  14000 / 14565
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 14565
# Detecting calls in probability streams:  1000 / 14565
# Detecting calls in probability streams:  2000 / 14565
# Detecting calls in probability streams:  3000 / 14565
# Detecting calls in probability streams:  4000 / 14565
# Detecting calls in probability streams:  5000 / 14565
# Detecting calls in probability streams:  6000 / 14565
# Detecting calls in probability streams:  7000 / 14565
# Detecting calls in probability streams:  8000 / 14565
# Detecting calls in probability streams:  9000 / 14565
# Detecting calls in probability streams:  10000 / 14565
# Detecting calls in probability streams:  11000 / 14565
# Detecting calls in probability streams:  12000 / 14565
# Detecting calls in probability streams:  13000 / 14565
# Detecting calls in probability streams:  14000 / 14565
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 14565
# Detecting calls in probability streams:  1000 / 14565
# Detecting calls in probability streams:  2000 / 14565
# Detecting calls in probability streams:  3000 / 14565
# Detecting calls in probability streams:  4000 / 14565
# Detecting calls in probability streams:  5000 / 14565
# Detecting calls in probability streams:  6000 / 14565
# Detecting calls in probability streams:  7000 / 14565
# Detecting calls in probability streams:  8000 / 14565
# Detecting calls in probability streams:  9000 / 14565
# Detecting calls in probability streams:  10000 / 14565
# Detecting calls in probability streams:  11000 / 14565
# Detecting calls in probability streams:  12000 / 14565
# Detecting calls in probability streams:  13000 / 14565
# Detecting calls in probability streams:  14000 / 14565
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 14565
# Detecting calls in probability streams:  1000 / 14565
# Detecting calls in probability streams:  2000 / 14565
# Detecting calls in probability streams:  3000 / 14565
# Detecting calls in probability streams:  4000 / 14565
# Detecting calls in probability streams:  5000 / 14565
# Detecting calls in probability streams:  6000 / 14565
# Detecting calls in probability streams:  7000 / 14565
# Detecting calls in probability streams:  8000 / 14565
# Detecting calls in probability streams:  9000 / 14565
# Detecting calls in probability streams:  10000 / 14565
# Detecting calls in probability streams:  11000 / 14565
# Detecting calls in probability streams:  12000 / 14565
# Detecting calls in probability streams:  13000 / 14565
# Detecting calls in probability streams:  14000 / 14565
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 14565
# Detecting calls in probability streams:  1000 / 14565
# Detecting calls in probability streams:  2000 / 14565
# Detecting calls in probability streams:  3000 / 14565
# Detecting calls in probability streams:  4000 / 14565
# Detecting calls in probability streams:  5000 / 14565
# Detecting calls in probability streams:  6000 / 14565
# Detecting calls in probability streams:  7000 / 14565
# Detecting calls in probability streams:  8000 / 14565
# Detecting calls in probability streams:  9000 / 14565
# Detecting calls in probability streams:  10000 / 14565
# Detecting calls in probability streams:  11000 / 14565
# Detecting calls in probability streams:  12000 / 14565
# Detecting calls in probability streams:  13000 / 14565
# Detecting calls in probability streams:  14000 / 14565
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 14565
# Detecting calls in probability streams:  1000 / 14565
# Detecting calls in probability streams:  2000 / 14565
# Detecting calls in probability streams:  3000 / 14565
# Detecting calls in probability streams:  4000 / 14565
# Detecting calls in probability streams:  5000 / 14565
# Detecting calls in probability streams:  6000 / 14565
# Detecting calls in probability streams:  7000 / 14565
# Detecting calls in probability streams:  8000 / 14565
# Detecting calls in probability streams:  9000 / 14565
# Detecting calls in probability streams:  10000 / 14565
# Detecting calls in probability streams:  11000 / 14565
# Detecting calls in probability streams:  12000 / 14565
# Detecting calls in probability streams:  13000 / 14565
# Detecting calls in probability streams:  14000 / 14565
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 14565
# Detecting calls in probability streams:  1000 / 14565
# Detecting calls in probability streams:  2000 / 14565
# Detecting calls in probability streams:  3000 / 14565
# Detecting calls in probability streams:  4000 / 14565
# Detecting calls in probability streams:  5000 / 14565
# Detecting calls in probability streams:  6000 / 14565
# Detecting calls in probability streams:  7000 / 14565
# Detecting calls in probability streams:  8000 / 14565
# Detecting calls in probability streams:  9000 / 14565
# Detecting calls in probability streams:  10000 / 14565
# Detecting calls in probability streams:  11000 / 14565
# Detecting calls in probability streams:  12000 / 14565
# Detecting calls in probability streams:  13000 / 14565
# Detecting calls in probability streams:  14000 / 14565
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 14565
# Detecting calls in probability streams:  1000 / 14565
# Detecting calls in probability streams:  2000 / 14565
# Detecting calls in probability streams:  3000 / 14565
# Detecting calls in probability streams:  4000 / 14565
# Detecting calls in probability streams:  5000 / 14565
# Detecting calls in probability streams:  6000 / 14565
# Detecting calls in probability streams:  7000 / 14565
# Detecting calls in probability streams:  8000 / 14565
# Detecting calls in probability streams:  9000 / 14565
# Detecting calls in probability streams:  10000 / 14565
# Detecting calls in probability streams:  11000 / 14565
# Detecting calls in probability streams:  12000 / 14565
# Detecting calls in probability streams:  13000 / 14565
# Detecting calls in probability streams:  14000 / 14565
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 14565
# Detecting calls in probability streams:  1000 / 14565
# Detecting calls in probability streams:  2000 / 14565
# Detecting calls in probability streams:  3000 / 14565
# Detecting calls in probability streams:  4000 / 14565
# Detecting calls in probability streams:  5000 / 14565
# Detecting calls in probability streams:  6000 / 14565
# Detecting calls in probability streams:  7000 / 14565
# Detecting calls in probability streams:  8000 / 14565
# Detecting calls in probability streams:  9000 / 14565
# Detecting calls in probability streams:  10000 / 14565
# Detecting calls in probability streams:  11000 / 14565
# Detecting calls in probability streams:  12000 / 14565
# Detecting calls in probability streams:  13000 / 14565
# Detecting calls in probability streams:  14000 / 14565
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 14565
# Detecting calls in probability streams:  1000 / 14565
# Detecting calls in probability streams:  2000 / 14565
# Detecting calls in probability streams:  3000 / 14565
# Detecting calls in probability streams:  4000 / 14565
# Detecting calls in probability streams:  5000 / 14565
# Detecting calls in probability streams:  6000 / 14565
# Detecting calls in probability streams:  7000 / 14565
# Detecting calls in probability streams:  8000 / 14565
# Detecting calls in probability streams:  9000 / 14565
# Detecting calls in probability streams:  10000 / 14565
# Detecting calls in probability streams:  11000 / 14565
# Detecting calls in probability streams:  12000 / 14565
# Detecting calls in probability streams:  13000 / 14565
# Detecting calls in probability streams:  14000 / 14565
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 14565
# Detecting calls in probability streams:  1000 / 14565
# Detecting calls in probability streams:  2000 / 14565
# Detecting calls in probability streams:  3000 / 14565
# Detecting calls in probability streams:  4000 / 14565
# Detecting calls in probability streams:  5000 / 14565
# Detecting calls in probability streams:  6000 / 14565
# Detecting calls in probability streams:  7000 / 14565
# Detecting calls in probability streams:  8000 / 14565
# Detecting calls in probability streams:  9000 / 14565
# Detecting calls in probability streams:  10000 / 14565
# Detecting calls in probability streams:  11000 / 14565
# Detecting calls in probability streams:  12000 / 14565
# Detecting calls in probability streams:  13000 / 14565
# Detecting calls in probability streams:  14000 / 14565
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 14565
# Detecting calls in probability streams:  1000 / 14565
# Detecting calls in probability streams:  2000 / 14565
# Detecting calls in probability streams:  3000 / 14565
# Detecting calls in probability streams:  4000 / 14565
# Detecting calls in probability streams:  5000 / 14565
# Detecting calls in probability streams:  6000 / 14565
# Detecting calls in probability streams:  7000 / 14565
# Detecting calls in probability streams:  8000 / 14565
# Detecting calls in probability streams:  9000 / 14565
# Detecting calls in probability streams:  10000 / 14565
# Detecting calls in probability streams:  11000 / 14565
# Detecting calls in probability streams:  12000 / 14565
# Detecting calls in probability streams:  13000 / 14565
# Detecting calls in probability streams:  14000 / 14565
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 14565
# Detecting calls in probability streams:  1000 / 14565
# Detecting calls in probability streams:  2000 / 14565
# Detecting calls in probability streams:  3000 / 14565
# Detecting calls in probability streams:  4000 / 14565
# Detecting calls in probability streams:  5000 / 14565
# Detecting calls in probability streams:  6000 / 14565
# Detecting calls in probability streams:  7000 / 14565
# Detecting calls in probability streams:  8000 / 14565
# Detecting calls in probability streams:  9000 / 14565
# Detecting calls in probability streams:  10000 / 14565
# Detecting calls in probability streams:  11000 / 14565
# Detecting calls in probability streams:  12000 / 14565
# Detecting calls in probability streams:  13000 / 14565
# Detecting calls in probability streams:  14000 / 14565
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 14565
# Detecting calls in probability streams:  1000 / 14565
# Detecting calls in probability streams:  2000 / 14565
# Detecting calls in probability streams:  3000 / 14565
# Detecting calls in probability streams:  4000 / 14565
# Detecting calls in probability streams:  5000 / 14565
# Detecting calls in probability streams:  6000 / 14565
# Detecting calls in probability streams:  7000 / 14565
# Detecting calls in probability streams:  8000 / 14565
# Detecting calls in probability streams:  9000 / 14565
# Detecting calls in probability streams:  10000 / 14565
# Detecting calls in probability streams:  11000 / 14565
# Detecting calls in probability streams:  12000 / 14565
# Detecting calls in probability streams:  13000 / 14565
# Detecting calls in probability streams:  14000 / 14565
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 14565
# Detecting calls in probability streams:  1000 / 14565
# Detecting calls in probability streams:  2000 / 14565
# Detecting calls in probability streams:  3000 / 14565
# Detecting calls in probability streams:  4000 / 14565
# Detecting calls in probability streams:  5000 / 14565
# Detecting calls in probability streams:  6000 / 14565
# Detecting calls in probability streams:  7000 / 14565
# Detecting calls in probability streams:  8000 / 14565
# Detecting calls in probability streams:  9000 / 14565
# Detecting calls in probability streams:  10000 / 14565
# Detecting calls in probability streams:  11000 / 14565
# Detecting calls in probability streams:  12000 / 14565
# Detecting calls in probability streams:  13000 / 14565
# Detecting calls in probability streams:  14000 / 14565
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 14565
# Detecting calls in probability streams:  1000 / 14565
# Detecting calls in probability streams:  2000 / 14565
# Detecting calls in probability streams:  3000 / 14565
# Detecting calls in probability streams:  4000 / 14565
# Detecting calls in probability streams:  5000 / 14565
# Detecting calls in probability streams:  6000 / 14565
# Detecting calls in probability streams:  7000 / 14565
# Detecting calls in probability streams:  8000 / 14565
# Detecting calls in probability streams:  9000 / 14565
# Detecting calls in probability streams:  10000 / 14565
# Detecting calls in probability streams:  11000 / 14565
# Detecting calls in probability streams:  12000 / 14565
# Detecting calls in probability streams:  13000 / 14565
# Detecting calls in probability streams:  14000 / 14565
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 14565
# Detecting calls in probability streams:  1000 / 14565
# Detecting calls in probability streams:  2000 / 14565
# Detecting calls in probability streams:  3000 / 14565
# Detecting calls in probability streams:  4000 / 14565
# Detecting calls in probability streams:  5000 / 14565
# Detecting calls in probability streams:  6000 / 14565
# Detecting calls in probability streams:  7000 / 14565
# Detecting calls in probability streams:  8000 / 14565
# Detecting calls in probability streams:  9000 / 14565
# Detecting calls in probability streams:  10000 / 14565
# Detecting calls in probability streams:  11000 / 14565
# Detecting calls in probability streams:  12000 / 14565
# Detecting calls in probability streams:  13000 / 14565
# Detecting calls in probability streams:  14000 / 14565
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 14565
# Detecting calls in probability streams:  1000 / 14565
# Detecting calls in probability streams:  2000 / 14565
# Detecting calls in probability streams:  3000 / 14565
# Detecting calls in probability streams:  4000 / 14565
# Detecting calls in probability streams:  5000 / 14565
# Detecting calls in probability streams:  6000 / 14565
# Detecting calls in probability streams:  7000 / 14565
# Detecting calls in probability streams:  8000 / 14565
# Detecting calls in probability streams:  9000 / 14565
# Detecting calls in probability streams:  10000 / 14565
# Detecting calls in probability streams:  11000 / 14565
# Detecting calls in probability streams:  12000 / 14565
# Detecting calls in probability streams:  13000 / 14565
# Detecting calls in probability streams:  14000 / 14565
# *****************************************************************
# *****************************************************************
# File being processed : /home/kiran/Documents/MPI-Server/EAS_shared/meerkat/archive/rawdata/MEERKAT_RAW_DATA/2019/HM_2019_2/COLLAR/AUDIO/HM_VHMF015_RTTB_R05_20190707-20190719/HM_VHMF015_RTTB_R05_20190707-20190719_file_6_(2019_07_12-11_44_59)_125944.wav
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 7395
# Detecting calls in probability streams:  1000 / 7395
# Detecting calls in probability streams:  2000 / 7395
# Detecting calls in probability streams:  3000 / 7395
# Detecting calls in probability streams:  4000 / 7395
# Detecting calls in probability streams:  5000 / 7395
# Detecting calls in probability streams:  6000 / 7395
# Detecting calls in probability streams:  7000 / 7395
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 7395
# Detecting calls in probability streams:  1000 / 7395
# Detecting calls in probability streams:  2000 / 7395
# Detecting calls in probability streams:  3000 / 7395
# Detecting calls in probability streams:  4000 / 7395
# Detecting calls in probability streams:  5000 / 7395
# Detecting calls in probability streams:  6000 / 7395
# Detecting calls in probability streams:  7000 / 7395
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 7395
# Detecting calls in probability streams:  1000 / 7395
# Detecting calls in probability streams:  2000 / 7395
# Detecting calls in probability streams:  3000 / 7395
# Detecting calls in probability streams:  4000 / 7395
# Detecting calls in probability streams:  5000 / 7395
# Detecting calls in probability streams:  6000 / 7395
# Detecting calls in probability streams:  7000 / 7395
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 7395
# Detecting calls in probability streams:  1000 / 7395
# Detecting calls in probability streams:  2000 / 7395
# Detecting calls in probability streams:  3000 / 7395
# Detecting calls in probability streams:  4000 / 7395
# Detecting calls in probability streams:  5000 / 7395
# Detecting calls in probability streams:  6000 / 7395
# Detecting calls in probability streams:  7000 / 7395
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 7395
# Detecting calls in probability streams:  1000 / 7395
# Detecting calls in probability streams:  2000 / 7395
# Detecting calls in probability streams:  3000 / 7395
# Detecting calls in probability streams:  4000 / 7395
# Detecting calls in probability streams:  5000 / 7395
# Detecting calls in probability streams:  6000 / 7395
# Detecting calls in probability streams:  7000 / 7395
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 7395
# Detecting calls in probability streams:  1000 / 7395
# Detecting calls in probability streams:  2000 / 7395
# Detecting calls in probability streams:  3000 / 7395
# Detecting calls in probability streams:  4000 / 7395
# Detecting calls in probability streams:  5000 / 7395
# Detecting calls in probability streams:  6000 / 7395
# Detecting calls in probability streams:  7000 / 7395
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 7395
# Detecting calls in probability streams:  1000 / 7395
# Detecting calls in probability streams:  2000 / 7395
# Detecting calls in probability streams:  3000 / 7395
# Detecting calls in probability streams:  4000 / 7395
# Detecting calls in probability streams:  5000 / 7395
# Detecting calls in probability streams:  6000 / 7395
# Detecting calls in probability streams:  7000 / 7395
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 7395
# Detecting calls in probability streams:  1000 / 7395
# Detecting calls in probability streams:  2000 / 7395
# Detecting calls in probability streams:  3000 / 7395
# Detecting calls in probability streams:  4000 / 7395
# Detecting calls in probability streams:  5000 / 7395
# Detecting calls in probability streams:  6000 / 7395
# Detecting calls in probability streams:  7000 / 7395
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 7395
# Detecting calls in probability streams:  1000 / 7395
# Detecting calls in probability streams:  2000 / 7395
# Detecting calls in probability streams:  3000 / 7395
# Detecting calls in probability streams:  4000 / 7395
# Detecting calls in probability streams:  5000 / 7395
# Detecting calls in probability streams:  6000 / 7395
# Detecting calls in probability streams:  7000 / 7395
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 7395
# Detecting calls in probability streams:  1000 / 7395
# Detecting calls in probability streams:  2000 / 7395
# Detecting calls in probability streams:  3000 / 7395
# Detecting calls in probability streams:  4000 / 7395
# Detecting calls in probability streams:  5000 / 7395
# Detecting calls in probability streams:  6000 / 7395
# Detecting calls in probability streams:  7000 / 7395
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 7395
# Detecting calls in probability streams:  1000 / 7395
# Detecting calls in probability streams:  2000 / 7395
# Detecting calls in probability streams:  3000 / 7395
# Detecting calls in probability streams:  4000 / 7395
# Detecting calls in probability streams:  5000 / 7395
# Detecting calls in probability streams:  6000 / 7395
# Detecting calls in probability streams:  7000 / 7395
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 7395
# Detecting calls in probability streams:  1000 / 7395
# Detecting calls in probability streams:  2000 / 7395
# Detecting calls in probability streams:  3000 / 7395
# Detecting calls in probability streams:  4000 / 7395
# Detecting calls in probability streams:  5000 / 7395
# Detecting calls in probability streams:  6000 / 7395
# Detecting calls in probability streams:  7000 / 7395
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 7395
# Detecting calls in probability streams:  1000 / 7395
# Detecting calls in probability streams:  2000 / 7395
# Detecting calls in probability streams:  3000 / 7395
# Detecting calls in probability streams:  4000 / 7395
# Detecting calls in probability streams:  5000 / 7395
# Detecting calls in probability streams:  6000 / 7395
# Detecting calls in probability streams:  7000 / 7395
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 7395
# Detecting calls in probability streams:  1000 / 7395
# Detecting calls in probability streams:  2000 / 7395
# Detecting calls in probability streams:  3000 / 7395
# Detecting calls in probability streams:  4000 / 7395
# Detecting calls in probability streams:  5000 / 7395
# Detecting calls in probability streams:  6000 / 7395
# Detecting calls in probability streams:  7000 / 7395
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 7395
# Detecting calls in probability streams:  1000 / 7395
# Detecting calls in probability streams:  2000 / 7395
# Detecting calls in probability streams:  3000 / 7395
# Detecting calls in probability streams:  4000 / 7395
# Detecting calls in probability streams:  5000 / 7395
# Detecting calls in probability streams:  6000 / 7395
# Detecting calls in probability streams:  7000 / 7395
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 7395
# Detecting calls in probability streams:  1000 / 7395
# Detecting calls in probability streams:  2000 / 7395
# Detecting calls in probability streams:  3000 / 7395
# Detecting calls in probability streams:  4000 / 7395
# Detecting calls in probability streams:  5000 / 7395
# Detecting calls in probability streams:  6000 / 7395
# Detecting calls in probability streams:  7000 / 7395
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 7395
# Detecting calls in probability streams:  1000 / 7395
# Detecting calls in probability streams:  2000 / 7395
# Detecting calls in probability streams:  3000 / 7395
# Detecting calls in probability streams:  4000 / 7395
# Detecting calls in probability streams:  5000 / 7395
# Detecting calls in probability streams:  6000 / 7395
# Detecting calls in probability streams:  7000 / 7395
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 7395
# Detecting calls in probability streams:  1000 / 7395
# Detecting calls in probability streams:  2000 / 7395
# Detecting calls in probability streams:  3000 / 7395
# Detecting calls in probability streams:  4000 / 7395
# Detecting calls in probability streams:  5000 / 7395
# Detecting calls in probability streams:  6000 / 7395
# Detecting calls in probability streams:  7000 / 7395
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 5886
# Detecting calls in probability streams:  1000 / 5886
# Detecting calls in probability streams:  2000 / 5886
# Detecting calls in probability streams:  3000 / 5886
# Detecting calls in probability streams:  4000 / 5886
# Detecting calls in probability streams:  5000 / 5886
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 5886
# Detecting calls in probability streams:  1000 / 5886
# Detecting calls in probability streams:  2000 / 5886
# Detecting calls in probability streams:  3000 / 5886
# Detecting calls in probability streams:  4000 / 5886
# Detecting calls in probability streams:  5000 / 5886
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 5886
# Detecting calls in probability streams:  1000 / 5886
# Detecting calls in probability streams:  2000 / 5886
# Detecting calls in probability streams:  3000 / 5886
# Detecting calls in probability streams:  4000 / 5886
# Detecting calls in probability streams:  5000 / 5886
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 5886
# Detecting calls in probability streams:  1000 / 5886
# Detecting calls in probability streams:  2000 / 5886
# Detecting calls in probability streams:  3000 / 5886
# Detecting calls in probability streams:  4000 / 5886
# Detecting calls in probability streams:  5000 / 5886
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 5886
# Detecting calls in probability streams:  1000 / 5886
# Detecting calls in probability streams:  2000 / 5886
# Detecting calls in probability streams:  3000 / 5886
# Detecting calls in probability streams:  4000 / 5886
# Detecting calls in probability streams:  5000 / 5886
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 5886
# Detecting calls in probability streams:  1000 / 5886
# Detecting calls in probability streams:  2000 / 5886
# Detecting calls in probability streams:  3000 / 5886
# Detecting calls in probability streams:  4000 / 5886
# Detecting calls in probability streams:  5000 / 5886
# ...
# Detecting calls in probability streams:  4000 / 5740
# Detecting calls in probability streams:  5000 / 5740
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 5740
# Detecting calls in probability streams:  1000 / 5740
# Detecting calls in probability streams:  2000 / 5740
# Detecting calls in probability streams:  3000 / 5740
# Detecting calls in probability streams:  4000 / 5740
# Detecting calls in probability streams:  5000 / 5740
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 5740
# Detecting calls in probability streams:  1000 / 5740
# Detecting calls in probability streams:  2000 / 5740
# Detecting calls in probability streams:  3000 / 5740
# Detecting calls in probability streams:  4000 / 5740
# Detecting calls in probability streams:  5000 / 5740
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 5740
# Detecting calls in probability streams:  1000 / 5740
# Detecting calls in probability streams:  2000 / 5740
# Detecting calls in probability streams:  3000 / 5740
# Detecting calls in probability streams:  4000 / 5740
# Detecting calls in probability streams:  5000 / 5740
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 5740
# Detecting calls in probability streams:  1000 / 5740
# Detecting calls in probability streams:  2000 / 5740
# Detecting calls in probability streams:  3000 / 5740
# Detecting calls in probability streams:  4000 / 5740
# Detecting calls in probability streams:  5000 / 5740
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 5740
# Detecting calls in probability streams:  1000 / 5740
# Detecting calls in probability streams:  2000 / 5740
# Detecting calls in probability streams:  3000 / 5740
# Detecting calls in probability streams:  4000 / 5740
# Detecting calls in probability streams:  5000 / 5740
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 5740
# Detecting calls in probability streams:  1000 / 5740
# Detecting calls in probability streams:  2000 / 5740
# Detecting calls in probability streams:  3000 / 5740
# Detecting calls in probability streams:  4000 / 5740
# Detecting calls in probability streams:  5000 / 5740
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 5740
# Detecting calls in probability streams:  1000 / 5740
# Detecting calls in probability streams:  2000 / 5740
# Detecting calls in probability streams:  3000 / 5740
# Detecting calls in probability streams:  4000 / 5740
# Detecting calls in probability streams:  5000 / 5740
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 5740
# Detecting calls in probability streams:  1000 / 5740
# Detecting calls in probability streams:  2000 / 5740
# Detecting calls in probability streams:  3000 / 5740
# Detecting calls in probability streams:  4000 / 5740
# Detecting calls in probability streams:  5000 / 5740
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 5740
# Detecting calls in probability streams:  1000 / 5740
# Detecting calls in probability streams:  2000 / 5740
# Detecting calls in probability streams:  3000 / 5740
# Detecting calls in probability streams:  4000 / 5740
# Detecting calls in probability streams:  5000 / 5740
# *****************************************************************
# *****************************************************************
# File being processed : /home/kiran/Documents/MPI-Server/EAS_shared/meerkat/archive/rawdata/MEERKAT_RAW_DATA/2019/HM_2019_2/COLLAR/AUDIO/HM_VHMM017_RSTB_R23_20190708-20190720/HM_VHMM017_RSTB_R23_20190708-20190720_file_6_(2019_07_12-11_44_59)_125944.wav
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 6331
# Detecting calls in probability streams:  1000 / 6331
# Detecting calls in probability streams:  2000 / 6331
# Detecting calls in probability streams:  3000 / 6331
# Detecting calls in probability streams:  4000 / 6331
# Detecting calls in probability streams:  5000 / 6331
# Detecting calls in probability streams:  6000 / 6331
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 6331
# Detecting calls in probability streams:  1000 / 6331
# Detecting calls in probability streams:  2000 / 6331
# Detecting calls in probability streams:  3000 / 6331
# Detecting calls in probability streams:  4000 / 6331
# Detecting calls in probability streams:  5000 / 6331
# Detecting calls in probability streams:  6000 / 6331
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 6331
# Detecting calls in probability streams:  1000 / 6331
# Detecting calls in probability streams:  2000 / 6331
# Detecting calls in probability streams:  3000 / 6331
# Detecting calls in probability streams:  4000 / 6331
# Detecting calls in probability streams:  5000 / 6331
# Detecting calls in probability streams:  6000 / 6331
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 6331
# Detecting calls in probability streams:  1000 / 6331
# Detecting calls in probability streams:  2000 / 6331
# Detecting calls in probability streams:  3000 / 6331
# Detecting calls in probability streams:  4000 / 6331
# Detecting calls in probability streams:  5000 / 6331
# Detecting calls in probability streams:  6000 / 6331
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 6331
# Detecting calls in probability streams:  1000 / 6331
# Detecting calls in probability streams:  2000 / 6331
# Detecting calls in probability streams:  3000 / 6331
# Detecting calls in probability streams:  4000 / 6331
# Detecting calls in probability streams:  5000 / 6331
# Detecting calls in probability streams:  6000 / 6331
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 6331
# Detecting calls in probability streams:  1000 / 6331
# Detecting calls in probability streams:  2000 / 6331
# Detecting calls in probability streams:  3000 / 6331
# Detecting calls in probability streams:  4000 / 6331
# Detecting calls in probability streams:  5000 / 6331
# Detecting calls in probability streams:  6000 / 6331
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 6331
# Detecting calls in probability streams:  1000 / 6331
# Detecting calls in probability streams:  2000 / 6331
# Detecting calls in probability streams:  3000 / 6331
# Detecting calls in probability streams:  4000 / 6331
# Detecting calls in probability streams:  5000 / 6331
# Detecting calls in probability streams:  6000 / 6331
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 6331
# Detecting calls in probability streams:  1000 / 6331
# Detecting calls in probability streams:  2000 / 6331
# Detecting calls in probability streams:  3000 / 6331
# Detecting calls in probability streams:  4000 / 6331
# Detecting calls in probability streams:  5000 / 6331
# Detecting calls in probability streams:  6000 / 6331
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 6331
# Detecting calls in probability streams:  1000 / 6331
# Detecting calls in probability streams:  2000 / 6331
# Detecting calls in probability streams:  3000 / 6331
# Detecting calls in probability streams:  4000 / 6331
# Detecting calls in probability streams:  5000 / 6331
# Detecting calls in probability streams:  6000 / 6331
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 6331
# Detecting calls in probability streams:  1000 / 6331
# Detecting calls in probability streams:  2000 / 6331
# Detecting calls in probability streams:  3000 / 6331
# Detecting calls in probability streams:  4000 / 6331
# Detecting calls in probability streams:  5000 / 6331
# Detecting calls in probability streams:  6000 / 6331
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 6331
# Detecting calls in probability streams:  1000 / 6331
# Detecting calls in probability streams:  2000 / 6331
# Detecting calls in probability streams:  3000 / 6331
# Detecting calls in probability streams:  4000 / 6331
# Detecting calls in probability streams:  5000 / 6331
# Detecting calls in probability streams:  6000 / 6331
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 6331
# Detecting calls in probability streams:  1000 / 6331
# Detecting calls in probability streams:  2000 / 6331
# Detecting calls in probability streams:  3000 / 6331
# Detecting calls in probability streams:  4000 / 6331
# Detecting calls in probability streams:  5000 / 6331
# Detecting calls in probability streams:  6000 / 6331
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 6331
# Detecting calls in probability streams:  1000 / 6331
# Detecting calls in probability streams:  2000 / 6331
# Detecting calls in probability streams:  3000 / 6331
# Detecting calls in probability streams:  4000 / 6331
# Detecting calls in probability streams:  5000 / 6331
# Detecting calls in probability streams:  6000 / 6331
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 6331
# Detecting calls in probability streams:  1000 / 6331
# Detecting calls in probability streams:  2000 / 6331
# Detecting calls in probability streams:  3000 / 6331
# Detecting calls in probability streams:  4000 / 6331
# Detecting calls in probability streams:  5000 / 6331
# Detecting calls in probability streams:  6000 / 6331
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 6331
# Detecting calls in probability streams:  1000 / 6331
# Detecting calls in probability streams:  2000 / 6331
# Detecting calls in probability streams:  3000 / 6331
# Detecting calls in probability streams:  4000 / 6331
# Detecting calls in probability streams:  5000 / 6331
# Detecting calls in probability streams:  6000 / 6331
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 6331
# Detecting calls in probability streams:  1000 / 6331
# Detecting calls in probability streams:  2000 / 6331
# Detecting calls in probability streams:  3000 / 6331
# Detecting calls in probability streams:  4000 / 6331
# Detecting calls in probability streams:  5000 / 6331
# Detecting calls in probability streams:  6000 / 6331
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 6331
# Detecting calls in probability streams:  1000 / 6331
# Detecting calls in probability streams:  2000 / 6331
# Detecting calls in probability streams:  3000 / 6331
# Detecting calls in probability streams:  4000 / 6331
# Detecting calls in probability streams:  5000 / 6331
# Detecting calls in probability streams:  6000 / 6331
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 6331
# Detecting calls in probability streams:  1000 / 6331
# Detecting calls in probability streams:  2000 / 6331
# Detecting calls in probability streams:  3000 / 6331
# Detecting calls in probability streams:  4000 / 6331
# Detecting calls in probability streams:  5000 / 6331
# Detecting calls in probability streams:  6000 / 6331
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 861
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 861
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 861
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 861
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 861
# *****************************************************************
# Low Threshold: 0.05
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 861
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 861
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 861
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 861
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 861
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 861
# *****************************************************************
# Low Threshold: 0.1
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 861
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.5
# Detecting calls in probability streams:  0 / 861
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.6
# Detecting calls in probability streams:  0 / 861
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.7
# Detecting calls in probability streams:  0 / 861
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.8
# Detecting calls in probability streams:  0 / 861
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.9
# Detecting calls in probability streams:  0 / 861
# *****************************************************************
# Low Threshold: 0.2
# High Threshold: 0.95
# Detecting calls in probability streams:  0 / 861
# *****************************************************************
# *****************************************************************
# File being processed : /home/kiran/Documents/MPI-Server/EAS_shared/meerkat/archive/rawdata/MEERKAT_RAW_DATA/2019/HM_2019_2/COLLAR/AUDIO/HM_VHMM021_MBLT_R01_20190707-20190719/HM_VHMM021_MBLT_R01_20190707-20190719_file_6_(2019_07_12-11_44_59)_125944.wav

# %%
#because we don't want to retrain the first
train_pattern = [["L2019","HM2019"],["HM2017","HM2019"], ["L2019"]]

for sensitivity_i in train_pattern:  
    
    
    ### SETUP file structure for sensitivity runs
    #------------------------------------------------------------
    run_name = "NoiseAugmented_"+ str(min_scaling_factor)+"_" +str(max_scaling_factor)+"_NotWeighted_MaskedOther_Forked_trained_with_" + '_'.join(sensitivity_i)

    # basically the root directory for train, test and model
    save_data_path = os.path.join(results_dir, run_name)
    if not os.path.isdir(save_data_path):
        os.makedirs(save_data_path)

    # Test folders
    test_path = os.path.join(save_data_path, 'test_data')
    if not os.path.isdir(test_path):
        os.makedirs(test_path)


    save_pred_test_path = os.path.join(test_path , "predictions")
    if not os.path.isdir(save_pred_test_path):
        os.makedirs(save_pred_test_path)

    save_pred_stack_test_path = os.path.join(save_pred_test_path,"stacks")
    if not os.path.isdir(save_pred_stack_test_path):
        os.makedirs(save_pred_stack_test_path)        

    save_pred_table_test_path = os.path.join(save_pred_test_path,"pred_table")
    if not os.path.isdir(save_pred_table_test_path):
        os.makedirs(save_pred_table_test_path)

    save_label_table_test_path = os.path.join(test_path, 'label_table')
    if not os.path.isdir(save_label_table_test_path):
        os.makedirs(save_label_table_test_path)

    save_metrics_path = os.path.join(test_path , "metrics")
    if not os.path.isdir(save_metrics_path):
        os.makedirs(save_metrics_path)

    save_metrics_path_eval = os.path.join(save_metrics_path, eval_analysis)
    if not os.path.isdir(save_metrics_path_eval):
        os.makedirs(save_metrics_path_eval)


    # Model folder
    save_model_path = os.path.join(save_data_path, 'trained_model')
    if not os.path.isdir(save_model_path):
        os.makedirs(save_model_path)
        
   

    training_files = label_table['wavFileName'][label_table['group'].isin(sensitivity_i)].unique()
    testing_filenames = label_table['wavFileName'][label_table['group'].isin(sensitivity_i) == False].unique()
    
    # Split the training and test set based on the separation
    split_index = floor(len(training_files) * train_val_split )
    training_filenames = training_files[:split_index]
    validation_filenames = training_files[split_index:]


    # save a copy of the training and testing diles
    with open(os.path.join(save_model_path, "training_files_used.txt"), "w") as f:
        for s in training_filenames:
            f.write(str(s) +"\n")
    with open(os.path.join(save_model_path, "testing_files_used.txt"), "w") as f:
        for s in testing_filenames:
            f.write(str(s) +"\n")
    with open(os.path.join(save_model_path, "validation_files_used.txt"), "w") as f:
        for s in validation_filenames:
            f.write(str(s) +"\n")


    '''Then we create a dictionary that will be used in the datagenerator. 
    Each key is a calltype and contains the start/stop/duration/filename where that call occurs. 
    This allows the data generator to shuffle them during the training.
    '''

    # separate out the training and test sets for analysis
    training_label_table = label_table[label_table['wavFileName'].isin(training_filenames)]
    testing_label_table = label_table[label_table['wavFileName'].isin(testing_filenames)]
    validation_label_table = label_table[label_table['wavFileName'].isin(validation_filenames)]

    # do the same for the noise
    training_noise_table = noise_table[noise_table['wavFileName'].isin(training_filenames)]
    testing_noise_table = noise_table[noise_table['wavFileName'].isin(testing_filenames)]
    validation_noise_table = noise_table[noise_table['wavFileName'].isin(validation_filenames)]

    # Compile training data into a format that the data generator can use
    training_label_dict = dict()
    for label in call_types: 
        training_label_dict[label] = training_label_table.loc[training_label_table[label] == True, ["Label", "Start", "Duration","End","wav_path","label_path"]]
    training_label_dict[label_for_noise] = training_noise_table[["Label", "Start", "Duration","End","wav_path","label_path"]]

    # Compile test data into a format that the data generator can use
    testing_label_dict = dict()
    for label in call_types: 
        testing_label_dict[label] = testing_label_table.loc[testing_label_table[label] == True, ["Label", "Start", "Duration","End","wav_path","label_path"]]
    testing_label_dict[label_for_noise] = testing_noise_table[["Label", "Start", "Duration","End","wav_path","label_path"]]

    # Compile validation data into a format that the data generator can use
    validation_label_dict = dict()
    for label in call_types: 
        validation_label_dict[label] = validation_label_table.loc[validation_label_table[label] == True, ["Label", "Start", "Duration","End","wav_path","label_path"]]
    validation_label_dict[label_for_noise] = validation_label_table[["Label", "Start", "Duration","End","wav_path","label_path"]]

    #---------------------------------------------------------------------------------------------
    #---------------------------------------------------------------------------------------------
    # TRAINING
    #---------------------------------------------------------------------------------------------
    #---------------------------------------------------------------------------------------------
    

    ## Build the training and validation data generators (for real this time)
    #---------------------------------------------------------------------------------------------
    


    if is_forked == True:
        # initiate the data generator
        train_generator = bg.ForkedDataGenerator(training_label_dict,
                                                 training_label_table, 
                                                 spec_window_size,
                                                 n_mels, 
                                                 window, 
                                                 fft_win , 
                                                 fft_hop , 
                                                 normalise,
                                                 label_for_noise,
                                                 label_for_other,
                                                 min_scaling_factor,
                                                 max_scaling_factor,
                                                 n_per_call,
                                                 other_ignored_in_training,
                                                 mask_value,
                                                 mask_vector)
        
        # get a batch to estimate rnn parameters
        x_train, y_train = train_generator.__next__()#__getitem__(0)

        # initial parameters
        num_calltypes = y_train[0].shape[2]
        gru_units = y_train[0].shape[1] 


        # initialise the training data generator and validation data generator
        train_generator = bg.ForkedDataGenerator(training_label_dict,
                                                 training_label_table, 
                                                 spec_window_size,
                                                 n_mels, 
                                                 window, 
                                                 fft_win , 
                                                 fft_hop , 
                                                 normalise,
                                                 label_for_noise,
                                                 label_for_other,
                                                 min_scaling_factor,
                                                 max_scaling_factor,
                                                 n_per_call,
                                                 other_ignored_in_training,
                                                 mask_value,
                                                 mask_vector)

        val_generator = bg.ForkedDataGenerator(validation_label_dict,
                                               validation_label_table, 
                                               spec_window_size,
                                               n_mels, 
                                               window, 
                                               fft_win , 
                                               fft_hop , 
                                               normalise,
                                               label_for_noise,
                                               label_for_other,
                                               min_scaling_factor,
                                               max_scaling_factor,
                                               n_per_call,
                                               other_ignored_in_training,
                                               mask_value,
                                               mask_vector)

    else:
        train_generator = bg.DataGenerator(training_label_dict,
                                                 training_label_table, 
                                                 spec_window_size,
                                                 n_mels, 
                                                 window, 
                                                 fft_win , 
                                                 fft_hop , 
                                                 normalise,
                                                 label_for_noise,
                                                 label_for_other,
                                                 min_scaling_factor,
                                                 max_scaling_factor,
                                                 n_per_call,
                                                 other_ignored_in_training,
                                                 mask_value,
                                                 mask_vector)
        x_train, y_train = train_generator.__next__()#__getitem__(0)

        # initial parameters
        num_calltypes = y_train[0].shape[2]
        gru_units = y_train[0].shape[1] 

        train_generator = bg.DataGenerator(training_label_dict,
                                                 training_label_table, 
                                                 spec_window_size,
                                                 n_mels, 
                                                 window, 
                                                 fft_win , 
                                                 fft_hop , 
                                                 normalise,
                                                 label_for_noise,
                                                 label_for_other,
                                                 min_scaling_factor,
                                                 max_scaling_factor,
                                                 n_per_call,
                                                 other_ignored_in_training,
                                                 mask_value,
                                                 mask_vector)

        val_generator = bg.DataGenerator(validation_label_dict,
                                               validation_label_table, 
                                               spec_window_size,
                                               n_mels, 
                                               window, 
                                               fft_win , 
                                               fft_hop , 
                                               normalise,
                                               label_for_noise,
                                               label_for_other,
                                               min_scaling_factor,
                                               max_scaling_factor,
                                               n_per_call,
                                               other_ignored_in_training,
                                               mask_value,
                                               mask_vector)    



    #---------------------------------------------------------------------------------------------
    ## CONSTRUCT THE RNN
    #---------------------------------------------------------------------------------------------

    # initialise the model class
    model = rnn.BuildNetwork(x_train, num_calltypes, filters, gru_units, dense_neurons, dropout, mask_value)

    # build the model
    if is_forked == True:
        RNN_model = model.build_forked_masked_rnn()

        # Multiple target losses
        losses = {
            'output_calltype' : 'categorical_crossentropy',  # classification
            'output_callpresence' : 'mse'  # regression 0-1
        }

        loss_weights = {
            'output_calltype' : 1.0,
            'output_callpresence' : 0.05  # Making this too large is not a good idea as we really want the network paying attention to class
        }
        accuracy_metrics = {
            'output_calltype' : 'categorical_accuracy',
            'output_callpresence' : 'binary_accuracy'
            
        }

    else:
        RNN_model = model.build_masked_rnn()
        # only one target loss
        losses = 'categorical_crossentropy'
        loss_weights = None
        accuracy_metrics = 'categorical_accuracy'

    # Adam optimiser
    adam = optimizers.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

    # Compile the model
    #RNN_model.compile(optimizer=adam, loss=losses, loss_weights=loss_weights, metrics=['binary_accuracy'])
    RNN_model.compile(optimizer=adam, loss=losses, loss_weights=loss_weights, metrics = accuracy_metrics)

    # Setup callbycks: learning rate / loss /tensorboard
    early_stopping = EarlyStopping(monitor='val_loss', patience=40, restore_best_weights=True, verbose=1)
    reduce_lr_plat = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=25, verbose=1,
                                       mode='auto', min_delta=0.0001, cooldown=0, min_lr=0.000001)
    loss = LossHistory()

    # setup a path with a timestamp
    date_time = datetime.datetime.now()
    date_now = str(date_time.date())
    time_now = str(date_time.time())
    save_tensorboard_path = os.path.join(save_model_path, "tensorboard_logs_" + date_now + "_" + time_now)
    if not os.path.isdir(save_tensorboard_path):
        os.makedirs(save_tensorboard_path)   

    # tensorboard
    tensorboard = TensorBoard(log_dir = save_tensorboard_path,
                              histogram_freq=0,
                              write_graph=True,  # Show the network
                              write_grads=True   # Show gradients
                              )  
    # fit model
    RNN_model.fit_generator(train_generator, 
                            steps_per_epoch = train_generator.__len__(),
                            epochs = epochs,
                            callbacks = [early_stopping, reduce_lr_plat, loss, tensorboard],
                            validation_data = val_generator,
                            validation_steps = val_generator.__len__())


    # Look at the model
    # plot_model(RNN_model, run_name + ".png", show_shapes=True)


    #---------------------------------------------------------------------------------------------
    ## SAVE THE MODEL
    #---------------------------------------------------------------------------------------------

    # save the model
    date_time = datetime.datetime.now()
    date_now = str(date_time.date())
    time_now = str(date_time.time())
    sf = os.path.join(save_model_path, run_name+ "_" + date_now + "_" + time_now)
    if not os.path.isdir(sf):
        os.makedirs(sf)

    RNN_model.save(sf + '/savedmodel' + '.h5')

    print(sf)

    test = load_model(sf + '/savedmodel' + '.h5')
    test.summary()
    #test.predict([spec])




    #---------------------------------------------------------------------------------------------
    #---------------------------------------------------------------------------------------------
    ## TESTING
    #---------------------------------------------------------------------------------------------
    #---------------------------------------------------------------------------------------------

    ## Predict over the test files
    #---------------------------------------------------------------------------------------------
    skipped_files = []

    # we only do one file in this example to avoid it running too long
    for file_ID in testing_filenames:
        # file_ID = testing_filenames[0] # for testing purposes only

        # subset the label table to only use that one file
        label_table = testing_label_table[testing_label_table['wavFileName'].isin([file_ID])]
        label_table = label_table.sort_values(by=['Start']).reset_index()
        # Find the file ID name i.e. remove the extention
        file_ID = file_ID.split(".")[0] 
        # find the matching audio for the label data
        audio_path = label_table["wav_path"][0]   

        print("*****************************************************************")   
        print("*****************************************************************") 
        print ("File being processed : " + audio_path)    

        # find the start and stop  of the labelling periods (also using skipon/skipoff)
        loop_table = label_table.loc[label_table["Label"].str.contains('|'.join(label_for_startstop), regex=True, case = False), ["Label","Start"]]
        loop_times = list(loop_table["Start"])

        # Make sure that the file contains the right number of start and stops, otherwise go to the next file
        if len(loop_times)%2 != 0:
            print("!!!!!!!!!!!!!!!!")
            warnings.warn("There is a missing start or stop in this file and it has been skipped: " + audio_path)
            skipped_files.append(file_ID)
            continue 

        if len(loop_times) == 0:
            print("!!!!!!!!!!!!!!!!")
            warnings.warn("There is a missing start or stop in this file and it has been skipped: " + audio_path)
            skipped_files.append(file_ID)
            continue 

        # save the label_table
        save_label_table_filename = file_ID + "_LABEL_TABLE.txt"
        label_table.to_csv(os.path.join(save_label_table_test_path, save_label_table_filename), 
                            header=True, index=None, sep=';')

        # load the audio data
        y, sr = librosa.load(audio_path, sr=None, mono=False)

        # # Reshaping the Audio file (mono) to deal with all wav files similarly
        # if y.ndim == 1:
        #     y = y.reshape(1, -1)

        # # Implement this for acc data
        # for ch in range(y.shape[0]):
        # ch=0
        # y_sub = y[:,ch]
        y_sub = y

        # loop through every labelling start based on skipon/off within this loop_table
        for loopi in range(0, int(len(loop_times)), 2):
            # loopi = 0
            fromi =  loop_times[loopi]
            #toi = fromi + 5
            toi = loop_times[int(loopi + 1)] # define the end of the labelling periods

            calltype_pred_list = []
            callpresence_pred_list = []
            # if the file exists, load it
            if os.path.exists(os.path.join(save_pred_stack_test_path, file_ID + '_CALLTYPE_PRED_STACK_' + str(fromi) + '-' + str(toi) + '.npy')): 
                calltype_pred_list = np.load( os.path.join(save_pred_stack_test_path, file_ID + '_CALLTYPE_PRED_STACK_' + str(fromi) + '-' + str(toi) + '.npy')) 
                callpresence_pred_list = np.load( os.path.join(save_pred_stack_test_path, file_ID + '_CALLPRESENCE_PRED_STACK_' + str(fromi) + '-' + str(toi) + '.npy'))


            # if the file is incomplete or non existant redo it
            if (len(np.arange(fromi, toi, slide)) - sum(np.arange(fromi, toi, slide)+spec_window_size > toi)) != (len(calltype_pred_list)):

                for spectro_slide in np.arange(fromi, toi, slide):                
                    # spectro_slide = fromi
                    start = round(spectro_slide,3)
                    stop = round(spectro_slide + spec_window_size, 3)

                    # ignore cases where the window is larger than what is labelled (e.g. at the end)
                    if stop <= toi:

                        #generate the spectrogram
                        spectro = pre.generate_mel_spectrogram(y=y_sub, sr=sr, start=start, stop=stop, 
                                                                n_mels = n_mels, window='hann', 
                                                                fft_win= fft_win, fft_hop = fft_hop, 
                                                                normalise = True)

                        # transpose it and put it in a format that works with the NN
                        spec = spectro.T
                        spec = spec[np.newaxis, ..., np.newaxis]  

                        # generate a mask (as a placeholder) but don't mask anything as we are predicting and want to include other
                        mask = np.asarray([True for i in range(spectro.shape[1])])
                        mask = mask[np.newaxis,...]

                        # generate the prediction
                        pred = RNN_model.predict([spec,mask])

                        # add this prediction to the stack that will be used to generate the predictions table
                        if is_forked:
                            calltype_pred_list.append(np.squeeze(pred[0]))
                            callpresence_pred_list.append(np.squeeze(pred[1]))
                        else:
                            calltype_pred_list.append(np.squeeze(pred))

                # save the prediction stacks
                np.save( os.path.join(save_pred_stack_test_path, file_ID + '_CALLTYPE_PRED_STACK_' + str(fromi) + '-' + str(toi) + '.npy'), calltype_pred_list)
                with open(os.path.join(save_pred_stack_test_path, file_ID + '_CALLTYPE_PRED_STACK_' + str(fromi) + '-' + str(toi) + '.txt'), "w") as f:
                    for row in calltype_pred_list:
                        f.write(str(row) +"\n")
                if is_forked:      
                    np.save( os.path.join(save_pred_stack_test_path, file_ID + '_CALLPRESENCE_PRED_STACK_' + str(fromi) + '-' + str(toi) + '.npy'), callpresence_pred_list)
                    with open(os.path.join(save_pred_stack_test_path, file_ID + '_CALLPRESENCE_PRED_STACK_' + str(fromi) + '-' + str(toi) + '.txt'), "w") as f:
                        for row in callpresence_pred_list:
                            f.write(str(row) +"\n")

            # Loop through different sets of thresholds
            for low_thr in [0.05,0.1,0.2]:
                for high_thr in [0.5,0.6,0.7,0.8,0.9,0.95]: 

                    # make sure it doesnt generate a 0.00098982374957839486 type number
                    low_thr = round(low_thr,2)                               
                    high_thr = round(high_thr,2)

                    # stop the loop if the low threshold is bigger than the high threshold
                    if low_thr >= high_thr:
                        continue

                    save_pred_table_filename = file_ID + "_CALLTYPE_PRED_TABLE_thr_" + str(low_thr) + "-" + str(high_thr) + ".txt"

                    # if the file exists, pass to the next iteration of the loop
                    #if os.path.exists(os.path.join(save_pred_table_test_path, save_pred_table_filename)):
                    #    continue

                    print("*****************************************************************") 
                    print ("Low Threshold: " + str(low_thr))    
                    print ("High Threshold: " + str(high_thr))  

                    #----------------------------------------------------------------------------
                    # Compile the predictions for each on/off labelling chunk
                    detections = ppm.merge_p(probabilities = calltype_pred_list, 
                                              labels=list(call_types.keys()),
                                              starttime = 0, 
                                              frameadv_s = fft_hop, 
                                              specadv_s = slide,
                                              low_thr=low_thr, 
                                              high_thr=high_thr, 
                                              debug=1)

                    #in case the dataset was just noise, still create an empty placeholder to merge
                    if len(detections) == 0:  
                        detections = pd.DataFrame(columns = ['category', 'start', 'end', 'scores'])

                    # create an empty dataset
                    pred_table = pd.DataFrame() 

                    #convert these detections to a predictions table                
                    table = pd.DataFrame(detections)
                    table["Label"] = table["category"]
                    table["Start"] = round(table["start"]*fft_hop + fromi, 3) #table["start"].apply(Decimal)*Decimal(fft_hop) + Decimal(fromi)
                    table["Duration"] = round( (table["end"]-table["start"])*fft_hop, 3) #(table["end"].apply(Decimal)-table["start"].apply(Decimal))*Decimal(fft_hop)
                    table["End"] = round(table["end"]*fft_hop + fromi, 3) #table["Start"].apply(Decimal) + table["Duration"].apply(Decimal)

                    # keep only the useful columns    
                    table = table[["Label","Start","Duration", "End", "scores"]]  

                    # Add a row which stores the start of the labelling period
                    row_start = pd.DataFrame()
                    row_start.loc[0,'Label'] = list(loop_table["Label"])[loopi]
                    row_start.loc[0,'Start'] = fromi
                    row_start.loc[0,'Duration'] = 0
                    row_start.loc[0,'End'] = fromi 
                    row_start.loc[0,'scores'] = [0] 

                    # Add a row which stores the end of the labelling period
                    row_stop = pd.DataFrame()
                    row_stop.loc[0,'Label'] = list(loop_table["Label"])[int(loopi + 1)]
                    row_stop.loc[0,'Start'] = toi
                    row_stop.loc[0,'Duration'] = 0
                    row_stop.loc[0,'End'] = toi 
                    row_stop.loc[0,'scores'] = [0]       

                    # add the true false columns based on the call types dictionary
                    for true_label in call_types:
                        table[true_label] = False
                        row_start[true_label] = False
                        row_stop[true_label] = False
                        for old_label in call_types[true_label]:
                            table.loc[table["Label"].str.contains(old_label, regex=True, case = False), true_label] = True

                    # make sure start and stop are not classified as calls
                    row_start[label_for_noise] = True
                    row_stop[label_for_noise] = True

                    # put these rows to the label table
                    table = pd.concat([row_start, table, row_stop]) 

                    # add this table to the overall predictions table for that collar
                    pred_table = pd.concat([pred_table, table ])

                    # for each on/off labelling chunk, we can save the prediction and append it to the previous chunk
                    if loopi == 0:                    
                        # for the first chunck keep the header, but not when appending later. Also, overwrite old runs
                        pred_table.to_csv(os.path.join(save_pred_table_test_path, save_pred_table_filename), 
                                          header=True, index=None, sep=';', mode = 'w')
                    else:
                        pred_table.to_csv(os.path.join(save_pred_table_test_path, save_pred_table_filename), 
                                          header=None, index=None, sep=';', mode = 'a')

    '''
    # # load the saved file
    # with open(os.path.join(save_pred_stack_test_path, file_ID + '_PRED_STACK.txt')) as f:
    #     content = f.readlines()
    # # remove whitespace characters like `\n` at the end of each line
    # pred_list = [x.strip() for x in content] 


    # #or
    # pred_list = np.load( os.path.join(save_pred_stack_test_path, file_ID + '_PRED_STACK.npy'))
    # '''

    # save the files that were skipped
    print(skipped_files)

    # save a copy of the training and testing diles
    with open(os.path.join(save_model_path, "skipped_testing_files.txt"), "w") as f:
        for s in skipped_files:
            f.write(str(s) +"\n")


    #---------------------------------------------------------------------------------------------
    #---------------------------------------------------------------------------------------------
    ## TESTING
    #---------------------------------------------------------------------------------------------
    #---------------------------------------------------------------------------------------------

    # because of new file format, need to only keep certain columns so that the evaluation metrics work with the label tables
    column_names = ["Label","Start","Duration","End"]
    column_names.extend(list(testing_label_dict.keys()))
    for file in label_list :
        df = pd.read_csv(file, delimiter=';') 
        # df = df.drop_duplicates(keep=False)
        df = df[column_names]
        df.to_csv(file, header=True, index=None, sep=';', mode = 'w')


    eval_analysis = "call_type_by_call_type"
    save_metrics_path_eval = os.path.join(save_metrics_path, eval_analysis)

    file_ID_list = [file_ID.split(".")[0] for file_ID in testing_filenames if file_ID not in skipped_files]
    label_list =  [os.path.join(save_label_table_test_path,file_ID.split(".")[0]  + "_LABEL_TABLE.txt" ) for file_ID in file_ID_list]


    for low_thr in [0.05,0.1,0.2]:
        for high_thr in [0.5,0.6,0.7,0.8,0.9,0.95]: 

            low_thr = round(low_thr,2)                               
            high_thr = round(high_thr,2) 
            print("**********************************************************")
            print("Evaluating thresholds: " + str(low_thr) + "-" + str(high_thr))
            print("**********************************************************")

            if low_thr >= high_thr:
                continue

            pred_list = [os.path.join(save_pred_table_test_path,file_ID.split(".")[0]  + "_CALLTYPE_PRED_TABLE_thr_" + str(low_thr) + "-" + str(high_thr) + ".txt" ) for file_ID in file_ID_list ]
            evaluation = metrics.Evaluate(label_list = label_list, 
                                          prediction_list = pred_list, 
                                          noise_label = "noise", 
                                          IoU_threshold = 0.2, 
                                          call_analysis = eval_analysis, 
                                          GT_proportion_cut = 0.01, 
                                          no_call = no_call,
                                          headers = set(['Label', 'Duration', 'Start', 'End']),
                                          nonfoc_tags =["NONFOC", "nf", "*"]
                                         ) # 0.99 is 0.5
            output, skipped_calls = evaluation.main()        
            print(str(skipped_calls) + " calls were skipped in total")

            to_pickle = ["Time_Difference", "Matching_Table", "Prediction_Indices", "Label_Indices" , "_Match"]
            for metric in output.keys():
                if any(ext in metric for ext in to_pickle):
                    filename = "PRED_TABLE_thr_" + str(low_thr) + "-" + str(high_thr) + "_" +str(metric) +".p"
                    with open(os.path.join(save_metrics_path_eval, filename), 'wb') as fp:
                        pickle.dump(output[metric], fp) 
                else:
                    filename = "PRED_TABLE_thr_" + str(low_thr) + "-" + str(high_thr) + "_" +str(metric) +".csv"
                    output[metric].to_csv(os.path.join(save_metrics_path_eval, filename))    


    #--------------------------------------------------------------------------------------------
    # PLOT A PREDICTION
    #--------------------------------------------------------------------------------------------


    pool = audiopool.AudioPool() 

    # Find a call
    call = testing_label_dict["sn"].iloc[15]
    label_subset = testing_label_table[testing_label_table['wav_path'].isin([call["wav_path"]])]

    # set the labels
    label_list = list(call_types.keys())
    if other_ignored_in_training:
        label_list.remove(label_for_other)


    # randomise the start a little so the new spectrogram will be a little different from the old
    # if the call is very long have a large range to draw the window
    if call["Duration"]>= spec_window_size:
        call_start = round(float(np.random.uniform(call["Start"]-spec_window_size/2, 
                                                   call["End"]-spec_window_size/2, 1)), 3)
    # if the call is short call, draw it from somewhere
    else:
        call_start = round(float(np.random.uniform((call["Start"]+call["End"])/2-spec_window_size, 
                                                   (call["Start"]+call["End"])/2)), 3)

    # load in a subsection of the spectrogram
    # y, sr = librosa.load(call["wav_path"], sr=None, mono=False,
    #                      offset = call_start, duration =self.spec_window_size)
    y = pool.get_seconds(call["wav_path"], call_start, spec_window_size)
    sr = pool.get_Fs(call["wav_path"])

    call_stop = round(call_start + spec_window_size,3 )

    # have it as an array
    data_subset = np.asfortranarray(y)

    #get the spectrogram
    spectrogram = pre.generate_mel_spectrogram(data_subset, sr, 0, spec_window_size, 
                                               n_mels, window, fft_win , fft_hop , normalise)

    # generate label
    label = pre.create_label_matrix(label_subset, 
                                    spectrogram, 
                                    testing_label_dict, 
                                    call_start, 
                                    call_stop, 
                                    label_for_noise, 
                                    label_for_other, 
                                    other_ignored_in_training)
    # plot spectrogram
    plt.figure(figsize=(10,4))
    #plt.subplot(411)
    yaxis = range(0, np.flipud(spectrogram).shape[0]+1)
    xaxis = range(0, np.flipud(spectrogram).shape[1]+1)
    plt.xticks(np.arange(0, np.flipud(label).shape[1]+1,50),
               list(label.columns[np.arange(0, np.flipud(label).shape[1]+1,50)]))
    librosa.display.specshow(spectrogram,  y_axis='mel', x_coords = label.columns)#, x_axis= "time",sr=sr, x_coords = label.columns)
    plt.ylabel('Frequency (Hz)')
    plt.clim(-35, 35)
    plt.colorbar(format='%+2.0f dB')
    plt.show()

    # plot LABEL
    #plt.subplot(412)
    #print(label.shape)
    plt.figure(figsize=(10, 4))
    xaxis = range(0, np.flipud(label).shape[1]+1)
    yaxis = range(0, np.flipud(label).shape[0]+1)
    plt.yticks(np.arange(0.5, len(label_list)+0.5 ,1 ),reversed(label_list))
    plt.xticks(np.arange(0, np.flipud(label).shape[1]+1,50),
               list(label.columns[np.arange(0, np.flipud(label).shape[1]+1,50)]))
    plt.pcolormesh(xaxis, yaxis, np.flipud(label))
    plt.clim(0, 1)
    plt.xlabel('Time (s)')
    plt.ylabel('Calltype')
    plt.colorbar(label="Label")
    plt.show()

    if is_forked:
        # generate matrix of call/not call
        callmat = pre.create_call_matrix(label_subset, spectrogram, call_start, call_stop, 
                                          label_for_noise, label_for_other, other_ignored_in_training)

    # prediction
    # transpose it and put it in a format that works with the NN
    spec = spectrogram.T
    spec = spec[np.newaxis, ..., np.newaxis]  

    # generate a mask (as a placeholder) but don't mask anything as we are predicting and want to include other
    mask = np.asarray([True for i in range(spectrogram.shape[1])])
    mask = mask[np.newaxis,...]

    # generate the prediction
    pred = RNN_model.predict([spec,mask])

    # add this prediction to the stack that will be used to generate the predictions table
    if is_forked:
        calltype_pred= pred[0]
        callpresence_pred = pred[1]   
    else:
        calltype_pred = pred

    pred = calltype_pred[0].T

    #print(pred.shape)
    #plot calltype prediction
    plt.figure(figsize=(10, 4))
    xaxis = range(0, np.flipud(label).shape[1]+1)
    yaxis = range(0, np.flipud(label).shape[0]+1)
    plt.yticks(np.arange(0.5, len(label_list)+0.5 ,1 ),reversed(label_list))
    plt.xticks(np.arange(0, np.flipud(label).shape[1]+1,50),
               list(label.columns[np.arange(0, np.flipud(label).shape[1]+1,50)]))
    plt.pcolormesh(xaxis, yaxis, np.flipud(pred))
    plt.clim(0, 1)
    plt.xlabel('Time (s)')
    plt.ylabel('Calltype Prediction')
    plt.colorbar(label="Label")
    plt.show()


    if is_forked:  
        # plot call matrix
        #plt.subplot(413)
        plt.figure(figsize=(10, 1))
        xaxis = range(0, np.flipud(label).shape[1]+1)
        yaxis = range(0, np.flipud(callmat).shape[0]+1)
        plt.yticks(np.arange(0.5, callmat.shape[0]+0.5 ,1 ), reversed(callmat.index.values))
        plt.xticks(np.arange(0, np.flipud(label).shape[1]+1,50),
                   list(label.columns[np.arange(0, np.flipud(label).shape[1]+1,50)]))
        plt.pcolormesh(xaxis, yaxis, np.flipud(callmat))
        plt.clim(0, 1)
        plt.xlabel('Time (s)')
        plt.ylabel('Call / No Call')
        plt.colorbar(label="Label")
        plt.show()

        pred = callpresence_pred[0].T
        #plot prediction
        plt.figure(figsize=(10, 1))
        xaxis = range(0, np.flipud(label).shape[1]+1)
        yaxis = range(0, np.flipud(callmat).shape[0]+1)
        plt.yticks(np.arange(0.5, callmat.shape[0]+0.5 ,1 ), reversed(callmat.index.values))
        plt.xticks(np.arange(0, np.flipud(label).shape[1]+1,50),
                   list(label.columns[np.arange(0, np.flipud(label).shape[1]+1,50)]))
        plt.pcolormesh(xaxis, yaxis, np.flipud(pred))
        plt.clim(0, 1)
        plt.xlabel('Time (s)')
        plt.ylabel('Call / No Call prediction')
        plt.colorbar(label="Label")
        plt.show()

    #--------------------------------------------------------------------------------------------
    # CONFUSION MATRIX
    #--------------------------------------------------------------------------------------------

    # loop over the threaholdsf
    for low_thr in [0.1]:#[0.05,0.1,0.2]:
        for high_thr in [0.6]:#[0.5,0.6,0.7,0.8,0.9,0.95]:         
            #########################################
            # FORMAT 

            low_thr = round(low_thr,2)                               
            high_thr = round(high_thr,2) 

            if low_thr >= high_thr:
                continue
            if low_thr == 0.1 and high_thr == 0.2:
                continue

            if eval_analysis == "normal":
                confusion_filename = os.path.join(save_metrics_path_eval, "PRED_TABLE_thr_" + str(low_thr) + "-" + str(high_thr) + '_foc_Confusion_Matrix.csv')
            else:
                confusion_filename = os.path.join(save_metrics_path_eval, "PRED_TABLE_thr_" + str(low_thr) + "-" + str(high_thr) + '__Confusion_Matrix.csv')
            with open(confusion_filename, newline='') as csvfile:
                array = list(csv.reader(csvfile))

            df_cm = pd.DataFrame(array) #, range(6), range(6))    

            # get rid of the weird indentations and make rows and columns as names
            new_col = df_cm.iloc[0] # grab the first row for the header
            df_cm = df_cm[1:] # take the data less the header row
            df_cm.columns = new_col # set the header row as the df header    
            new_row = df_cm['']
            df_cm = df_cm.drop('', 1)
            df_cm.index = new_row
            df_cm.index.name= None
            df_cm.columns.name= None

            # # replace FP and FN with noise
            df_cm['noise'] = df_cm['FN'] 
            #df_cm.loc['noise']=df_cm.loc['FP']

            # remove FP and FN
            df_cm = df_cm.drop("FN", axis=1)
            #df_cm = df_cm.drop("FP", axis=0)

            df_cm = df_cm.apply(pd.to_numeric)

            # Raw confusion matrix
            df_cm = df_cm[list(testing_label_dict.keys())]
            df_cm = df_cm.reindex(list(testing_label_dict.keys()))       

            #########################################
            # CALCULATE

            # Recall confusion matrix
            df_recall = df_cm.div(df_cm.sum(axis=1), axis=0).round(2)#pd.DataFrame(df_cm.values / df_cm.sum(axis=1).values).round(2)

            # Proportion of calls for confusion matrix
            call_len = list()
            for i in testing_label_dict.keys():
                call_len.append(testing_label_dict[i].shape[0])
            # add noise at the end
            call_len[-1] = df_cm.sum(axis=1)[-1]

            #proportion of calls
            df_prop = df_cm.div(call_len, axis=0).round(2)#pd.DataFrame(df_cm.values / df_cm.sum(axis=1).values).round(2)

            #########################################
            # PLOT

            #multi figure parameters
            fig,((ax1,ax2,ax3)) = plt.subplots(1,3, figsize=(20,5))
            fig.suptitle(str(low_thr) + " - " + str(high_thr))

            # plot raw
            sn.set(font_scale=1.1) # for label size
            sn.heatmap((df_cm+1), annot=df_cm, fmt='g',norm = LogNorm(), annot_kws={"size": 10}, ax= ax1) # font size
            ax1.set_title("Raw")              

            # plot recall
            sn.set(font_scale=1.1) # for label size
            sn.heatmap((df_recall), annot=True, fmt='g', annot_kws={"size": 10}, ax= ax2) # font size
            ax2.set_title("Recall" )

            # plot proportion of calls
            sn.set(font_scale=1.1) # for label size
            sn.heatmap((df_prop), annot=True, fmt='g', annot_kws={"size": 10}, ax= ax3) # font size
            ax3.set_title("Call Prop")

            # Save 3 panels
            plt.savefig(os.path.join(save_metrics_path, eval_analysis, "Confusion_mat_thr_" + str(low_thr) + "-" + str(high_thr) + '.png'))
            plt.show()
            plt.clf()
